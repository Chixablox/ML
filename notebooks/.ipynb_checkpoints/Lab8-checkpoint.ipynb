# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report

# %%
train_ds, test_ds = tf.keras.utils.image_dataset_from_directory(
    "../data/data 8.1", # путь к изображениям
    validation_split=0.2, # процент на тест
    subset="both", # берем и обучающую и тестовую выборку
    seed=42, # сид генератора случайных чисел
    image_size=(200,400), # целевой размер изображения (СНАЧАЛА ВЫСОТА, ПОТОМ ШИРИНА)
    batch_size=25, # размер пакета (батча)
)
# Out:
# Found 2000 files belonging to 2 classes.
# Using 1600 files for training.
# Using 400 files for validation.

# %%
data_augmentation = tf.keras.Sequential(
    [
        tf.keras.layers.RandomFlip("horizontal"),
        tf.keras.layers.RandomRotation(0.1),
    ]
)

# %%
train_ds = train_ds.map(
    lambda img, label: (data_augmentation(img), label)
)

# %%
plt.figure(figsize=(10, 10))
# берем один батч
for images, labels in train_ds.take(1):
    # отрисуем 16 картинок из батча
    for i in range(16):
        ax = plt.subplot(4, 4, i + 1)
        # выводим картинку
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(labels[i]))
        # выключаем оси (чтобы они не отображались)
        plt.axis("off")

# %%
# входной слой - размер (200, 400, 3)
inputs = tf.keras.Input(shape=(200, 400, 3))
# преобразуем значения пикселей из [0, 255] к [0, 1]
x = tf.keras.layers.Rescaling(1.0 / 255)(inputs)
x = tf.keras.layers.Conv2D(64, 3, strides=2, padding="same")(x)
x = tf.keras.layers.MaxPooling2D(3, strides=2, padding="same")(x)
x = tf.keras.layers.Conv2D(128, 4, strides=2, padding="same")(x)
x = tf.keras.layers.MaxPooling2D(3, strides=2, padding="same")(x)
x = tf.keras.layers.Conv2D(64, 4, strides=2, padding="same")(x)
x = tf.keras.layers.MaxPooling2D(3, strides=2, padding="same")(x)
# выпрямляем многомерный массив
x = tf.keras.layers.Flatten()(x)
# полносвязный слой с 64 нейронами
x = tf.keras.layers.Dense(64, activation="relu")(x)
# выходной слой с функцией sofrmax
outputs = tf.keras.layers.Dense(2, activation="softmax")(x)
model = tf.keras.Model(inputs, outputs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 200, 400, 3)]     0
#
#  rescaling (Rescaling)       (None, 200, 400, 3)       0
#
#  conv2d (Conv2D)             (None, 100, 200, 64)      1792
#
#  max_pooling2d (MaxPooling2  (None, 50, 100, 64)       0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 25, 50, 128)       131200
#
#  max_pooling2d_1 (MaxPoolin  (None, 13, 25, 128)       0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 7, 13, 64)         131136
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 7, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 1792)              0
#
#  dense (Dense)               (None, 64)                114752
#
#  dense_1 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 379010 (1.45 MB)
# Trainable params: 379010 (1.45 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(1e-3), loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# %%
model.fit(train_ds, epochs=20, validation_data=test_ds)
# Out:
# Epoch 1/20
# 64/64 [==============================] - 26s 387ms/step - loss: 0.7052 - accuracy: 0.5619 - val_loss: 0.6122 - val_accuracy: 0.6550
# Epoch 2/20
# 64/64 [==============================] - 25s 386ms/step - loss: 0.6559 - accuracy: 0.6156 - val_loss: 0.6169 - val_accuracy: 0.5775
# Epoch 3/20
# 64/64 [==============================] - 25s 381ms/step - loss: 0.6295 - accuracy: 0.6475 - val_loss: 0.5797 - val_accuracy: 0.7000
# Epoch 4/20
# 64/64 [==============================] - 25s 382ms/step - loss: 0.5977 - accuracy: 0.6669 - val_loss: 0.5755 - val_accuracy: 0.6775
# Epoch 5/20
# 64/64 [==============================] - 25s 382ms/step - loss: 0.5804 - accuracy: 0.6888 - val_loss: 0.5620 - val_accuracy: 0.6950
# Epoch 6/20
# 64/64 [==============================] - 25s 386ms/step - loss: 0.5762 - accuracy: 0.6931 - val_loss: 0.5882 - val_accuracy: 0.7100
# Epoch 7/20
# 64/64 [==============================] - 27s 422ms/step - loss: 0.5820 - accuracy: 0.7013 - val_loss: 0.5450 - val_accuracy: 0.7125
# Epoch 8/20
# 64/64 [==============================] - 25s 384ms/step - loss: 0.5904 - accuracy: 0.6844 - val_loss: 0.4981 - val_accuracy: 0.7350
# Epoch 9/20
# 64/64 [==============================] - 25s 382ms/step - loss: 0.5662 - accuracy: 0.7106 - val_loss: 0.4668 - val_accuracy: 0.7725
# Epoch 10/20
# 64/64 [==============================] - 25s 382ms/step - loss: 0.5141 - accuracy: 0.7462 - val_loss: 0.4620 - val_accuracy: 0.7850
# Epoch 11/20
# 64/64 [==============================] - 25s 382ms/step - loss: 0.4859 - accuracy: 0.7713 - val_loss: 0.4714 - val_accuracy: 0.7825
# Epoch 12/20
# 64/64 [==============================] - 25s 381ms/step - loss: 0.4861 - accuracy: 0.7625 - val_loss: 0.5057 - val_accuracy: 0.7350
# Epoch 13/20
# 64/64 [==============================] - 25s 382ms/step - loss: 0.4688 - accuracy: 0.7862 - val_loss: 0.4850 - val_accuracy: 0.7675
# Epoch 14/20
# 64/64 [==============================] - 25s 381ms/step - loss: 0.4604 - accuracy: 0.7844 - val_loss: 0.4336 - val_accuracy: 0.7775
# Epoch 15/20
# 64/64 [==============================] - 25s 387ms/step - loss: 0.4397 - accuracy: 0.7975 - val_loss: 0.4200 - val_accuracy: 0.8000
# Epoch 16/20
# 64/64 [==============================] - 25s 383ms/step - loss: 0.4227 - accuracy: 0.8050 - val_loss: 0.4182 - val_accuracy: 0.8025
# Epoch 17/20
# 64/64 [==============================] - 25s 383ms/step - loss: 0.4476 - accuracy: 0.7969 - val_loss: 0.4246 - val_accuracy: 0.8275
# Epoch 18/20
# 64/64 [==============================] - 25s 381ms/step - loss: 0.4266 - accuracy: 0.8200 - val_loss: 0.4490 - val_accuracy: 0.7975
# Epoch 19/20
# 64/64 [==============================] - 24s 378ms/step - loss: 0.4175 - accuracy: 0.8125 - val_loss: 0.4215 - val_accuracy: 0.8225
# Epoch 20/20
# 64/64 [==============================] - 25s 384ms/step - loss: 0.4069 - accuracy: 0.8225 - val_loss: 0.5497 - val_accuracy: 0.7650

# %%
predictions = [np.argmax(pred) for pred in model.predict(test_ds)]
# Out:
# 16/16 [==============================] - 2s 88ms/step

# %%
y_test = np.empty(400)
j=0;
for images, labels in test_ds.take(16):
    for i in range(25):
        y_test[j+i] = int(labels[i])
    j+=25
print(j)
# Out:
# 400

# %%
print(classification_report(y_test, predictions))
print(confusion_matrix(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.69      0.73       182
#          1.0       0.76      0.83      0.79       218
#
#     accuracy                           0.77       400
#    macro avg       0.77      0.76      0.76       400
# weighted avg       0.77      0.77      0.76       400
#
# [[125  57]
#  [ 37 181]]

# %% [markdown]
# # Задание 2

# %% [markdown]
# ## VGG19

# %%
# формируем датасет
train_ds, test_ds = tf.keras.utils.image_dataset_from_directory(
    "../data/data 8.2", # путь к изображениям
    validation_split=0.15, # процент на тест
    subset="both", # берем и обучающую и тестовую выборку
    seed=42, # сид генератора случайных чисел
    image_size=(224,224), # целевой размер изображения (СНАЧАЛА ВЫСОТА, ПОТОМ ШИРИНА)
    batch_size=25, # размер пакета (батча)
)
# Out:
# Found 167 files belonging to 3 classes.
# Using 142 files for training.
# Using 25 files for validation.

# %%
data_augmentation = tf.keras.Sequential(
    [
        tf.keras.layers.RandomFlip("horizontal"),
        tf.keras.layers.RandomRotation(0.1),
    ]
)

# %%
train_ds = train_ds.map(
    lambda img, label: (data_augmentation(img), label)
)

# %%
plt.figure(figsize=(10, 10))
# берем один батч
for images, labels in train_ds.take(1):
    # отрисуем 9 картинок из батча
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        # выводим картинку
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(labels[i]))
        # выключаем оси (чтобы они не отображались)
        plt.axis("off")

# %%
vgg = tf.keras.applications.VGG19(weights='imagenet', include_top=True)
vgg.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 1000)              4097000
#
# =================================================================
# Total params: 143667240 (548.05 MB)
# Trainable params: 143667240 (548.05 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# сохраним ссылку на входной слой сети
inp = vgg.input

# создадим новый слой классификации по нашему количеству классов
new_classification_layer = tf.keras.layers.Dense(3, activation='softmax')

# соединим предпоследний слой VGG и наш новый слой классификации
out = new_classification_layer(vgg.layers[-2].output)

# создадим новую модель
model_new = tf.keras.Model(inp, out)

# %%
model_new.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  dense_2 (Dense)             (None, 3)                 12291
#
# =================================================================
# Total params: 139582531 (532.47 MB)
# Trainable params: 139582531 (532.47 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
for layer in model_new.layers:
    layer.trainable = False
model_new.layers[-1].trainable = True
model_new.layers[-2].trainable = True

# %%
model_new.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model_new.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  dense_2 (Dense)             (None, 3)                 12291
#
# =================================================================
# Total params: 139582531 (532.47 MB)
# Trainable params: 16793603 (64.06 MB)
# Non-trainable params: 122788928 (468.40 MB)
# _________________________________________________________________

# %%
model_new.fit(train_ds, epochs=10, validation_data=test_ds)
# Out:
# Epoch 1/10
# 6/6 [==============================] - 18s 3s/step - loss: 1.7654 - accuracy: 0.7887 - val_loss: 0.7198 - val_accuracy: 0.9600
# Epoch 2/10
# 6/6 [==============================] - 19s 3s/step - loss: 0.2901 - accuracy: 0.9718 - val_loss: 5.9439 - val_accuracy: 0.9200
# Epoch 3/10
# 6/6 [==============================] - 18s 3s/step - loss: 1.3297 - accuracy: 0.9718 - val_loss: 9.9819 - val_accuracy: 0.9200
# Epoch 4/10
# 6/6 [==============================] - 19s 3s/step - loss: 1.0972 - accuracy: 0.9789 - val_loss: 5.1560 - val_accuracy: 0.8800
# Epoch 5/10
# 6/6 [==============================] - 19s 3s/step - loss: 0.5112 - accuracy: 0.9789 - val_loss: 5.1287 - val_accuracy: 0.8800
# Epoch 6/10
# 6/6 [==============================] - 17s 3s/step - loss: 0.3404 - accuracy: 0.9930 - val_loss: 19.2074 - val_accuracy: 0.8400
# Epoch 7/10
# 6/6 [==============================] - 17s 3s/step - loss: 0.7830 - accuracy: 0.9789 - val_loss: 19.6592 - val_accuracy: 0.8400
# Epoch 8/10
# 6/6 [==============================] - 17s 3s/step - loss: 0.3112 - accuracy: 0.9930 - val_loss: 3.8826 - val_accuracy: 0.9200
# Epoch 9/10
# 6/6 [==============================] - 20s 3s/step - loss: 0.6162 - accuracy: 0.9718 - val_loss: 10.1942 - val_accuracy: 0.8400
# Epoch 10/10
# 6/6 [==============================] - 18s 3s/step - loss: 4.1975e-09 - accuracy: 1.0000 - val_loss: 21.6255 - val_accuracy: 0.8800

# %%
y_test = np.empty(25)
for images, labels in test_ds.take(1):
    for i in range(25):
        y_test[i] = int(labels[i])

# %%
predictions = [np.argmax(pred) for pred in model_new.predict(test_ds)]
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
print(classification_report(y_test, predictions))
print(confusion_matrix(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.57      0.73         7
#          1.0       0.79      1.00      0.88        11
#          2.0       1.00      1.00      1.00         7
#
#     accuracy                           0.88        25
#    macro avg       0.93      0.86      0.87        25
# weighted avg       0.91      0.88      0.87        25
#
# [[ 4  3  0]
#  [ 0 11  0]
#  [ 0  0  7]]

# %% [markdown]
# ## InceptionV3

# %%
train_ds, test_ds = tf.keras.utils.image_dataset_from_directory(
    "../data/data 8.2", # путь к изображениям
    validation_split=0.15, # процент на тест
    subset="both", # берем и обучающую и тестовую выборку
    seed=42, # сид генератора случайных чисел
    image_size=(299,299), # целевой размер изображения (СНАЧАЛА ВЫСОТА, ПОТОМ ШИРИНА)
    batch_size=25, # размер пакета (батча)
)
# Out:
# Found 167 files belonging to 3 classes.
# Using 142 files for training.
# Using 25 files for validation.

# %%
data_augmentation = tf.keras.Sequential(
    [
        tf.keras.layers.RandomFlip("horizontal"),
        tf.keras.layers.RandomRotation(0.1),
    ]
)

# %%
train_ds = train_ds.map(
    lambda img, label: (data_augmentation(img), label)
)

# %%
plt.figure(figsize=(10, 10))
# берем один батч
for images, labels in train_ds.take(1):
    # отрисуем 9 картинок из батча
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        # выводим картинку
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(labels[i]))
        # выключаем оси (чтобы они не отображались)
        plt.axis("off")

# %%
inc = tf.keras.applications.InceptionV3(weights='imagenet', include_top=True)
inc.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 299, 299, 3)]        0         []
#
#  conv2d_97 (Conv2D)          (None, 149, 149, 32)         864       ['input_4[0][0]']
#
#  batch_normalization_94 (Ba  (None, 149, 149, 32)         96        ['conv2d_97[0][0]']
#  tchNormalization)
#
#  activation_94 (Activation)  (None, 149, 149, 32)         0         ['batch_normalization_94[0][0]
#                                                                     ']
#
#  conv2d_98 (Conv2D)          (None, 147, 147, 32)         9216      ['activation_94[0][0]']
#
#  batch_normalization_95 (Ba  (None, 147, 147, 32)         96        ['conv2d_98[0][0]']
#  tchNormalization)
#
#  activation_95 (Activation)  (None, 147, 147, 32)         0         ['batch_normalization_95[0][0]
#                                                                     ']
#
#  conv2d_99 (Conv2D)          (None, 147, 147, 64)         18432     ['activation_95[0][0]']
#
#  batch_normalization_96 (Ba  (None, 147, 147, 64)         192       ['conv2d_99[0][0]']
#  tchNormalization)
#
#  activation_96 (Activation)  (None, 147, 147, 64)         0         ['batch_normalization_96[0][0]
#                                                                     ']
#
#  max_pooling2d_7 (MaxPoolin  (None, 73, 73, 64)           0         ['activation_96[0][0]']
#  g2D)
#
#  conv2d_100 (Conv2D)         (None, 73, 73, 80)           5120      ['max_pooling2d_7[0][0]']
#
#  batch_normalization_97 (Ba  (None, 73, 73, 80)           240       ['conv2d_100[0][0]']
#  tchNormalization)
#
#  activation_97 (Activation)  (None, 73, 73, 80)           0         ['batch_normalization_97[0][0]
#                                                                     ']
#
#  conv2d_101 (Conv2D)         (None, 71, 71, 192)          138240    ['activation_97[0][0]']
#
#  batch_normalization_98 (Ba  (None, 71, 71, 192)          576       ['conv2d_101[0][0]']
#  tchNormalization)
#
#  activation_98 (Activation)  (None, 71, 71, 192)          0         ['batch_normalization_98[0][0]
#                                                                     ']
#
#  max_pooling2d_8 (MaxPoolin  (None, 35, 35, 192)          0         ['activation_98[0][0]']
#  g2D)
#
#  conv2d_105 (Conv2D)         (None, 35, 35, 64)           12288     ['max_pooling2d_8[0][0]']
#
#  batch_normalization_102 (B  (None, 35, 35, 64)           192       ['conv2d_105[0][0]']
#  atchNormalization)
#
#  activation_102 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_102[0][0
#  )                                                                  ]']
#
#  conv2d_103 (Conv2D)         (None, 35, 35, 48)           9216      ['max_pooling2d_8[0][0]']
#
#  conv2d_106 (Conv2D)         (None, 35, 35, 96)           55296     ['activation_102[0][0]']
#
#  batch_normalization_100 (B  (None, 35, 35, 48)           144       ['conv2d_103[0][0]']
#  atchNormalization)
#
#  batch_normalization_103 (B  (None, 35, 35, 96)           288       ['conv2d_106[0][0]']
#  atchNormalization)
#
#  activation_100 (Activation  (None, 35, 35, 48)           0         ['batch_normalization_100[0][0
#  )                                                                  ]']
#
#  activation_103 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_103[0][0
#  )                                                                  ]']
#
#  average_pooling2d_9 (Avera  (None, 35, 35, 192)          0         ['max_pooling2d_8[0][0]']
#  gePooling2D)
#
#  conv2d_102 (Conv2D)         (None, 35, 35, 64)           12288     ['max_pooling2d_8[0][0]']
#
#  conv2d_104 (Conv2D)         (None, 35, 35, 64)           76800     ['activation_100[0][0]']
#
#  conv2d_107 (Conv2D)         (None, 35, 35, 96)           82944     ['activation_103[0][0]']
#
#  conv2d_108 (Conv2D)         (None, 35, 35, 32)           6144      ['average_pooling2d_9[0][0]']
#
#  batch_normalization_99 (Ba  (None, 35, 35, 64)           192       ['conv2d_102[0][0]']
#  tchNormalization)
#
#  batch_normalization_101 (B  (None, 35, 35, 64)           192       ['conv2d_104[0][0]']
#  atchNormalization)
#
#  batch_normalization_104 (B  (None, 35, 35, 96)           288       ['conv2d_107[0][0]']
#  atchNormalization)
#
#  batch_normalization_105 (B  (None, 35, 35, 32)           96        ['conv2d_108[0][0]']
#  atchNormalization)
#
#  activation_99 (Activation)  (None, 35, 35, 64)           0         ['batch_normalization_99[0][0]
#                                                                     ']
#
#  activation_101 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_101[0][0
#  )                                                                  ]']
#
#  activation_104 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_104[0][0
#  )                                                                  ]']
#
#  activation_105 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_105[0][0
#  )                                                                  ]']
#
#  mixed0 (Concatenate)        (None, 35, 35, 256)          0         ['activation_99[0][0]',
#                                                                      'activation_101[0][0]',
#                                                                      'activation_104[0][0]',
#                                                                      'activation_105[0][0]']
#
#  conv2d_112 (Conv2D)         (None, 35, 35, 64)           16384     ['mixed0[0][0]']
#
#  batch_normalization_109 (B  (None, 35, 35, 64)           192       ['conv2d_112[0][0]']
#  atchNormalization)
#
#  activation_109 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_109[0][0
#  )                                                                  ]']
#
#  conv2d_110 (Conv2D)         (None, 35, 35, 48)           12288     ['mixed0[0][0]']
#
#  conv2d_113 (Conv2D)         (None, 35, 35, 96)           55296     ['activation_109[0][0]']
#
#  batch_normalization_107 (B  (None, 35, 35, 48)           144       ['conv2d_110[0][0]']
#  atchNormalization)
#
#  batch_normalization_110 (B  (None, 35, 35, 96)           288       ['conv2d_113[0][0]']
#  atchNormalization)
#
#  activation_107 (Activation  (None, 35, 35, 48)           0         ['batch_normalization_107[0][0
#  )                                                                  ]']
#
#  activation_110 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_110[0][0
#  )                                                                  ]']
#
#  average_pooling2d_10 (Aver  (None, 35, 35, 256)          0         ['mixed0[0][0]']
#  agePooling2D)
#
#  conv2d_109 (Conv2D)         (None, 35, 35, 64)           16384     ['mixed0[0][0]']
#
#  conv2d_111 (Conv2D)         (None, 35, 35, 64)           76800     ['activation_107[0][0]']
#
#  conv2d_114 (Conv2D)         (None, 35, 35, 96)           82944     ['activation_110[0][0]']
#
#  conv2d_115 (Conv2D)         (None, 35, 35, 64)           16384     ['average_pooling2d_10[0][0]']
#
#  batch_normalization_106 (B  (None, 35, 35, 64)           192       ['conv2d_109[0][0]']
#  atchNormalization)
#
#  batch_normalization_108 (B  (None, 35, 35, 64)           192       ['conv2d_111[0][0]']
#  atchNormalization)
#
#  batch_normalization_111 (B  (None, 35, 35, 96)           288       ['conv2d_114[0][0]']
#  atchNormalization)
#
#  batch_normalization_112 (B  (None, 35, 35, 64)           192       ['conv2d_115[0][0]']
#  atchNormalization)
#
#  activation_106 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_106[0][0
#  )                                                                  ]']
#
#  activation_108 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_108[0][0
#  )                                                                  ]']
#
#  activation_111 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_111[0][0
#  )                                                                  ]']
#
#  activation_112 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_112[0][0
#  )                                                                  ]']
#
#  mixed1 (Concatenate)        (None, 35, 35, 288)          0         ['activation_106[0][0]',
#                                                                      'activation_108[0][0]',
#                                                                      'activation_111[0][0]',
#                                                                      'activation_112[0][0]']
#
#  conv2d_119 (Conv2D)         (None, 35, 35, 64)           18432     ['mixed1[0][0]']
#
#  batch_normalization_116 (B  (None, 35, 35, 64)           192       ['conv2d_119[0][0]']
#  atchNormalization)
#
#  activation_116 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_116[0][0
#  )                                                                  ]']
#
#  conv2d_117 (Conv2D)         (None, 35, 35, 48)           13824     ['mixed1[0][0]']
#
#  conv2d_120 (Conv2D)         (None, 35, 35, 96)           55296     ['activation_116[0][0]']
#
#  batch_normalization_114 (B  (None, 35, 35, 48)           144       ['conv2d_117[0][0]']
#  atchNormalization)
#
#  batch_normalization_117 (B  (None, 35, 35, 96)           288       ['conv2d_120[0][0]']
#  atchNormalization)
#
#  activation_114 (Activation  (None, 35, 35, 48)           0         ['batch_normalization_114[0][0
#  )                                                                  ]']
#
#  activation_117 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_117[0][0
#  )                                                                  ]']
#
#  average_pooling2d_11 (Aver  (None, 35, 35, 288)          0         ['mixed1[0][0]']
#  agePooling2D)
#
#  conv2d_116 (Conv2D)         (None, 35, 35, 64)           18432     ['mixed1[0][0]']
#
#  conv2d_118 (Conv2D)         (None, 35, 35, 64)           76800     ['activation_114[0][0]']
#
#  conv2d_121 (Conv2D)         (None, 35, 35, 96)           82944     ['activation_117[0][0]']
#
#  conv2d_122 (Conv2D)         (None, 35, 35, 64)           18432     ['average_pooling2d_11[0][0]']
#
#  batch_normalization_113 (B  (None, 35, 35, 64)           192       ['conv2d_116[0][0]']
#  atchNormalization)
#
#  batch_normalization_115 (B  (None, 35, 35, 64)           192       ['conv2d_118[0][0]']
#  atchNormalization)
#
#  batch_normalization_118 (B  (None, 35, 35, 96)           288       ['conv2d_121[0][0]']
#  atchNormalization)
#
#  batch_normalization_119 (B  (None, 35, 35, 64)           192       ['conv2d_122[0][0]']
#  atchNormalization)
#
#  activation_113 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_113[0][0
#  )                                                                  ]']
#
#  activation_115 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_115[0][0
#  )                                                                  ]']
#
#  activation_118 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_118[0][0
#  )                                                                  ]']
#
#  activation_119 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_119[0][0
#  )                                                                  ]']
#
#  mixed2 (Concatenate)        (None, 35, 35, 288)          0         ['activation_113[0][0]',
#                                                                      'activation_115[0][0]',
#                                                                      'activation_118[0][0]',
#                                                                      'activation_119[0][0]']
#
#  conv2d_124 (Conv2D)         (None, 35, 35, 64)           18432     ['mixed2[0][0]']
#
#  batch_normalization_121 (B  (None, 35, 35, 64)           192       ['conv2d_124[0][0]']
#  atchNormalization)
#
#  activation_121 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_121[0][0
#  )                                                                  ]']
#
#  conv2d_125 (Conv2D)         (None, 35, 35, 96)           55296     ['activation_121[0][0]']
#
#  batch_normalization_122 (B  (None, 35, 35, 96)           288       ['conv2d_125[0][0]']
#  atchNormalization)
#
#  activation_122 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_122[0][0
#  )                                                                  ]']
#
#  conv2d_123 (Conv2D)         (None, 17, 17, 384)          995328    ['mixed2[0][0]']
#
#  conv2d_126 (Conv2D)         (None, 17, 17, 96)           82944     ['activation_122[0][0]']
#
#  batch_normalization_120 (B  (None, 17, 17, 384)          1152      ['conv2d_123[0][0]']
#  atchNormalization)
#
#  batch_normalization_123 (B  (None, 17, 17, 96)           288       ['conv2d_126[0][0]']
#  atchNormalization)
#
#  activation_120 (Activation  (None, 17, 17, 384)          0         ['batch_normalization_120[0][0
#  )                                                                  ]']
#
#  activation_123 (Activation  (None, 17, 17, 96)           0         ['batch_normalization_123[0][0
#  )                                                                  ]']
#
#  max_pooling2d_9 (MaxPoolin  (None, 17, 17, 288)          0         ['mixed2[0][0]']
#  g2D)
#
#  mixed3 (Concatenate)        (None, 17, 17, 768)          0         ['activation_120[0][0]',
#                                                                      'activation_123[0][0]',
#                                                                      'max_pooling2d_9[0][0]']
#
#  conv2d_131 (Conv2D)         (None, 17, 17, 128)          98304     ['mixed3[0][0]']
#
#  batch_normalization_128 (B  (None, 17, 17, 128)          384       ['conv2d_131[0][0]']
#  atchNormalization)
#
#  activation_128 (Activation  (None, 17, 17, 128)          0         ['batch_normalization_128[0][0
#  )                                                                  ]']
#
#  conv2d_132 (Conv2D)         (None, 17, 17, 128)          114688    ['activation_128[0][0]']
#
#  batch_normalization_129 (B  (None, 17, 17, 128)          384       ['conv2d_132[0][0]']
#  atchNormalization)
#
#  activation_129 (Activation  (None, 17, 17, 128)          0         ['batch_normalization_129[0][0
#  )                                                                  ]']
#
#  conv2d_128 (Conv2D)         (None, 17, 17, 128)          98304     ['mixed3[0][0]']
#
#  conv2d_133 (Conv2D)         (None, 17, 17, 128)          114688    ['activation_129[0][0]']
#
#  batch_normalization_125 (B  (None, 17, 17, 128)          384       ['conv2d_128[0][0]']
#  atchNormalization)
#
#  batch_normalization_130 (B  (None, 17, 17, 128)          384       ['conv2d_133[0][0]']
#  atchNormalization)
#
#  activation_125 (Activation  (None, 17, 17, 128)          0         ['batch_normalization_125[0][0
#  )                                                                  ]']
#
#  activation_130 (Activation  (None, 17, 17, 128)          0         ['batch_normalization_130[0][0
#  )                                                                  ]']
#
#  conv2d_129 (Conv2D)         (None, 17, 17, 128)          114688    ['activation_125[0][0]']
#
#  conv2d_134 (Conv2D)         (None, 17, 17, 128)          114688    ['activation_130[0][0]']
#
#  batch_normalization_126 (B  (None, 17, 17, 128)          384       ['conv2d_129[0][0]']
#  atchNormalization)
#
#  batch_normalization_131 (B  (None, 17, 17, 128)          384       ['conv2d_134[0][0]']
#  atchNormalization)
#
#  activation_126 (Activation  (None, 17, 17, 128)          0         ['batch_normalization_126[0][0
#  )                                                                  ]']
#
#  activation_131 (Activation  (None, 17, 17, 128)          0         ['batch_normalization_131[0][0
#  )                                                                  ]']
#
#  average_pooling2d_12 (Aver  (None, 17, 17, 768)          0         ['mixed3[0][0]']
#  agePooling2D)
#
#  conv2d_127 (Conv2D)         (None, 17, 17, 192)          147456    ['mixed3[0][0]']
#
#  conv2d_130 (Conv2D)         (None, 17, 17, 192)          172032    ['activation_126[0][0]']
#
#  conv2d_135 (Conv2D)         (None, 17, 17, 192)          172032    ['activation_131[0][0]']
#
#  conv2d_136 (Conv2D)         (None, 17, 17, 192)          147456    ['average_pooling2d_12[0][0]']
#
#  batch_normalization_124 (B  (None, 17, 17, 192)          576       ['conv2d_127[0][0]']
#  atchNormalization)
#
#  batch_normalization_127 (B  (None, 17, 17, 192)          576       ['conv2d_130[0][0]']
#  atchNormalization)
#
#  batch_normalization_132 (B  (None, 17, 17, 192)          576       ['conv2d_135[0][0]']
#  atchNormalization)
#
#  batch_normalization_133 (B  (None, 17, 17, 192)          576       ['conv2d_136[0][0]']
#  atchNormalization)
#
#  activation_124 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_124[0][0
#  )                                                                  ]']
#
#  activation_127 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_127[0][0
#  )                                                                  ]']
#
#  activation_132 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_132[0][0
#  )                                                                  ]']
#
#  activation_133 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_133[0][0
#  )                                                                  ]']
#
#  mixed4 (Concatenate)        (None, 17, 17, 768)          0         ['activation_124[0][0]',
#                                                                      'activation_127[0][0]',
#                                                                      'activation_132[0][0]',
#                                                                      'activation_133[0][0]']
#
#  conv2d_141 (Conv2D)         (None, 17, 17, 160)          122880    ['mixed4[0][0]']
#
#  batch_normalization_138 (B  (None, 17, 17, 160)          480       ['conv2d_141[0][0]']
#  atchNormalization)
#
#  activation_138 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_138[0][0
#  )                                                                  ]']
#
#  conv2d_142 (Conv2D)         (None, 17, 17, 160)          179200    ['activation_138[0][0]']
#
#  batch_normalization_139 (B  (None, 17, 17, 160)          480       ['conv2d_142[0][0]']
#  atchNormalization)
#
#  activation_139 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_139[0][0
#  )                                                                  ]']
#
#  conv2d_138 (Conv2D)         (None, 17, 17, 160)          122880    ['mixed4[0][0]']
#
#  conv2d_143 (Conv2D)         (None, 17, 17, 160)          179200    ['activation_139[0][0]']
#
#  batch_normalization_135 (B  (None, 17, 17, 160)          480       ['conv2d_138[0][0]']
#  atchNormalization)
#
#  batch_normalization_140 (B  (None, 17, 17, 160)          480       ['conv2d_143[0][0]']
#  atchNormalization)
#
#  activation_135 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_135[0][0
#  )                                                                  ]']
#
#  activation_140 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_140[0][0
#  )                                                                  ]']
#
#  conv2d_139 (Conv2D)         (None, 17, 17, 160)          179200    ['activation_135[0][0]']
#
#  conv2d_144 (Conv2D)         (None, 17, 17, 160)          179200    ['activation_140[0][0]']
#
#  batch_normalization_136 (B  (None, 17, 17, 160)          480       ['conv2d_139[0][0]']
#  atchNormalization)
#
#  batch_normalization_141 (B  (None, 17, 17, 160)          480       ['conv2d_144[0][0]']
#  atchNormalization)
#
#  activation_136 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_136[0][0
#  )                                                                  ]']
#
#  activation_141 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_141[0][0
#  )                                                                  ]']
#
#  average_pooling2d_13 (Aver  (None, 17, 17, 768)          0         ['mixed4[0][0]']
#  agePooling2D)
#
#  conv2d_137 (Conv2D)         (None, 17, 17, 192)          147456    ['mixed4[0][0]']
#
#  conv2d_140 (Conv2D)         (None, 17, 17, 192)          215040    ['activation_136[0][0]']
#
#  conv2d_145 (Conv2D)         (None, 17, 17, 192)          215040    ['activation_141[0][0]']
#
#  conv2d_146 (Conv2D)         (None, 17, 17, 192)          147456    ['average_pooling2d_13[0][0]']
#
#  batch_normalization_134 (B  (None, 17, 17, 192)          576       ['conv2d_137[0][0]']
#  atchNormalization)
#
#  batch_normalization_137 (B  (None, 17, 17, 192)          576       ['conv2d_140[0][0]']
#  atchNormalization)
#
#  batch_normalization_142 (B  (None, 17, 17, 192)          576       ['conv2d_145[0][0]']
#  atchNormalization)
#
#  batch_normalization_143 (B  (None, 17, 17, 192)          576       ['conv2d_146[0][0]']
#  atchNormalization)
#
#  activation_134 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_134[0][0
#  )                                                                  ]']
#
#  activation_137 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_137[0][0
#  )                                                                  ]']
#
#  activation_142 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_142[0][0
#  )                                                                  ]']
#
#  activation_143 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_143[0][0
#  )                                                                  ]']
#
#  mixed5 (Concatenate)        (None, 17, 17, 768)          0         ['activation_134[0][0]',
#                                                                      'activation_137[0][0]',
#                                                                      'activation_142[0][0]',
#                                                                      'activation_143[0][0]']
#
#  conv2d_151 (Conv2D)         (None, 17, 17, 160)          122880    ['mixed5[0][0]']
#
#  batch_normalization_148 (B  (None, 17, 17, 160)          480       ['conv2d_151[0][0]']
#  atchNormalization)
#
#  activation_148 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_148[0][0
#  )                                                                  ]']
#
#  conv2d_152 (Conv2D)         (None, 17, 17, 160)          179200    ['activation_148[0][0]']
#
#  batch_normalization_149 (B  (None, 17, 17, 160)          480       ['conv2d_152[0][0]']
#  atchNormalization)
#
#  activation_149 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_149[0][0
#  )                                                                  ]']
#
#  conv2d_148 (Conv2D)         (None, 17, 17, 160)          122880    ['mixed5[0][0]']
#
#  conv2d_153 (Conv2D)         (None, 17, 17, 160)          179200    ['activation_149[0][0]']
#
#  batch_normalization_145 (B  (None, 17, 17, 160)          480       ['conv2d_148[0][0]']
#  atchNormalization)
#
#  batch_normalization_150 (B  (None, 17, 17, 160)          480       ['conv2d_153[0][0]']
#  atchNormalization)
#
# ...
#  )                                                                  ]']
#
#  activation_175 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_175[0][0
#  )                                                                  ]']
#
#  conv2d_175 (Conv2D)         (None, 8, 8, 384)            442368    ['activation_171[0][0]']
#
#  conv2d_176 (Conv2D)         (None, 8, 8, 384)            442368    ['activation_171[0][0]']
#
#  conv2d_179 (Conv2D)         (None, 8, 8, 384)            442368    ['activation_175[0][0]']
#
#  conv2d_180 (Conv2D)         (None, 8, 8, 384)            442368    ['activation_175[0][0]']
#
#  average_pooling2d_16 (Aver  (None, 8, 8, 1280)           0         ['mixed8[0][0]']
#  agePooling2D)
#
#  conv2d_173 (Conv2D)         (None, 8, 8, 320)            409600    ['mixed8[0][0]']
#
#  batch_normalization_172 (B  (None, 8, 8, 384)            1152      ['conv2d_175[0][0]']
#  atchNormalization)
#
#  batch_normalization_173 (B  (None, 8, 8, 384)            1152      ['conv2d_176[0][0]']
#  atchNormalization)
#
#  batch_normalization_176 (B  (None, 8, 8, 384)            1152      ['conv2d_179[0][0]']
#  atchNormalization)
#
#  batch_normalization_177 (B  (None, 8, 8, 384)            1152      ['conv2d_180[0][0]']
#  atchNormalization)
#
#  conv2d_181 (Conv2D)         (None, 8, 8, 192)            245760    ['average_pooling2d_16[0][0]']
#
#  batch_normalization_170 (B  (None, 8, 8, 320)            960       ['conv2d_173[0][0]']
#  atchNormalization)
#
#  activation_172 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_172[0][0
#  )                                                                  ]']
#
#  activation_173 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_173[0][0
#  )                                                                  ]']
#
#  activation_176 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_176[0][0
#  )                                                                  ]']
#
#  activation_177 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_177[0][0
#  )                                                                  ]']
#
#  batch_normalization_178 (B  (None, 8, 8, 192)            576       ['conv2d_181[0][0]']
#  atchNormalization)
#
#  activation_170 (Activation  (None, 8, 8, 320)            0         ['batch_normalization_170[0][0
#  )                                                                  ]']
#
#  mixed9_0 (Concatenate)      (None, 8, 8, 768)            0         ['activation_172[0][0]',
#                                                                      'activation_173[0][0]']
#
#  concatenate_2 (Concatenate  (None, 8, 8, 768)            0         ['activation_176[0][0]',
#  )                                                                   'activation_177[0][0]']
#
#  activation_178 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_178[0][0
#  )                                                                  ]']
#
#  mixed9 (Concatenate)        (None, 8, 8, 2048)           0         ['activation_170[0][0]',
#                                                                      'mixed9_0[0][0]',
#                                                                      'concatenate_2[0][0]',
#                                                                      'activation_178[0][0]']
#
#  conv2d_186 (Conv2D)         (None, 8, 8, 448)            917504    ['mixed9[0][0]']
#
#  batch_normalization_183 (B  (None, 8, 8, 448)            1344      ['conv2d_186[0][0]']
#  atchNormalization)
#
#  activation_183 (Activation  (None, 8, 8, 448)            0         ['batch_normalization_183[0][0
#  )                                                                  ]']
#
#  conv2d_183 (Conv2D)         (None, 8, 8, 384)            786432    ['mixed9[0][0]']
#
#  conv2d_187 (Conv2D)         (None, 8, 8, 384)            1548288   ['activation_183[0][0]']
#
#  batch_normalization_180 (B  (None, 8, 8, 384)            1152      ['conv2d_183[0][0]']
#  atchNormalization)
#
#  batch_normalization_184 (B  (None, 8, 8, 384)            1152      ['conv2d_187[0][0]']
#  atchNormalization)
#
#  activation_180 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_180[0][0
#  )                                                                  ]']
#
#  activation_184 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_184[0][0
#  )                                                                  ]']
#
#  conv2d_184 (Conv2D)         (None, 8, 8, 384)            442368    ['activation_180[0][0]']
#
#  conv2d_185 (Conv2D)         (None, 8, 8, 384)            442368    ['activation_180[0][0]']
#
#  conv2d_188 (Conv2D)         (None, 8, 8, 384)            442368    ['activation_184[0][0]']
#
#  conv2d_189 (Conv2D)         (None, 8, 8, 384)            442368    ['activation_184[0][0]']
#
#  average_pooling2d_17 (Aver  (None, 8, 8, 2048)           0         ['mixed9[0][0]']
#  agePooling2D)
#
#  conv2d_182 (Conv2D)         (None, 8, 8, 320)            655360    ['mixed9[0][0]']
#
#  batch_normalization_181 (B  (None, 8, 8, 384)            1152      ['conv2d_184[0][0]']
#  atchNormalization)
#
#  batch_normalization_182 (B  (None, 8, 8, 384)            1152      ['conv2d_185[0][0]']
#  atchNormalization)
#
#  batch_normalization_185 (B  (None, 8, 8, 384)            1152      ['conv2d_188[0][0]']
#  atchNormalization)
#
#  batch_normalization_186 (B  (None, 8, 8, 384)            1152      ['conv2d_189[0][0]']
#  atchNormalization)
#
#  conv2d_190 (Conv2D)         (None, 8, 8, 192)            393216    ['average_pooling2d_17[0][0]']
#
#  batch_normalization_179 (B  (None, 8, 8, 320)            960       ['conv2d_182[0][0]']
#  atchNormalization)
#
#  activation_181 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_181[0][0
#  )                                                                  ]']
#
#  activation_182 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_182[0][0
#  )                                                                  ]']
#
#  activation_185 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_185[0][0
#  )                                                                  ]']
#
#  activation_186 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_186[0][0
#  )                                                                  ]']
#
#  batch_normalization_187 (B  (None, 8, 8, 192)            576       ['conv2d_190[0][0]']
#  atchNormalization)
#
#  activation_179 (Activation  (None, 8, 8, 320)            0         ['batch_normalization_179[0][0
#  )                                                                  ]']
#
#  mixed9_1 (Concatenate)      (None, 8, 8, 768)            0         ['activation_181[0][0]',
#                                                                      'activation_182[0][0]']
#
#  concatenate_3 (Concatenate  (None, 8, 8, 768)            0         ['activation_185[0][0]',
#  )                                                                   'activation_186[0][0]']
#
#  activation_187 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_187[0][0
#  )                                                                  ]']
#
#  mixed10 (Concatenate)       (None, 8, 8, 2048)           0         ['activation_179[0][0]',
#                                                                      'mixed9_1[0][0]',
#                                                                      'concatenate_3[0][0]',
#                                                                      'activation_187[0][0]']
#
#  avg_pool (GlobalAveragePoo  (None, 2048)                 0         ['mixed10[0][0]']
#  ling2D)
#
#  predictions (Dense)         (None, 1000)                 2049000   ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 23851784 (90.99 MB)
# Trainable params: 23817352 (90.86 MB)
# Non-trainable params: 34432 (134.50 KB)
# __________________________________________________________________________________________________

# %%
# сохраним ссылку на входной слой сети
inp = inc.input

# создадим новый слой классификации по нашему количеству классов
new_classification_layer = tf.keras.layers.Dense(3, activation='softmax')

# соединим предпоследний слой и наш новый слой классификации
out = new_classification_layer(inc.layers[-2].output)

# создадим новую модель
model_new2 = tf.keras.Model(inp, out)

# %%
model_new2.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 299, 299, 3)]        0         []
#
#  conv2d_97 (Conv2D)          (None, 149, 149, 32)         864       ['input_4[0][0]']
#
#  batch_normalization_94 (Ba  (None, 149, 149, 32)         96        ['conv2d_97[0][0]']
#  tchNormalization)
#
#  activation_94 (Activation)  (None, 149, 149, 32)         0         ['batch_normalization_94[0][0]
#                                                                     ']
#
#  conv2d_98 (Conv2D)          (None, 147, 147, 32)         9216      ['activation_94[0][0]']
#
#  batch_normalization_95 (Ba  (None, 147, 147, 32)         96        ['conv2d_98[0][0]']
#  tchNormalization)
#
#  activation_95 (Activation)  (None, 147, 147, 32)         0         ['batch_normalization_95[0][0]
#                                                                     ']
#
#  conv2d_99 (Conv2D)          (None, 147, 147, 64)         18432     ['activation_95[0][0]']
#
#  batch_normalization_96 (Ba  (None, 147, 147, 64)         192       ['conv2d_99[0][0]']
#  tchNormalization)
#
#  activation_96 (Activation)  (None, 147, 147, 64)         0         ['batch_normalization_96[0][0]
#                                                                     ']
#
#  max_pooling2d_7 (MaxPoolin  (None, 73, 73, 64)           0         ['activation_96[0][0]']
#  g2D)
#
#  conv2d_100 (Conv2D)         (None, 73, 73, 80)           5120      ['max_pooling2d_7[0][0]']
#
#  batch_normalization_97 (Ba  (None, 73, 73, 80)           240       ['conv2d_100[0][0]']
#  tchNormalization)
#
#  activation_97 (Activation)  (None, 73, 73, 80)           0         ['batch_normalization_97[0][0]
#                                                                     ']
#
#  conv2d_101 (Conv2D)         (None, 71, 71, 192)          138240    ['activation_97[0][0]']
#
#  batch_normalization_98 (Ba  (None, 71, 71, 192)          576       ['conv2d_101[0][0]']
#  tchNormalization)
#
#  activation_98 (Activation)  (None, 71, 71, 192)          0         ['batch_normalization_98[0][0]
#                                                                     ']
#
#  max_pooling2d_8 (MaxPoolin  (None, 35, 35, 192)          0         ['activation_98[0][0]']
#  g2D)
#
#  conv2d_105 (Conv2D)         (None, 35, 35, 64)           12288     ['max_pooling2d_8[0][0]']
#
#  batch_normalization_102 (B  (None, 35, 35, 64)           192       ['conv2d_105[0][0]']
#  atchNormalization)
#
#  activation_102 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_102[0][0
#  )                                                                  ]']
#
#  conv2d_103 (Conv2D)         (None, 35, 35, 48)           9216      ['max_pooling2d_8[0][0]']
#
#  conv2d_106 (Conv2D)         (None, 35, 35, 96)           55296     ['activation_102[0][0]']
#
#  batch_normalization_100 (B  (None, 35, 35, 48)           144       ['conv2d_103[0][0]']
#  atchNormalization)
#
#  batch_normalization_103 (B  (None, 35, 35, 96)           288       ['conv2d_106[0][0]']
#  atchNormalization)
#
#  activation_100 (Activation  (None, 35, 35, 48)           0         ['batch_normalization_100[0][0
#  )                                                                  ]']
#
#  activation_103 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_103[0][0
#  )                                                                  ]']
#
#  average_pooling2d_9 (Avera  (None, 35, 35, 192)          0         ['max_pooling2d_8[0][0]']
#  gePooling2D)
#
#  conv2d_102 (Conv2D)         (None, 35, 35, 64)           12288     ['max_pooling2d_8[0][0]']
#
#  conv2d_104 (Conv2D)         (None, 35, 35, 64)           76800     ['activation_100[0][0]']
#
#  conv2d_107 (Conv2D)         (None, 35, 35, 96)           82944     ['activation_103[0][0]']
#
#  conv2d_108 (Conv2D)         (None, 35, 35, 32)           6144      ['average_pooling2d_9[0][0]']
#
#  batch_normalization_99 (Ba  (None, 35, 35, 64)           192       ['conv2d_102[0][0]']
#  tchNormalization)
#
#  batch_normalization_101 (B  (None, 35, 35, 64)           192       ['conv2d_104[0][0]']
#  atchNormalization)
#
#  batch_normalization_104 (B  (None, 35, 35, 96)           288       ['conv2d_107[0][0]']
#  atchNormalization)
#
#  batch_normalization_105 (B  (None, 35, 35, 32)           96        ['conv2d_108[0][0]']
#  atchNormalization)
#
#  activation_99 (Activation)  (None, 35, 35, 64)           0         ['batch_normalization_99[0][0]
#                                                                     ']
#
#  activation_101 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_101[0][0
#  )                                                                  ]']
#
#  activation_104 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_104[0][0
#  )                                                                  ]']
#
#  activation_105 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_105[0][0
#  )                                                                  ]']
#
#  mixed0 (Concatenate)        (None, 35, 35, 256)          0         ['activation_99[0][0]',
#                                                                      'activation_101[0][0]',
#                                                                      'activation_104[0][0]',
#                                                                      'activation_105[0][0]']
#
#  conv2d_112 (Conv2D)         (None, 35, 35, 64)           16384     ['mixed0[0][0]']
#
#  batch_normalization_109 (B  (None, 35, 35, 64)           192       ['conv2d_112[0][0]']
#  atchNormalization)
#
#  activation_109 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_109[0][0
#  )                                                                  ]']
#
#  conv2d_110 (Conv2D)         (None, 35, 35, 48)           12288     ['mixed0[0][0]']
#
#  conv2d_113 (Conv2D)         (None, 35, 35, 96)           55296     ['activation_109[0][0]']
#
#  batch_normalization_107 (B  (None, 35, 35, 48)           144       ['conv2d_110[0][0]']
#  atchNormalization)
#
#  batch_normalization_110 (B  (None, 35, 35, 96)           288       ['conv2d_113[0][0]']
#  atchNormalization)
#
#  activation_107 (Activation  (None, 35, 35, 48)           0         ['batch_normalization_107[0][0
#  )                                                                  ]']
#
#  activation_110 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_110[0][0
#  )                                                                  ]']
#
#  average_pooling2d_10 (Aver  (None, 35, 35, 256)          0         ['mixed0[0][0]']
#  agePooling2D)
#
#  conv2d_109 (Conv2D)         (None, 35, 35, 64)           16384     ['mixed0[0][0]']
#
#  conv2d_111 (Conv2D)         (None, 35, 35, 64)           76800     ['activation_107[0][0]']
#
#  conv2d_114 (Conv2D)         (None, 35, 35, 96)           82944     ['activation_110[0][0]']
#
#  conv2d_115 (Conv2D)         (None, 35, 35, 64)           16384     ['average_pooling2d_10[0][0]']
#
#  batch_normalization_106 (B  (None, 35, 35, 64)           192       ['conv2d_109[0][0]']
#  atchNormalization)
#
#  batch_normalization_108 (B  (None, 35, 35, 64)           192       ['conv2d_111[0][0]']
#  atchNormalization)
#
#  batch_normalization_111 (B  (None, 35, 35, 96)           288       ['conv2d_114[0][0]']
#  atchNormalization)
#
#  batch_normalization_112 (B  (None, 35, 35, 64)           192       ['conv2d_115[0][0]']
#  atchNormalization)
#
#  activation_106 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_106[0][0
#  )                                                                  ]']
#
#  activation_108 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_108[0][0
#  )                                                                  ]']
#
#  activation_111 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_111[0][0
#  )                                                                  ]']
#
#  activation_112 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_112[0][0
#  )                                                                  ]']
#
#  mixed1 (Concatenate)        (None, 35, 35, 288)          0         ['activation_106[0][0]',
#                                                                      'activation_108[0][0]',
#                                                                      'activation_111[0][0]',
#                                                                      'activation_112[0][0]']
#
#  conv2d_119 (Conv2D)         (None, 35, 35, 64)           18432     ['mixed1[0][0]']
#
#  batch_normalization_116 (B  (None, 35, 35, 64)           192       ['conv2d_119[0][0]']
#  atchNormalization)
#
#  activation_116 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_116[0][0
#  )                                                                  ]']
#
#  conv2d_117 (Conv2D)         (None, 35, 35, 48)           13824     ['mixed1[0][0]']
#
#  conv2d_120 (Conv2D)         (None, 35, 35, 96)           55296     ['activation_116[0][0]']
#
#  batch_normalization_114 (B  (None, 35, 35, 48)           144       ['conv2d_117[0][0]']
#  atchNormalization)
#
#  batch_normalization_117 (B  (None, 35, 35, 96)           288       ['conv2d_120[0][0]']
#  atchNormalization)
#
#  activation_114 (Activation  (None, 35, 35, 48)           0         ['batch_normalization_114[0][0
#  )                                                                  ]']
#
#  activation_117 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_117[0][0
#  )                                                                  ]']
#
#  average_pooling2d_11 (Aver  (None, 35, 35, 288)          0         ['mixed1[0][0]']
#  agePooling2D)
#
#  conv2d_116 (Conv2D)         (None, 35, 35, 64)           18432     ['mixed1[0][0]']
#
#  conv2d_118 (Conv2D)         (None, 35, 35, 64)           76800     ['activation_114[0][0]']
#
#  conv2d_121 (Conv2D)         (None, 35, 35, 96)           82944     ['activation_117[0][0]']
#
#  conv2d_122 (Conv2D)         (None, 35, 35, 64)           18432     ['average_pooling2d_11[0][0]']
#
#  batch_normalization_113 (B  (None, 35, 35, 64)           192       ['conv2d_116[0][0]']
#  atchNormalization)
#
#  batch_normalization_115 (B  (None, 35, 35, 64)           192       ['conv2d_118[0][0]']
#  atchNormalization)
#
#  batch_normalization_118 (B  (None, 35, 35, 96)           288       ['conv2d_121[0][0]']
#  atchNormalization)
#
#  batch_normalization_119 (B  (None, 35, 35, 64)           192       ['conv2d_122[0][0]']
#  atchNormalization)
#
#  activation_113 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_113[0][0
#  )                                                                  ]']
#
#  activation_115 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_115[0][0
#  )                                                                  ]']
#
#  activation_118 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_118[0][0
#  )                                                                  ]']
#
#  activation_119 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_119[0][0
#  )                                                                  ]']
#
#  mixed2 (Concatenate)        (None, 35, 35, 288)          0         ['activation_113[0][0]',
#                                                                      'activation_115[0][0]',
#                                                                      'activation_118[0][0]',
#                                                                      'activation_119[0][0]']
#
#  conv2d_124 (Conv2D)         (None, 35, 35, 64)           18432     ['mixed2[0][0]']
#
#  batch_normalization_121 (B  (None, 35, 35, 64)           192       ['conv2d_124[0][0]']
#  atchNormalization)
#
#  activation_121 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_121[0][0
#  )                                                                  ]']
#
#  conv2d_125 (Conv2D)         (None, 35, 35, 96)           55296     ['activation_121[0][0]']
#
#  batch_normalization_122 (B  (None, 35, 35, 96)           288       ['conv2d_125[0][0]']
#  atchNormalization)
#
#  activation_122 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_122[0][0
#  )                                                                  ]']
#
#  conv2d_123 (Conv2D)         (None, 17, 17, 384)          995328    ['mixed2[0][0]']
#
#  conv2d_126 (Conv2D)         (None, 17, 17, 96)           82944     ['activation_122[0][0]']
#
#  batch_normalization_120 (B  (None, 17, 17, 384)          1152      ['conv2d_123[0][0]']
#  atchNormalization)
#
#  batch_normalization_123 (B  (None, 17, 17, 96)           288       ['conv2d_126[0][0]']
#  atchNormalization)
#
#  activation_120 (Activation  (None, 17, 17, 384)          0         ['batch_normalization_120[0][0
#  )                                                                  ]']
#
#  activation_123 (Activation  (None, 17, 17, 96)           0         ['batch_normalization_123[0][0
#  )                                                                  ]']
#
#  max_pooling2d_9 (MaxPoolin  (None, 17, 17, 288)          0         ['mixed2[0][0]']
#  g2D)
#
#  mixed3 (Concatenate)        (None, 17, 17, 768)          0         ['activation_120[0][0]',
#                                                                      'activation_123[0][0]',
#                                                                      'max_pooling2d_9[0][0]']
#
#  conv2d_131 (Conv2D)         (None, 17, 17, 128)          98304     ['mixed3[0][0]']
#
#  batch_normalization_128 (B  (None, 17, 17, 128)          384       ['conv2d_131[0][0]']
#  atchNormalization)
#
#  activation_128 (Activation  (None, 17, 17, 128)          0         ['batch_normalization_128[0][0
#  )                                                                  ]']
#
#  conv2d_132 (Conv2D)         (None, 17, 17, 128)          114688    ['activation_128[0][0]']
#
#  batch_normalization_129 (B  (None, 17, 17, 128)          384       ['conv2d_132[0][0]']
#  atchNormalization)
#
#  activation_129 (Activation  (None, 17, 17, 128)          0         ['batch_normalization_129[0][0
#  )                                                                  ]']
#
#  conv2d_128 (Conv2D)         (None, 17, 17, 128)          98304     ['mixed3[0][0]']
#
#  conv2d_133 (Conv2D)         (None, 17, 17, 128)          114688    ['activation_129[0][0]']
#
#  batch_normalization_125 (B  (None, 17, 17, 128)          384       ['conv2d_128[0][0]']
#  atchNormalization)
#
#  batch_normalization_130 (B  (None, 17, 17, 128)          384       ['conv2d_133[0][0]']
#  atchNormalization)
#
#  activation_125 (Activation  (None, 17, 17, 128)          0         ['batch_normalization_125[0][0
#  )                                                                  ]']
#
#  activation_130 (Activation  (None, 17, 17, 128)          0         ['batch_normalization_130[0][0
#  )                                                                  ]']
#
#  conv2d_129 (Conv2D)         (None, 17, 17, 128)          114688    ['activation_125[0][0]']
#
#  conv2d_134 (Conv2D)         (None, 17, 17, 128)          114688    ['activation_130[0][0]']
#
#  batch_normalization_126 (B  (None, 17, 17, 128)          384       ['conv2d_129[0][0]']
#  atchNormalization)
#
#  batch_normalization_131 (B  (None, 17, 17, 128)          384       ['conv2d_134[0][0]']
#  atchNormalization)
#
#  activation_126 (Activation  (None, 17, 17, 128)          0         ['batch_normalization_126[0][0
#  )                                                                  ]']
#
#  activation_131 (Activation  (None, 17, 17, 128)          0         ['batch_normalization_131[0][0
#  )                                                                  ]']
#
#  average_pooling2d_12 (Aver  (None, 17, 17, 768)          0         ['mixed3[0][0]']
#  agePooling2D)
#
#  conv2d_127 (Conv2D)         (None, 17, 17, 192)          147456    ['mixed3[0][0]']
#
#  conv2d_130 (Conv2D)         (None, 17, 17, 192)          172032    ['activation_126[0][0]']
#
#  conv2d_135 (Conv2D)         (None, 17, 17, 192)          172032    ['activation_131[0][0]']
#
#  conv2d_136 (Conv2D)         (None, 17, 17, 192)          147456    ['average_pooling2d_12[0][0]']
#
#  batch_normalization_124 (B  (None, 17, 17, 192)          576       ['conv2d_127[0][0]']
#  atchNormalization)
#
#  batch_normalization_127 (B  (None, 17, 17, 192)          576       ['conv2d_130[0][0]']
#  atchNormalization)
#
#  batch_normalization_132 (B  (None, 17, 17, 192)          576       ['conv2d_135[0][0]']
#  atchNormalization)
#
#  batch_normalization_133 (B  (None, 17, 17, 192)          576       ['conv2d_136[0][0]']
#  atchNormalization)
#
#  activation_124 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_124[0][0
#  )                                                                  ]']
#
#  activation_127 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_127[0][0
#  )                                                                  ]']
#
#  activation_132 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_132[0][0
#  )                                                                  ]']
#
#  activation_133 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_133[0][0
#  )                                                                  ]']
#
#  mixed4 (Concatenate)        (None, 17, 17, 768)          0         ['activation_124[0][0]',
#                                                                      'activation_127[0][0]',
#                                                                      'activation_132[0][0]',
#                                                                      'activation_133[0][0]']
#
#  conv2d_141 (Conv2D)         (None, 17, 17, 160)          122880    ['mixed4[0][0]']
#
#  batch_normalization_138 (B  (None, 17, 17, 160)          480       ['conv2d_141[0][0]']
#  atchNormalization)
#
#  activation_138 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_138[0][0
#  )                                                                  ]']
#
#  conv2d_142 (Conv2D)         (None, 17, 17, 160)          179200    ['activation_138[0][0]']
#
#  batch_normalization_139 (B  (None, 17, 17, 160)          480       ['conv2d_142[0][0]']
#  atchNormalization)
#
#  activation_139 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_139[0][0
#  )                                                                  ]']
#
#  conv2d_138 (Conv2D)         (None, 17, 17, 160)          122880    ['mixed4[0][0]']
#
#  conv2d_143 (Conv2D)         (None, 17, 17, 160)          179200    ['activation_139[0][0]']
#
#  batch_normalization_135 (B  (None, 17, 17, 160)          480       ['conv2d_138[0][0]']
#  atchNormalization)
#
#  batch_normalization_140 (B  (None, 17, 17, 160)          480       ['conv2d_143[0][0]']
#  atchNormalization)
#
#  activation_135 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_135[0][0
#  )                                                                  ]']
#
#  activation_140 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_140[0][0
#  )                                                                  ]']
#
#  conv2d_139 (Conv2D)         (None, 17, 17, 160)          179200    ['activation_135[0][0]']
#
#  conv2d_144 (Conv2D)         (None, 17, 17, 160)          179200    ['activation_140[0][0]']
#
#  batch_normalization_136 (B  (None, 17, 17, 160)          480       ['conv2d_139[0][0]']
#  atchNormalization)
#
#  batch_normalization_141 (B  (None, 17, 17, 160)          480       ['conv2d_144[0][0]']
#  atchNormalization)
#
#  activation_136 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_136[0][0
#  )                                                                  ]']
#
#  activation_141 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_141[0][0
#  )                                                                  ]']
#
#  average_pooling2d_13 (Aver  (None, 17, 17, 768)          0         ['mixed4[0][0]']
#  agePooling2D)
#
#  conv2d_137 (Conv2D)         (None, 17, 17, 192)          147456    ['mixed4[0][0]']
#
#  conv2d_140 (Conv2D)         (None, 17, 17, 192)          215040    ['activation_136[0][0]']
#
#  conv2d_145 (Conv2D)         (None, 17, 17, 192)          215040    ['activation_141[0][0]']
#
#  conv2d_146 (Conv2D)         (None, 17, 17, 192)          147456    ['average_pooling2d_13[0][0]']
#
#  batch_normalization_134 (B  (None, 17, 17, 192)          576       ['conv2d_137[0][0]']
#  atchNormalization)
#
#  batch_normalization_137 (B  (None, 17, 17, 192)          576       ['conv2d_140[0][0]']
#  atchNormalization)
#
#  batch_normalization_142 (B  (None, 17, 17, 192)          576       ['conv2d_145[0][0]']
#  atchNormalization)
#
#  batch_normalization_143 (B  (None, 17, 17, 192)          576       ['conv2d_146[0][0]']
#  atchNormalization)
#
#  activation_134 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_134[0][0
#  )                                                                  ]']
#
#  activation_137 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_137[0][0
#  )                                                                  ]']
#
#  activation_142 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_142[0][0
#  )                                                                  ]']
#
#  activation_143 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_143[0][0
#  )                                                                  ]']
#
#  mixed5 (Concatenate)        (None, 17, 17, 768)          0         ['activation_134[0][0]',
#                                                                      'activation_137[0][0]',
#                                                                      'activation_142[0][0]',
#                                                                      'activation_143[0][0]']
#
#  conv2d_151 (Conv2D)         (None, 17, 17, 160)          122880    ['mixed5[0][0]']
#
#  batch_normalization_148 (B  (None, 17, 17, 160)          480       ['conv2d_151[0][0]']
#  atchNormalization)
#
#  activation_148 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_148[0][0
#  )                                                                  ]']
#
#  conv2d_152 (Conv2D)         (None, 17, 17, 160)          179200    ['activation_148[0][0]']
#
#  batch_normalization_149 (B  (None, 17, 17, 160)          480       ['conv2d_152[0][0]']
#  atchNormalization)
#
#  activation_149 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_149[0][0
#  )                                                                  ]']
#
#  conv2d_148 (Conv2D)         (None, 17, 17, 160)          122880    ['mixed5[0][0]']
#
#  conv2d_153 (Conv2D)         (None, 17, 17, 160)          179200    ['activation_149[0][0]']
#
#  batch_normalization_145 (B  (None, 17, 17, 160)          480       ['conv2d_148[0][0]']
#  atchNormalization)
#
#  batch_normalization_150 (B  (None, 17, 17, 160)          480       ['conv2d_153[0][0]']
#  atchNormalization)
#
# ...
#  )                                                                  ]']
#
#  activation_175 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_175[0][0
#  )                                                                  ]']
#
#  conv2d_175 (Conv2D)         (None, 8, 8, 384)            442368    ['activation_171[0][0]']
#
#  conv2d_176 (Conv2D)         (None, 8, 8, 384)            442368    ['activation_171[0][0]']
#
#  conv2d_179 (Conv2D)         (None, 8, 8, 384)            442368    ['activation_175[0][0]']
#
#  conv2d_180 (Conv2D)         (None, 8, 8, 384)            442368    ['activation_175[0][0]']
#
#  average_pooling2d_16 (Aver  (None, 8, 8, 1280)           0         ['mixed8[0][0]']
#  agePooling2D)
#
#  conv2d_173 (Conv2D)         (None, 8, 8, 320)            409600    ['mixed8[0][0]']
#
#  batch_normalization_172 (B  (None, 8, 8, 384)            1152      ['conv2d_175[0][0]']
#  atchNormalization)
#
#  batch_normalization_173 (B  (None, 8, 8, 384)            1152      ['conv2d_176[0][0]']
#  atchNormalization)
#
#  batch_normalization_176 (B  (None, 8, 8, 384)            1152      ['conv2d_179[0][0]']
#  atchNormalization)
#
#  batch_normalization_177 (B  (None, 8, 8, 384)            1152      ['conv2d_180[0][0]']
#  atchNormalization)
#
#  conv2d_181 (Conv2D)         (None, 8, 8, 192)            245760    ['average_pooling2d_16[0][0]']
#
#  batch_normalization_170 (B  (None, 8, 8, 320)            960       ['conv2d_173[0][0]']
#  atchNormalization)
#
#  activation_172 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_172[0][0
#  )                                                                  ]']
#
#  activation_173 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_173[0][0
#  )                                                                  ]']
#
#  activation_176 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_176[0][0
#  )                                                                  ]']
#
#  activation_177 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_177[0][0
#  )                                                                  ]']
#
#  batch_normalization_178 (B  (None, 8, 8, 192)            576       ['conv2d_181[0][0]']
#  atchNormalization)
#
#  activation_170 (Activation  (None, 8, 8, 320)            0         ['batch_normalization_170[0][0
#  )                                                                  ]']
#
#  mixed9_0 (Concatenate)      (None, 8, 8, 768)            0         ['activation_172[0][0]',
#                                                                      'activation_173[0][0]']
#
#  concatenate_2 (Concatenate  (None, 8, 8, 768)            0         ['activation_176[0][0]',
#  )                                                                   'activation_177[0][0]']
#
#  activation_178 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_178[0][0
#  )                                                                  ]']
#
#  mixed9 (Concatenate)        (None, 8, 8, 2048)           0         ['activation_170[0][0]',
#                                                                      'mixed9_0[0][0]',
#                                                                      'concatenate_2[0][0]',
#                                                                      'activation_178[0][0]']
#
#  conv2d_186 (Conv2D)         (None, 8, 8, 448)            917504    ['mixed9[0][0]']
#
#  batch_normalization_183 (B  (None, 8, 8, 448)            1344      ['conv2d_186[0][0]']
#  atchNormalization)
#
#  activation_183 (Activation  (None, 8, 8, 448)            0         ['batch_normalization_183[0][0
#  )                                                                  ]']
#
#  conv2d_183 (Conv2D)         (None, 8, 8, 384)            786432    ['mixed9[0][0]']
#
#  conv2d_187 (Conv2D)         (None, 8, 8, 384)            1548288   ['activation_183[0][0]']
#
#  batch_normalization_180 (B  (None, 8, 8, 384)            1152      ['conv2d_183[0][0]']
#  atchNormalization)
#
#  batch_normalization_184 (B  (None, 8, 8, 384)            1152      ['conv2d_187[0][0]']
#  atchNormalization)
#
#  activation_180 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_180[0][0
#  )                                                                  ]']
#
#  activation_184 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_184[0][0
#  )                                                                  ]']
#
#  conv2d_184 (Conv2D)         (None, 8, 8, 384)            442368    ['activation_180[0][0]']
#
#  conv2d_185 (Conv2D)         (None, 8, 8, 384)            442368    ['activation_180[0][0]']
#
#  conv2d_188 (Conv2D)         (None, 8, 8, 384)            442368    ['activation_184[0][0]']
#
#  conv2d_189 (Conv2D)         (None, 8, 8, 384)            442368    ['activation_184[0][0]']
#
#  average_pooling2d_17 (Aver  (None, 8, 8, 2048)           0         ['mixed9[0][0]']
#  agePooling2D)
#
#  conv2d_182 (Conv2D)         (None, 8, 8, 320)            655360    ['mixed9[0][0]']
#
#  batch_normalization_181 (B  (None, 8, 8, 384)            1152      ['conv2d_184[0][0]']
#  atchNormalization)
#
#  batch_normalization_182 (B  (None, 8, 8, 384)            1152      ['conv2d_185[0][0]']
#  atchNormalization)
#
#  batch_normalization_185 (B  (None, 8, 8, 384)            1152      ['conv2d_188[0][0]']
#  atchNormalization)
#
#  batch_normalization_186 (B  (None, 8, 8, 384)            1152      ['conv2d_189[0][0]']
#  atchNormalization)
#
#  conv2d_190 (Conv2D)         (None, 8, 8, 192)            393216    ['average_pooling2d_17[0][0]']
#
#  batch_normalization_179 (B  (None, 8, 8, 320)            960       ['conv2d_182[0][0]']
#  atchNormalization)
#
#  activation_181 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_181[0][0
#  )                                                                  ]']
#
#  activation_182 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_182[0][0
#  )                                                                  ]']
#
#  activation_185 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_185[0][0
#  )                                                                  ]']
#
#  activation_186 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_186[0][0
#  )                                                                  ]']
#
#  batch_normalization_187 (B  (None, 8, 8, 192)            576       ['conv2d_190[0][0]']
#  atchNormalization)
#
#  activation_179 (Activation  (None, 8, 8, 320)            0         ['batch_normalization_179[0][0
#  )                                                                  ]']
#
#  mixed9_1 (Concatenate)      (None, 8, 8, 768)            0         ['activation_181[0][0]',
#                                                                      'activation_182[0][0]']
#
#  concatenate_3 (Concatenate  (None, 8, 8, 768)            0         ['activation_185[0][0]',
#  )                                                                   'activation_186[0][0]']
#
#  activation_187 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_187[0][0
#  )                                                                  ]']
#
#  mixed10 (Concatenate)       (None, 8, 8, 2048)           0         ['activation_179[0][0]',
#                                                                      'mixed9_1[0][0]',
#                                                                      'concatenate_3[0][0]',
#                                                                      'activation_187[0][0]']
#
#  avg_pool (GlobalAveragePoo  (None, 2048)                 0         ['mixed10[0][0]']
#  ling2D)
#
#  dense_4 (Dense)             (None, 3)                    6147      ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 21808931 (83.19 MB)
# Trainable params: 21774499 (83.06 MB)
# Non-trainable params: 34432 (134.50 KB)
# __________________________________________________________________________________________________

# %%
for layer in model_new2.layers:
    layer.trainable = False
model_new2.layers[-1].trainable = True
model_new.layers[-2].trainable = True

# %%
model_new2.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model_new2.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 299, 299, 3)]        0         []
#
#  conv2d_97 (Conv2D)          (None, 149, 149, 32)         864       ['input_4[0][0]']
#
#  batch_normalization_94 (Ba  (None, 149, 149, 32)         96        ['conv2d_97[0][0]']
#  tchNormalization)
#
#  activation_94 (Activation)  (None, 149, 149, 32)         0         ['batch_normalization_94[0][0]
#                                                                     ']
#
#  conv2d_98 (Conv2D)          (None, 147, 147, 32)         9216      ['activation_94[0][0]']
#
#  batch_normalization_95 (Ba  (None, 147, 147, 32)         96        ['conv2d_98[0][0]']
#  tchNormalization)
#
#  activation_95 (Activation)  (None, 147, 147, 32)         0         ['batch_normalization_95[0][0]
#                                                                     ']
#
#  conv2d_99 (Conv2D)          (None, 147, 147, 64)         18432     ['activation_95[0][0]']
#
#  batch_normalization_96 (Ba  (None, 147, 147, 64)         192       ['conv2d_99[0][0]']
#  tchNormalization)
#
#  activation_96 (Activation)  (None, 147, 147, 64)         0         ['batch_normalization_96[0][0]
#                                                                     ']
#
#  max_pooling2d_7 (MaxPoolin  (None, 73, 73, 64)           0         ['activation_96[0][0]']
#  g2D)
#
#  conv2d_100 (Conv2D)         (None, 73, 73, 80)           5120      ['max_pooling2d_7[0][0]']
#
#  batch_normalization_97 (Ba  (None, 73, 73, 80)           240       ['conv2d_100[0][0]']
#  tchNormalization)
#
#  activation_97 (Activation)  (None, 73, 73, 80)           0         ['batch_normalization_97[0][0]
#                                                                     ']
#
#  conv2d_101 (Conv2D)         (None, 71, 71, 192)          138240    ['activation_97[0][0]']
#
#  batch_normalization_98 (Ba  (None, 71, 71, 192)          576       ['conv2d_101[0][0]']
#  tchNormalization)
#
#  activation_98 (Activation)  (None, 71, 71, 192)          0         ['batch_normalization_98[0][0]
#                                                                     ']
#
#  max_pooling2d_8 (MaxPoolin  (None, 35, 35, 192)          0         ['activation_98[0][0]']
#  g2D)
#
#  conv2d_105 (Conv2D)         (None, 35, 35, 64)           12288     ['max_pooling2d_8[0][0]']
#
#  batch_normalization_102 (B  (None, 35, 35, 64)           192       ['conv2d_105[0][0]']
#  atchNormalization)
#
#  activation_102 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_102[0][0
#  )                                                                  ]']
#
#  conv2d_103 (Conv2D)         (None, 35, 35, 48)           9216      ['max_pooling2d_8[0][0]']
#
#  conv2d_106 (Conv2D)         (None, 35, 35, 96)           55296     ['activation_102[0][0]']
#
#  batch_normalization_100 (B  (None, 35, 35, 48)           144       ['conv2d_103[0][0]']
#  atchNormalization)
#
#  batch_normalization_103 (B  (None, 35, 35, 96)           288       ['conv2d_106[0][0]']
#  atchNormalization)
#
#  activation_100 (Activation  (None, 35, 35, 48)           0         ['batch_normalization_100[0][0
#  )                                                                  ]']
#
#  activation_103 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_103[0][0
#  )                                                                  ]']
#
#  average_pooling2d_9 (Avera  (None, 35, 35, 192)          0         ['max_pooling2d_8[0][0]']
#  gePooling2D)
#
#  conv2d_102 (Conv2D)         (None, 35, 35, 64)           12288     ['max_pooling2d_8[0][0]']
#
#  conv2d_104 (Conv2D)         (None, 35, 35, 64)           76800     ['activation_100[0][0]']
#
#  conv2d_107 (Conv2D)         (None, 35, 35, 96)           82944     ['activation_103[0][0]']
#
#  conv2d_108 (Conv2D)         (None, 35, 35, 32)           6144      ['average_pooling2d_9[0][0]']
#
#  batch_normalization_99 (Ba  (None, 35, 35, 64)           192       ['conv2d_102[0][0]']
#  tchNormalization)
#
#  batch_normalization_101 (B  (None, 35, 35, 64)           192       ['conv2d_104[0][0]']
#  atchNormalization)
#
#  batch_normalization_104 (B  (None, 35, 35, 96)           288       ['conv2d_107[0][0]']
#  atchNormalization)
#
#  batch_normalization_105 (B  (None, 35, 35, 32)           96        ['conv2d_108[0][0]']
#  atchNormalization)
#
#  activation_99 (Activation)  (None, 35, 35, 64)           0         ['batch_normalization_99[0][0]
#                                                                     ']
#
#  activation_101 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_101[0][0
#  )                                                                  ]']
#
#  activation_104 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_104[0][0
#  )                                                                  ]']
#
#  activation_105 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_105[0][0
#  )                                                                  ]']
#
#  mixed0 (Concatenate)        (None, 35, 35, 256)          0         ['activation_99[0][0]',
#                                                                      'activation_101[0][0]',
#                                                                      'activation_104[0][0]',
#                                                                      'activation_105[0][0]']
#
#  conv2d_112 (Conv2D)         (None, 35, 35, 64)           16384     ['mixed0[0][0]']
#
#  batch_normalization_109 (B  (None, 35, 35, 64)           192       ['conv2d_112[0][0]']
#  atchNormalization)
#
#  activation_109 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_109[0][0
#  )                                                                  ]']
#
#  conv2d_110 (Conv2D)         (None, 35, 35, 48)           12288     ['mixed0[0][0]']
#
#  conv2d_113 (Conv2D)         (None, 35, 35, 96)           55296     ['activation_109[0][0]']
#
#  batch_normalization_107 (B  (None, 35, 35, 48)           144       ['conv2d_110[0][0]']
#  atchNormalization)
#
#  batch_normalization_110 (B  (None, 35, 35, 96)           288       ['conv2d_113[0][0]']
#  atchNormalization)
#
#  activation_107 (Activation  (None, 35, 35, 48)           0         ['batch_normalization_107[0][0
#  )                                                                  ]']
#
#  activation_110 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_110[0][0
#  )                                                                  ]']
#
#  average_pooling2d_10 (Aver  (None, 35, 35, 256)          0         ['mixed0[0][0]']
#  agePooling2D)
#
#  conv2d_109 (Conv2D)         (None, 35, 35, 64)           16384     ['mixed0[0][0]']
#
#  conv2d_111 (Conv2D)         (None, 35, 35, 64)           76800     ['activation_107[0][0]']
#
#  conv2d_114 (Conv2D)         (None, 35, 35, 96)           82944     ['activation_110[0][0]']
#
#  conv2d_115 (Conv2D)         (None, 35, 35, 64)           16384     ['average_pooling2d_10[0][0]']
#
#  batch_normalization_106 (B  (None, 35, 35, 64)           192       ['conv2d_109[0][0]']
#  atchNormalization)
#
#  batch_normalization_108 (B  (None, 35, 35, 64)           192       ['conv2d_111[0][0]']
#  atchNormalization)
#
#  batch_normalization_111 (B  (None, 35, 35, 96)           288       ['conv2d_114[0][0]']
#  atchNormalization)
#
#  batch_normalization_112 (B  (None, 35, 35, 64)           192       ['conv2d_115[0][0]']
#  atchNormalization)
#
#  activation_106 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_106[0][0
#  )                                                                  ]']
#
#  activation_108 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_108[0][0
#  )                                                                  ]']
#
#  activation_111 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_111[0][0
#  )                                                                  ]']
#
#  activation_112 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_112[0][0
#  )                                                                  ]']
#
#  mixed1 (Concatenate)        (None, 35, 35, 288)          0         ['activation_106[0][0]',
#                                                                      'activation_108[0][0]',
#                                                                      'activation_111[0][0]',
#                                                                      'activation_112[0][0]']
#
#  conv2d_119 (Conv2D)         (None, 35, 35, 64)           18432     ['mixed1[0][0]']
#
#  batch_normalization_116 (B  (None, 35, 35, 64)           192       ['conv2d_119[0][0]']
#  atchNormalization)
#
#  activation_116 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_116[0][0
#  )                                                                  ]']
#
#  conv2d_117 (Conv2D)         (None, 35, 35, 48)           13824     ['mixed1[0][0]']
#
#  conv2d_120 (Conv2D)         (None, 35, 35, 96)           55296     ['activation_116[0][0]']
#
#  batch_normalization_114 (B  (None, 35, 35, 48)           144       ['conv2d_117[0][0]']
#  atchNormalization)
#
#  batch_normalization_117 (B  (None, 35, 35, 96)           288       ['conv2d_120[0][0]']
#  atchNormalization)
#
#  activation_114 (Activation  (None, 35, 35, 48)           0         ['batch_normalization_114[0][0
#  )                                                                  ]']
#
#  activation_117 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_117[0][0
#  )                                                                  ]']
#
#  average_pooling2d_11 (Aver  (None, 35, 35, 288)          0         ['mixed1[0][0]']
#  agePooling2D)
#
#  conv2d_116 (Conv2D)         (None, 35, 35, 64)           18432     ['mixed1[0][0]']
#
#  conv2d_118 (Conv2D)         (None, 35, 35, 64)           76800     ['activation_114[0][0]']
#
#  conv2d_121 (Conv2D)         (None, 35, 35, 96)           82944     ['activation_117[0][0]']
#
#  conv2d_122 (Conv2D)         (None, 35, 35, 64)           18432     ['average_pooling2d_11[0][0]']
#
#  batch_normalization_113 (B  (None, 35, 35, 64)           192       ['conv2d_116[0][0]']
#  atchNormalization)
#
#  batch_normalization_115 (B  (None, 35, 35, 64)           192       ['conv2d_118[0][0]']
#  atchNormalization)
#
#  batch_normalization_118 (B  (None, 35, 35, 96)           288       ['conv2d_121[0][0]']
#  atchNormalization)
#
#  batch_normalization_119 (B  (None, 35, 35, 64)           192       ['conv2d_122[0][0]']
#  atchNormalization)
#
#  activation_113 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_113[0][0
#  )                                                                  ]']
#
#  activation_115 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_115[0][0
#  )                                                                  ]']
#
#  activation_118 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_118[0][0
#  )                                                                  ]']
#
#  activation_119 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_119[0][0
#  )                                                                  ]']
#
#  mixed2 (Concatenate)        (None, 35, 35, 288)          0         ['activation_113[0][0]',
#                                                                      'activation_115[0][0]',
#                                                                      'activation_118[0][0]',
#                                                                      'activation_119[0][0]']
#
#  conv2d_124 (Conv2D)         (None, 35, 35, 64)           18432     ['mixed2[0][0]']
#
#  batch_normalization_121 (B  (None, 35, 35, 64)           192       ['conv2d_124[0][0]']
#  atchNormalization)
#
#  activation_121 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_121[0][0
#  )                                                                  ]']
#
#  conv2d_125 (Conv2D)         (None, 35, 35, 96)           55296     ['activation_121[0][0]']
#
#  batch_normalization_122 (B  (None, 35, 35, 96)           288       ['conv2d_125[0][0]']
#  atchNormalization)
#
#  activation_122 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_122[0][0
#  )                                                                  ]']
#
#  conv2d_123 (Conv2D)         (None, 17, 17, 384)          995328    ['mixed2[0][0]']
#
#  conv2d_126 (Conv2D)         (None, 17, 17, 96)           82944     ['activation_122[0][0]']
#
#  batch_normalization_120 (B  (None, 17, 17, 384)          1152      ['conv2d_123[0][0]']
#  atchNormalization)
#
#  batch_normalization_123 (B  (None, 17, 17, 96)           288       ['conv2d_126[0][0]']
#  atchNormalization)
#
#  activation_120 (Activation  (None, 17, 17, 384)          0         ['batch_normalization_120[0][0
#  )                                                                  ]']
#
#  activation_123 (Activation  (None, 17, 17, 96)           0         ['batch_normalization_123[0][0
#  )                                                                  ]']
#
#  max_pooling2d_9 (MaxPoolin  (None, 17, 17, 288)          0         ['mixed2[0][0]']
#  g2D)
#
#  mixed3 (Concatenate)        (None, 17, 17, 768)          0         ['activation_120[0][0]',
#                                                                      'activation_123[0][0]',
#                                                                      'max_pooling2d_9[0][0]']
#
#  conv2d_131 (Conv2D)         (None, 17, 17, 128)          98304     ['mixed3[0][0]']
#
#  batch_normalization_128 (B  (None, 17, 17, 128)          384       ['conv2d_131[0][0]']
#  atchNormalization)
#
#  activation_128 (Activation  (None, 17, 17, 128)          0         ['batch_normalization_128[0][0
#  )                                                                  ]']
#
#  conv2d_132 (Conv2D)         (None, 17, 17, 128)          114688    ['activation_128[0][0]']
#
#  batch_normalization_129 (B  (None, 17, 17, 128)          384       ['conv2d_132[0][0]']
#  atchNormalization)
#
#  activation_129 (Activation  (None, 17, 17, 128)          0         ['batch_normalization_129[0][0
#  )                                                                  ]']
#
#  conv2d_128 (Conv2D)         (None, 17, 17, 128)          98304     ['mixed3[0][0]']
#
#  conv2d_133 (Conv2D)         (None, 17, 17, 128)          114688    ['activation_129[0][0]']
#
#  batch_normalization_125 (B  (None, 17, 17, 128)          384       ['conv2d_128[0][0]']
#  atchNormalization)
#
#  batch_normalization_130 (B  (None, 17, 17, 128)          384       ['conv2d_133[0][0]']
#  atchNormalization)
#
#  activation_125 (Activation  (None, 17, 17, 128)          0         ['batch_normalization_125[0][0
#  )                                                                  ]']
#
#  activation_130 (Activation  (None, 17, 17, 128)          0         ['batch_normalization_130[0][0
#  )                                                                  ]']
#
#  conv2d_129 (Conv2D)         (None, 17, 17, 128)          114688    ['activation_125[0][0]']
#
#  conv2d_134 (Conv2D)         (None, 17, 17, 128)          114688    ['activation_130[0][0]']
#
#  batch_normalization_126 (B  (None, 17, 17, 128)          384       ['conv2d_129[0][0]']
#  atchNormalization)
#
#  batch_normalization_131 (B  (None, 17, 17, 128)          384       ['conv2d_134[0][0]']
#  atchNormalization)
#
#  activation_126 (Activation  (None, 17, 17, 128)          0         ['batch_normalization_126[0][0
#  )                                                                  ]']
#
#  activation_131 (Activation  (None, 17, 17, 128)          0         ['batch_normalization_131[0][0
#  )                                                                  ]']
#
#  average_pooling2d_12 (Aver  (None, 17, 17, 768)          0         ['mixed3[0][0]']
#  agePooling2D)
#
#  conv2d_127 (Conv2D)         (None, 17, 17, 192)          147456    ['mixed3[0][0]']
#
#  conv2d_130 (Conv2D)         (None, 17, 17, 192)          172032    ['activation_126[0][0]']
#
#  conv2d_135 (Conv2D)         (None, 17, 17, 192)          172032    ['activation_131[0][0]']
#
#  conv2d_136 (Conv2D)         (None, 17, 17, 192)          147456    ['average_pooling2d_12[0][0]']
#
#  batch_normalization_124 (B  (None, 17, 17, 192)          576       ['conv2d_127[0][0]']
#  atchNormalization)
#
#  batch_normalization_127 (B  (None, 17, 17, 192)          576       ['conv2d_130[0][0]']
#  atchNormalization)
#
#  batch_normalization_132 (B  (None, 17, 17, 192)          576       ['conv2d_135[0][0]']
#  atchNormalization)
#
#  batch_normalization_133 (B  (None, 17, 17, 192)          576       ['conv2d_136[0][0]']
#  atchNormalization)
#
#  activation_124 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_124[0][0
#  )                                                                  ]']
#
#  activation_127 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_127[0][0
#  )                                                                  ]']
#
#  activation_132 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_132[0][0
#  )                                                                  ]']
#
#  activation_133 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_133[0][0
#  )                                                                  ]']
#
#  mixed4 (Concatenate)        (None, 17, 17, 768)          0         ['activation_124[0][0]',
#                                                                      'activation_127[0][0]',
#                                                                      'activation_132[0][0]',
#                                                                      'activation_133[0][0]']
#
#  conv2d_141 (Conv2D)         (None, 17, 17, 160)          122880    ['mixed4[0][0]']
#
#  batch_normalization_138 (B  (None, 17, 17, 160)          480       ['conv2d_141[0][0]']
#  atchNormalization)
#
#  activation_138 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_138[0][0
#  )                                                                  ]']
#
#  conv2d_142 (Conv2D)         (None, 17, 17, 160)          179200    ['activation_138[0][0]']
#
#  batch_normalization_139 (B  (None, 17, 17, 160)          480       ['conv2d_142[0][0]']
#  atchNormalization)
#
#  activation_139 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_139[0][0
#  )                                                                  ]']
#
#  conv2d_138 (Conv2D)         (None, 17, 17, 160)          122880    ['mixed4[0][0]']
#
#  conv2d_143 (Conv2D)         (None, 17, 17, 160)          179200    ['activation_139[0][0]']
#
#  batch_normalization_135 (B  (None, 17, 17, 160)          480       ['conv2d_138[0][0]']
#  atchNormalization)
#
#  batch_normalization_140 (B  (None, 17, 17, 160)          480       ['conv2d_143[0][0]']
#  atchNormalization)
#
#  activation_135 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_135[0][0
#  )                                                                  ]']
#
#  activation_140 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_140[0][0
#  )                                                                  ]']
#
#  conv2d_139 (Conv2D)         (None, 17, 17, 160)          179200    ['activation_135[0][0]']
#
#  conv2d_144 (Conv2D)         (None, 17, 17, 160)          179200    ['activation_140[0][0]']
#
#  batch_normalization_136 (B  (None, 17, 17, 160)          480       ['conv2d_139[0][0]']
#  atchNormalization)
#
#  batch_normalization_141 (B  (None, 17, 17, 160)          480       ['conv2d_144[0][0]']
#  atchNormalization)
#
#  activation_136 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_136[0][0
#  )                                                                  ]']
#
#  activation_141 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_141[0][0
#  )                                                                  ]']
#
#  average_pooling2d_13 (Aver  (None, 17, 17, 768)          0         ['mixed4[0][0]']
#  agePooling2D)
#
#  conv2d_137 (Conv2D)         (None, 17, 17, 192)          147456    ['mixed4[0][0]']
#
#  conv2d_140 (Conv2D)         (None, 17, 17, 192)          215040    ['activation_136[0][0]']
#
#  conv2d_145 (Conv2D)         (None, 17, 17, 192)          215040    ['activation_141[0][0]']
#
#  conv2d_146 (Conv2D)         (None, 17, 17, 192)          147456    ['average_pooling2d_13[0][0]']
#
#  batch_normalization_134 (B  (None, 17, 17, 192)          576       ['conv2d_137[0][0]']
#  atchNormalization)
#
#  batch_normalization_137 (B  (None, 17, 17, 192)          576       ['conv2d_140[0][0]']
#  atchNormalization)
#
#  batch_normalization_142 (B  (None, 17, 17, 192)          576       ['conv2d_145[0][0]']
#  atchNormalization)
#
#  batch_normalization_143 (B  (None, 17, 17, 192)          576       ['conv2d_146[0][0]']
#  atchNormalization)
#
#  activation_134 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_134[0][0
#  )                                                                  ]']
#
#  activation_137 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_137[0][0
#  )                                                                  ]']
#
#  activation_142 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_142[0][0
#  )                                                                  ]']
#
#  activation_143 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_143[0][0
#  )                                                                  ]']
#
#  mixed5 (Concatenate)        (None, 17, 17, 768)          0         ['activation_134[0][0]',
#                                                                      'activation_137[0][0]',
#                                                                      'activation_142[0][0]',
#                                                                      'activation_143[0][0]']
#
#  conv2d_151 (Conv2D)         (None, 17, 17, 160)          122880    ['mixed5[0][0]']
#
#  batch_normalization_148 (B  (None, 17, 17, 160)          480       ['conv2d_151[0][0]']
#  atchNormalization)
#
#  activation_148 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_148[0][0
#  )                                                                  ]']
#
#  conv2d_152 (Conv2D)         (None, 17, 17, 160)          179200    ['activation_148[0][0]']
#
#  batch_normalization_149 (B  (None, 17, 17, 160)          480       ['conv2d_152[0][0]']
#  atchNormalization)
#
#  activation_149 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_149[0][0
#  )                                                                  ]']
#
#  conv2d_148 (Conv2D)         (None, 17, 17, 160)          122880    ['mixed5[0][0]']
#
#  conv2d_153 (Conv2D)         (None, 17, 17, 160)          179200    ['activation_149[0][0]']
#
#  batch_normalization_145 (B  (None, 17, 17, 160)          480       ['conv2d_148[0][0]']
#  atchNormalization)
#
#  batch_normalization_150 (B  (None, 17, 17, 160)          480       ['conv2d_153[0][0]']
#  atchNormalization)
#
# ...
#  )                                                                  ]']
#
#  activation_175 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_175[0][0
#  )                                                                  ]']
#
#  conv2d_175 (Conv2D)         (None, 8, 8, 384)            442368    ['activation_171[0][0]']
#
#  conv2d_176 (Conv2D)         (None, 8, 8, 384)            442368    ['activation_171[0][0]']
#
#  conv2d_179 (Conv2D)         (None, 8, 8, 384)            442368    ['activation_175[0][0]']
#
#  conv2d_180 (Conv2D)         (None, 8, 8, 384)            442368    ['activation_175[0][0]']
#
#  average_pooling2d_16 (Aver  (None, 8, 8, 1280)           0         ['mixed8[0][0]']
#  agePooling2D)
#
#  conv2d_173 (Conv2D)         (None, 8, 8, 320)            409600    ['mixed8[0][0]']
#
#  batch_normalization_172 (B  (None, 8, 8, 384)            1152      ['conv2d_175[0][0]']
#  atchNormalization)
#
#  batch_normalization_173 (B  (None, 8, 8, 384)            1152      ['conv2d_176[0][0]']
#  atchNormalization)
#
#  batch_normalization_176 (B  (None, 8, 8, 384)            1152      ['conv2d_179[0][0]']
#  atchNormalization)
#
#  batch_normalization_177 (B  (None, 8, 8, 384)            1152      ['conv2d_180[0][0]']
#  atchNormalization)
#
#  conv2d_181 (Conv2D)         (None, 8, 8, 192)            245760    ['average_pooling2d_16[0][0]']
#
#  batch_normalization_170 (B  (None, 8, 8, 320)            960       ['conv2d_173[0][0]']
#  atchNormalization)
#
#  activation_172 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_172[0][0
#  )                                                                  ]']
#
#  activation_173 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_173[0][0
#  )                                                                  ]']
#
#  activation_176 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_176[0][0
#  )                                                                  ]']
#
#  activation_177 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_177[0][0
#  )                                                                  ]']
#
#  batch_normalization_178 (B  (None, 8, 8, 192)            576       ['conv2d_181[0][0]']
#  atchNormalization)
#
#  activation_170 (Activation  (None, 8, 8, 320)            0         ['batch_normalization_170[0][0
#  )                                                                  ]']
#
#  mixed9_0 (Concatenate)      (None, 8, 8, 768)            0         ['activation_172[0][0]',
#                                                                      'activation_173[0][0]']
#
#  concatenate_2 (Concatenate  (None, 8, 8, 768)            0         ['activation_176[0][0]',
#  )                                                                   'activation_177[0][0]']
#
#  activation_178 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_178[0][0
#  )                                                                  ]']
#
#  mixed9 (Concatenate)        (None, 8, 8, 2048)           0         ['activation_170[0][0]',
#                                                                      'mixed9_0[0][0]',
#                                                                      'concatenate_2[0][0]',
#                                                                      'activation_178[0][0]']
#
#  conv2d_186 (Conv2D)         (None, 8, 8, 448)            917504    ['mixed9[0][0]']
#
#  batch_normalization_183 (B  (None, 8, 8, 448)            1344      ['conv2d_186[0][0]']
#  atchNormalization)
#
#  activation_183 (Activation  (None, 8, 8, 448)            0         ['batch_normalization_183[0][0
#  )                                                                  ]']
#
#  conv2d_183 (Conv2D)         (None, 8, 8, 384)            786432    ['mixed9[0][0]']
#
#  conv2d_187 (Conv2D)         (None, 8, 8, 384)            1548288   ['activation_183[0][0]']
#
#  batch_normalization_180 (B  (None, 8, 8, 384)            1152      ['conv2d_183[0][0]']
#  atchNormalization)
#
#  batch_normalization_184 (B  (None, 8, 8, 384)            1152      ['conv2d_187[0][0]']
#  atchNormalization)
#
#  activation_180 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_180[0][0
#  )                                                                  ]']
#
#  activation_184 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_184[0][0
#  )                                                                  ]']
#
#  conv2d_184 (Conv2D)         (None, 8, 8, 384)            442368    ['activation_180[0][0]']
#
#  conv2d_185 (Conv2D)         (None, 8, 8, 384)            442368    ['activation_180[0][0]']
#
#  conv2d_188 (Conv2D)         (None, 8, 8, 384)            442368    ['activation_184[0][0]']
#
#  conv2d_189 (Conv2D)         (None, 8, 8, 384)            442368    ['activation_184[0][0]']
#
#  average_pooling2d_17 (Aver  (None, 8, 8, 2048)           0         ['mixed9[0][0]']
#  agePooling2D)
#
#  conv2d_182 (Conv2D)         (None, 8, 8, 320)            655360    ['mixed9[0][0]']
#
#  batch_normalization_181 (B  (None, 8, 8, 384)            1152      ['conv2d_184[0][0]']
#  atchNormalization)
#
#  batch_normalization_182 (B  (None, 8, 8, 384)            1152      ['conv2d_185[0][0]']
#  atchNormalization)
#
#  batch_normalization_185 (B  (None, 8, 8, 384)            1152      ['conv2d_188[0][0]']
#  atchNormalization)
#
#  batch_normalization_186 (B  (None, 8, 8, 384)            1152      ['conv2d_189[0][0]']
#  atchNormalization)
#
#  conv2d_190 (Conv2D)         (None, 8, 8, 192)            393216    ['average_pooling2d_17[0][0]']
#
#  batch_normalization_179 (B  (None, 8, 8, 320)            960       ['conv2d_182[0][0]']
#  atchNormalization)
#
#  activation_181 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_181[0][0
#  )                                                                  ]']
#
#  activation_182 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_182[0][0
#  )                                                                  ]']
#
#  activation_185 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_185[0][0
#  )                                                                  ]']
#
#  activation_186 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_186[0][0
#  )                                                                  ]']
#
#  batch_normalization_187 (B  (None, 8, 8, 192)            576       ['conv2d_190[0][0]']
#  atchNormalization)
#
#  activation_179 (Activation  (None, 8, 8, 320)            0         ['batch_normalization_179[0][0
#  )                                                                  ]']
#
#  mixed9_1 (Concatenate)      (None, 8, 8, 768)            0         ['activation_181[0][0]',
#                                                                      'activation_182[0][0]']
#
#  concatenate_3 (Concatenate  (None, 8, 8, 768)            0         ['activation_185[0][0]',
#  )                                                                   'activation_186[0][0]']
#
#  activation_187 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_187[0][0
#  )                                                                  ]']
#
#  mixed10 (Concatenate)       (None, 8, 8, 2048)           0         ['activation_179[0][0]',
#                                                                      'mixed9_1[0][0]',
#                                                                      'concatenate_3[0][0]',
#                                                                      'activation_187[0][0]']
#
#  avg_pool (GlobalAveragePoo  (None, 2048)                 0         ['mixed10[0][0]']
#  ling2D)
#
#  dense_4 (Dense)             (None, 3)                    6147      ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 21808931 (83.19 MB)
# Trainable params: 6147 (24.01 KB)
# Non-trainable params: 21802784 (83.17 MB)
# __________________________________________________________________________________________________

# %%
model_new2.fit(train_ds, epochs=10, validation_data=test_ds)
# Out:
# Epoch 1/10
# 6/6 [==============================] - 7s 1s/step - loss: 0.6671 - accuracy: 0.8239 - val_loss: 1.4181 - val_accuracy: 0.7600
# Epoch 2/10
# 6/6 [==============================] - 7s 1s/step - loss: 0.9037 - accuracy: 0.8099 - val_loss: 2.3934 - val_accuracy: 0.6800
# Epoch 3/10
# 6/6 [==============================] - 7s 1s/step - loss: 1.0567 - accuracy: 0.7535 - val_loss: 1.6257 - val_accuracy: 0.8400
# Epoch 4/10
# 6/6 [==============================] - 7s 1s/step - loss: 0.8775 - accuracy: 0.7887 - val_loss: 1.0996 - val_accuracy: 0.7600
# Epoch 5/10
# 6/6 [==============================] - 7s 1s/step - loss: 0.8769 - accuracy: 0.7676 - val_loss: 2.2365 - val_accuracy: 0.7600
# Epoch 6/10
# 6/6 [==============================] - 7s 1s/step - loss: 1.0627 - accuracy: 0.7958 - val_loss: 1.1452 - val_accuracy: 0.7600
# Epoch 7/10
# 6/6 [==============================] - 7s 1s/step - loss: 0.4836 - accuracy: 0.8803 - val_loss: 1.9729 - val_accuracy: 0.6800
# Epoch 8/10
# 6/6 [==============================] - 7s 1s/step - loss: 0.4461 - accuracy: 0.8732 - val_loss: 1.4506 - val_accuracy: 0.6800
# Epoch 9/10
# 6/6 [==============================] - 7s 1s/step - loss: 0.4620 - accuracy: 0.8592 - val_loss: 1.3114 - val_accuracy: 0.7600
# Epoch 10/10
# 6/6 [==============================] - 7s 1s/step - loss: 0.2743 - accuracy: 0.8944 - val_loss: 1.4896 - val_accuracy: 0.8400

# %%
y_test = np.empty(25)
for images, labels in test_ds.take(1):
    for i in range(25):
        y_test[i] = int(labels[i])

# %%
predictions = [np.argmax(pred) for pred in model_new2.predict(test_ds)]
# Out:
# 1/1 [==============================] - 1s 984ms/step

# %%
print(classification_report(y_test, predictions))
print(confusion_matrix(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.86      0.75         7
#          1.0       0.91      0.91      0.91        11
#          2.0       1.00      0.71      0.83         7
#
#     accuracy                           0.84        25
#    macro avg       0.86      0.83      0.83        25
# weighted avg       0.87      0.84      0.84        25
#
# [[ 6  1  0]
#  [ 1 10  0]
#  [ 2  0  5]]
