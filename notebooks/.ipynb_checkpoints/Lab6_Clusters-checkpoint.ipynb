# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.cluster import KMeans, AffinityPropagation, DBSCAN, AgglomerativeClustering
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import davies_bouldin_score, rand_score, silhouette_score, fowlkes_mallows_score, make_scorer
from scipy.cluster import hierarchy
from sklearn.mixture import GaussianMixture
from sklearn.model_selection import train_test_split
from imblearn.under_sampling import NearMiss
from sklearn.preprocessing import StandardScaler
from sklearn_som.som import SOM

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Задание №1

# %% [markdown]
# # Генерация датасетов

# %%
#from sklearn.datasets import make_classification, make_blobs

# %%
#X1, Y1 = make_classification(n_samples=500, n_classes=2, n_features=3, n_redundant=0, n_clusters_per_class=1)

# %%
#X2, Y2 = make_blobs(n_samples=300, n_features=5, centers = 3, cluster_std=1.2)

# %%
#X3, Y3 = make_blobs(n_samples=300, n_features=8, centers = 5, cluster_std=0.75)

# %%
#pd.DataFrame(data=X1).to_csv('../data/Lab6_X1.csv', index=False)
#pd.DataFrame(data=Y1).to_csv('../data/Lab6_Y1.csv', index=False) 
#pd.DataFrame(data=X2).to_csv('../data/Lab6_X2.csv', index=False) 
#pd.DataFrame(data=Y2).to_csv('../data/Lab6_Y2.csv', index=False) 
#pd.DataFrame(data=X3).to_csv('../data/Lab6_X3.csv', index=False) 
#pd.DataFrame(data=Y3).to_csv('../data/Lab6_Y3.csv', index=False)

# %%
X1 = pd.read_csv('../data/Lab6_X1.csv')
Y1 = pd.read_csv('../data/Lab6_Y1.csv') 
X2 = pd.read_csv('../data/Lab6_X2.csv')
Y2 = pd.read_csv('../data/Lab6_Y2.csv')
X3 = pd.read_csv('../data/Lab6_X3.csv')
Y3 = pd.read_csv('../data/Lab6_Y3.csv')

# %%
X1 = X1.to_numpy()
Y1 = Y1.to_numpy()
X2 = X2.to_numpy()
Y2 = Y2.to_numpy()
X3 = X3.to_numpy()
Y3 = Y3.to_numpy()

# %%
Y1 = np.array(Y1).flatten()

# %%
Y2 = np.array(Y2).flatten()

# %%
Y3 = np.array(Y3).flatten()

# %% [markdown]
# # Визуализация

# %%
plt.scatter(X1[:, 0], X1[:, 1], marker="o", c=Y1, s=25, edgecolor="k")
plt.show()

# %%
plt.scatter(X2[:, 0], X2[:, 1], marker="o", c=Y2, s=25, edgecolor="k")
plt.show()

# %%
plt.scatter(X3[:, 0], X3[:, 1], marker="o", c=Y3, s=25, edgecolor="k")
plt.show()

# %% [markdown]
# # Вспомогательные функции

# %%
def metrics(name, model, X, Y): 
        print(name)
        print('\nВнутренние метрики')
        try:
            print('Силуэт:', silhouette_score(X, model.predict(X)))
            print('Индекс Дэвиса-Болдуина:', davies_bouldin_score(X, model.predict(X)))
            print('\nВнешние метрики')
            print('Индекс RAND:', rand_score(Y, model.predict(X)))
            print('Индекс Фоулкса – Мэллова', fowlkes_mallows_score(Y, model.predict(X)))
        except:
            print('Силуэт:', silhouette_score(X, model.labels_))
            print('Индекс Дэвиса-Болдуина:', davies_bouldin_score(X, model.labels_))
            print('\nВнешние метрики')
            print('Индекс RAND:', rand_score(Y, model.labels_))
            print('Индекс Фоулкса – Мэллова', fowlkes_mallows_score(Y, model.labels_))

# %% [markdown]
# # Кластеризация

# %% [markdown]
# ## Подбор гиперпараметров

# %% [markdown]
# ### Метод локтя

# %% [markdown]
# #### Первый датасет

# %%
inertias = []

for i in range(1, 10):
  m = KMeans(i, n_init='auto').fit(X1)
  inertias.append(m.inertia_)

plt.plot(range(1,10), inertias)

# %% [markdown]
# #### Второй датасет

# %%
inertias = []

for i in range(1, 10):
  m = KMeans(i, n_init='auto').fit(X2)
  inertias.append(m.inertia_)

plt.plot(range(1,10), inertias)

# %% [markdown]
# #### Третий датасет

# %%
inertias = []

for i in range(1, 10):
  m = KMeans(i, n_init='auto').fit(X3)
  inertias.append(m.inertia_)

plt.plot(range(1,10), inertias)

# %% [markdown]
# ### Метод силуэтов

# %% [markdown]
# #### Первый датасет

# %%
ss = []

for i in range(2, 10):
  ss.append(silhouette_score(X1, KMeans(i, n_init='auto').fit(X1).labels_))

plt.plot(range(2,10), ss)

# %% [markdown]
# #### Второй датасет

# %%
ss = []

for i in range(2, 10):
  ss.append(silhouette_score(X2, KMeans(i, n_init='auto').fit(X2).labels_))

plt.plot(range(2,10), ss)

# %% [markdown]
# #### Третий датасет

# %%
ss = []

for i in range(2, 10):
  ss.append(silhouette_score(X3, KMeans(i, n_init='auto').fit(X3).labels_))

plt.plot(range(2,10), ss)

# %% [markdown]
# ### Заключение

# %% [markdown]
# Метод силуэтов показал себя чуть лучше, так как по нему проще определить число кластеров. По результатам: для первого датасета - 2 кластера, для второго - 3, для третьего - 5.

# %% [markdown]
# ## K-means

# %% [markdown]
# ### Первый датасет

# %%
kmeans1 = KMeans(2, n_init='auto').fit(X1)

# %%
plt.scatter(X1[:,0], X1[:,1], c=kmeans1.labels_)
plt.scatter(kmeans1.cluster_centers_[:,0], kmeans1.cluster_centers_[:,1], s=100, c='red')

# %% [markdown]
# #### Метрики

# %%
metrics('K-means', kmeans1, X1, Y1)
# Out:
# K-means
#
# Внутренние метрики
# Силуэт: 0.39781881428472343
# Индекс Дэвиса-Болдуина: 1.06077136905463
#
# Внешние метрики
# Индекс RAND: 0.9304529058116232
# Индекс Фоулкса – Мэллова 0.9304091226241625

# %% [markdown]
# ### Второй датасет

# %%
kmeans2 = KMeans(3, n_init='auto').fit(X2)

# %%
plt.scatter(X2[:,0], X2[:,1], c=kmeans2.labels_)
plt.scatter(kmeans2.cluster_centers_[:,0], kmeans2.cluster_centers_[:,1], s=100, c='red')

# %% [markdown]
# #### Метрики

# %%
metrics('K-means', kmeans2, X2, Y2)
# Out:
# K-means
#
# Внутренние метрики
# Силуэт: 0.7682327484780341
# Индекс Дэвиса-Болдуина: 0.3370157110126761
#
# Внешние метрики
# Индекс RAND: 1.0
# Индекс Фоулкса – Мэллова 1.0

# %% [markdown]
# ### Третий датасет

# %%
kmeans3 = KMeans(5, n_init='auto').fit(X3)

# %%
plt.scatter(X3[:,0], X3[:,1], c=kmeans3.labels_)
plt.scatter(kmeans3.cluster_centers_[:,0], kmeans3.cluster_centers_[:,1], s=100, c='red')

# %% [markdown]
# #### Метрики

# %%
metrics('K-means', kmeans3, X3, Y3)
# Out:
# K-means
#
# Внутренние метрики
# Силуэт: 0.7866124005339178
# Индекс Дэвиса-Болдуина: 0.3078906457882362
#
# Внешние метрики
# Индекс RAND: 1.0
# Индекс Фоулкса – Мэллова 1.0

# %% [markdown]
# ## AffinityPropagation

# %% [markdown]
# ### Первый датасет

# %%
ap1 = AffinityPropagation(preference=-400).fit(X1)

plt.scatter(X1[:,0], X1[:,1], c=ap1.labels_)
plt.scatter(ap1.cluster_centers_[:,0], ap1.cluster_centers_[:,1], s=100, c='red')

# %% [markdown]
# #### Метрики

# %%
metrics('AffinityPropagation', ap1, X1, Y1)
# Out:
# AffinityPropagation
#
# Внутренние метрики
# Силуэт: 0.3880145122667424
# Индекс Дэвиса-Болдуина: 1.0769682644782812
#
# Внешние метрики
# Индекс RAND: 0.8695390781563126
# Индекс Фоулкса – Мэллова 0.8702387090291924

# %% [markdown]
# ### Второй датасет

# %%
ap2 = AffinityPropagation(preference=-200).fit(X2)

plt.scatter(X2[:,0], X2[:,1], c=ap2.labels_)
plt.scatter(ap2.cluster_centers_[:,0], ap2.cluster_centers_[:,1], s=100, c='red')

# %% [markdown]
# #### Метрики

# %%
metrics('AffinityPropagation', ap2, X2, Y2)
# Out:
# AffinityPropagation
#
# Внутренние метрики
# Силуэт: 0.7682327484780341
# Индекс Дэвиса-Болдуина: 0.3370157110126761
#
# Внешние метрики
# Индекс RAND: 1.0
# Индекс Фоулкса – Мэллова 1.0

# %% [markdown]
# ### Третий датасет

# %%
ap3 = AffinityPropagation(preference=-100).fit(X3)

plt.scatter(X3[:,0], X3[:,1], c=ap3.labels_)
plt.scatter(ap3.cluster_centers_[:,0], ap3.cluster_centers_[:,1], s=100, c='red')

# %% [markdown]
# #### Метрики

# %%
metrics('AffinityPropagation', ap3, X3, Y3)
# Out:
# AffinityPropagation
#
# Внутренние метрики
# Силуэт: 0.7866124005339178
# Индекс Дэвиса-Болдуина: 0.30789064578823616
#
# Внешние метрики
# Индекс RAND: 1.0
# Индекс Фоулкса – Мэллова 1.0

# %% [markdown]
# ## DBSCAN

# %% [markdown]
# ### Подбор гиперпараметров

# %%
from sklearn.neighbors import NearestNeighbors

nbrs = NearestNeighbors(n_neighbors=25).fit(X1)
distances, indices = nbrs.kneighbors(X1)
distances = np.mean(distances, axis=1)
distances = np.sort(distances)
# distances
plt.plot(distances)

# %%
from sklearn.neighbors import NearestNeighbors

nbrs = NearestNeighbors(n_neighbors=43).fit(X2)
distances, indices = nbrs.kneighbors(X2)
distances = np.mean(distances, axis=1)
distances = np.sort(distances)
# distances
plt.plot(distances)

# %%
from sklearn.neighbors import NearestNeighbors

nbrs = NearestNeighbors(n_neighbors=33).fit(X3)
distances, indices = nbrs.kneighbors(X3)
distances = np.mean(distances, axis=1)
distances = np.sort(distances)
# distances
plt.plot(distances)

# %% [markdown]
# ### Первый датасет

# %%
dbs1 = DBSCAN(eps=0.6, min_samples=50).fit(X1)

# %%
print(np.unique(dbs1.labels_))
plt.scatter(X1[:,0], X1[:,1], c=dbs1.labels_)
# Out:
# [-1  0]

# %% [markdown]
# #### Метрики

# %%
metrics('DBSCAN', dbs1, X1, Y1)
# Out:
# DBSCAN
#
# Внутренние метрики
# Силуэт: 0.2947948952718122
# Индекс Дэвиса-Болдуина: 1.3118844154461906
#
# Внешние метрики
# Индекс RAND: 0.794501002004008
# Индекс Фоулкса – Мэллова 0.7984708014683991

# %% [markdown]
# ### Второй датасет

# %%
dbs2 = DBSCAN(eps=3.2).fit(X2)

# %%
print(np.unique(dbs2.labels_))
plt.scatter(X2[:,0], X2[:,1], c=dbs2.labels_)
# Out:
# [-1  0  1  2]

# %% [markdown]
# #### Метрики

# %%
metrics('DBSCAN', dbs2, X2, Y2)
# Out:
# DBSCAN
#
# Внутренние метрики
# Силуэт: 0.6563093370640098
# Индекс Дэвиса-Болдуина: 1.0852565492853743
#
# Внешние метрики
# Индекс RAND: 0.9956298773690078
# Индекс Фоулкса – Мэллова 0.9933787529443877

# %% [markdown]
# ### Третий датасет

# %%
dbs3 = DBSCAN(eps=2.75).fit(X3)

# %%
print(np.unique(dbs3.labels_))
plt.scatter(X3[:,0], X3[:,1], c=dbs3.labels_)
# Out:
# [0 1 2 3 4]

# %% [markdown]
# #### Метрики

# %%
metrics('DBSCAN', dbs3, X3, Y3)
# Out:
# DBSCAN
#
# Внутренние метрики
# Силуэт: 0.7866124005339178
# Индекс Дэвиса-Болдуина: 0.30789064578823616
#
# Внешние метрики
# Индекс RAND: 1.0
# Индекс Фоулкса – Мэллова 1.0

# %% [markdown]
# ## Gaussian Mixtures

# %% [markdown]
# ### Первый датасет

# %%
gm = GaussianMixture(n_components=2).fit(X1)

# %%
plt.scatter(X1[:,0], X1[:,1], c=gm.predict(X1))
plt.scatter(gm.means_[:,0], gm.means_[:,1], s=100, c='red')

# %% [markdown]
# #### Метрики

# %%
metrics('GaussianMixture', gm, X1, Y1)
# Out:
# GaussianMixture
#
# Внутренние метрики
# Силуэт: 0.3941753078347178
# Индекс Дэвиса-Болдуина: 1.0673051524352686
#
# Внешние метрики
# Индекс RAND: 0.9684488977955912
# Индекс Фоулкса – Мэллова 0.9683860500232929

# %% [markdown]
# ### Второй датасет

# %%
gm2 = GaussianMixture(n_components=3).fit(X2)

# %%
plt.scatter(X2[:,0], X2[:,1], c=gm2.predict(X2))
plt.scatter(gm2.means_[:,0], gm2.means_[:,1], s=100, c='red')

# %% [markdown]
# #### Метрики

# %%
metrics('GaussianMixture', gm2, X2, Y2)
# Out:
# GaussianMixture
#
# Внутренние метрики
# Силуэт: 0.7682327484780341
# Индекс Дэвиса-Болдуина: 0.3370157110126761
#
# Внешние метрики
# Индекс RAND: 1.0
# Индекс Фоулкса – Мэллова 1.0

# %% [markdown]
# ### Третий датасет

# %%
gm3 = GaussianMixture(n_components=5).fit(X3)

# %%
plt.scatter(X3[:,0], X3[:,1], c=gm3.predict(X3))
plt.scatter(gm3.means_[:,0], gm3.means_[:,1], s=100, c='red')

# %% [markdown]
# #### Метрики

# %%
metrics('GaussianMixture', gm3, X3, Y3)
# Out:
# GaussianMixture
#
# Внутренние метрики
# Силуэт: 0.7866124005339178
# Индекс Дэвиса-Болдуина: 0.30789064578823616
#
# Внешние метрики
# Индекс RAND: 1.0
# Индекс Фоулкса – Мэллова 1.0

# %% [markdown]
# ## Иерархическая кластеризация

# %% [markdown]
# ### Первый датасет

# %%
ag1 = AgglomerativeClustering(n_clusters=2, linkage="ward").fit(X1)

# %%
plt.scatter(X1[:,0], X1[:,1], c=ag1.labels_)

# %% [markdown]
# #### Метрики

# %%
metrics('Hierarchy', ag1, X1, Y1)
# Out:
# Hierarchy
#
# Внутренние метрики
# Силуэт: 0.39087782767119
# Индекс Дэвиса-Болдуина: 1.0721489200962107
#
# Внешние метрики
# Индекс RAND: 0.949250501002004
# Индекс Фоулкса – Мэллова 0.9491555438819886

# %% [markdown]
# ### Второй датасет

# %%
ag2 = AgglomerativeClustering(n_clusters=3, linkage="ward").fit(X2)

# %%
plt.scatter(X2[:,0], X2[:,1], c=ag2.labels_)

# %% [markdown]
# #### Метрики

# %%
metrics('Hierarchy', ag2, X2, Y2)
# Out:
# Hierarchy
#
# Внутренние метрики
# Силуэт: 0.7682327484780341
# Индекс Дэвиса-Болдуина: 0.3370157110126761
#
# Внешние метрики
# Индекс RAND: 1.0
# Индекс Фоулкса – Мэллова 1.0

# %% [markdown]
# ### Третий датасет

# %%
ag3 = AgglomerativeClustering(n_clusters=5, linkage="ward").fit(X3)

# %%
plt.scatter(X3[:,0], X3[:,1], c=ag3.labels_)

# %% [markdown]
# #### Метрики

# %%
metrics('Hierarchy', ag3, X3, Y3)
# Out:
# Hierarchy
#
# Внутренние метрики
# Силуэт: 0.7866124005339178
# Индекс Дэвиса-Болдуина: 0.3078906457882362
#
# Внешние метрики
# Индекс RAND: 1.0
# Индекс Фоулкса – Мэллова 1.0

# %% [markdown]
# ## Карты Кохена

# %% [markdown]
# ### Первый датасет

# %%
iris_som1 = SOM(m=2, n=1, dim=3)
iris_som1.fit(X1)

# %%
predictions = iris_som1.predict(X1)

# %%
plt.scatter(X1[:,0], X1[:,1], c=predictions)

# %%
metrics('SOM', iris_som1, X1, Y1)
# Out:
# SOM
#
# Внутренние метрики
# Силуэт: 0.39786615148433796
# Индекс Дэвиса-Болдуина: 1.0608941702566155
#
# Внешние метрики
# Индекс RAND: 0.9379238476953908
# Индекс Фоулкса – Мэллова 0.9378605237007352

# %% [markdown]
# ### Второй датасет

# %%
iris_som2 = SOM(m=3, n=1, dim=5)
iris_som2.fit(X2)

# %%
predictions = iris_som2.predict(X2)

# %%
plt.scatter(X2[:,0], X2[:,1], c=predictions)

# %%
metrics('SOM', iris_som2, X2, Y2)
# Out:
# SOM
#
# Внутренние метрики
# Силуэт: 0.7682327484780341
# Индекс Дэвиса-Болдуина: 0.3370157110126761
#
# Внешние метрики
# Индекс RAND: 1.0
# Индекс Фоулкса – Мэллова 1.0

# %% [markdown]
# ### Третий датасет

# %%
iris_som3 = SOM(m=5, n=1, dim=8)
iris_som3.fit(X3)

# %%
predictions = iris_som3.predict(X3)

# %%
plt.scatter(X3[:,0], X3[:,1], c=predictions)

# %%
metrics('SOM', iris_som3, X3, Y3)
# Out:
# SOM
#
# Внутренние метрики
# Силуэт: 0.7866124005339178
# Индекс Дэвиса-Болдуина: 0.3078906457882362
#
# Внешние метрики
# Индекс RAND: 1.0
# Индекс Фоулкса – Мэллова 1.0

# %% [markdown]
# # Задание №2

# %% [markdown]
# ## Обработка датасета из задания №4

# %%
df = pd.read_csv('../data/Lab4_Mrdak_MO-221.csv')

# %%
df
# Out:
#        Unnamed: 0          name  est_diameter_min  est_diameter_max  \
# 0               0    (2011 GZ2)          0.016016          0.035813
# 1               1    (2020 HT6)          0.030518          0.068240
# 2               2  (2016 ED156)          0.055533          0.124177
# 3               3    (2013 FD8)          0.019256          0.043057
# 4               4   (2016 CW31)          0.139494          0.311918
# ...           ...           ...               ...               ...
# 81565       90830    (2019 GF1)          0.008405          0.018795
# 81566       90831     (2021 YE)          0.017561          0.039268
# 81567       90832     (2018 KL)          0.110804          0.247765
# 81568       90834  (2014 SQ260)          0.044112          0.098637
# 81569       90835    (2012 EQ3)          0.084441          0.188817
#
#        relative_velocity  miss_distance  absolute_magnitude  hazardous
# 0           56014.078517   1.024333e+06               26.10          0
# 1            7864.348060   3.268186e+07               24.70          0
# 2           55257.544508   6.538636e+07               23.40          0
# 3           41531.404722   1.260796e+07               25.70          0
# 4           67639.394481   7.130590e+07               21.40          0
# ...                  ...            ...                 ...        ...
# 81565        8424.366481   3.821292e+06               27.50          0
# 81566       23264.740825   1.635007e+06               25.90          0
# 81567       24802.519406   3.351901e+07               21.90          0
# 81568       45763.317060   2.694877e+07               23.90          0
# 81569       79519.526381   3.631207e+07               22.49          0
#
# [81570 rows x 8 columns]

# %%
df = df.drop(['Unnamed: 0', 'name'], axis=1)
df
# Out:
#        est_diameter_min  est_diameter_max  relative_velocity  miss_distance  \
# 0              0.016016          0.035813       56014.078517   1.024333e+06
# 1              0.030518          0.068240        7864.348060   3.268186e+07
# 2              0.055533          0.124177       55257.544508   6.538636e+07
# 3              0.019256          0.043057       41531.404722   1.260796e+07
# 4              0.139494          0.311918       67639.394481   7.130590e+07
# ...                 ...               ...                ...            ...
# 81565          0.008405          0.018795        8424.366481   3.821292e+06
# 81566          0.017561          0.039268       23264.740825   1.635007e+06
# 81567          0.110804          0.247765       24802.519406   3.351901e+07
# 81568          0.044112          0.098637       45763.317060   2.694877e+07
# 81569          0.084441          0.188817       79519.526381   3.631207e+07
#
#        absolute_magnitude  hazardous
# 0                   26.10          0
# 1                   24.70          0
# 2                   23.40          0
# 3                   25.70          0
# 4                   21.40          0
# ...                   ...        ...
# 81565               27.50          0
# 81566               25.90          0
# 81567               21.90          0
# 81568               23.90          0
# 81569               22.49          0
#
# [81570 rows x 6 columns]

# %%
y = df["hazardous"]
X = df.drop(["hazardous"], axis=1)
cols = X.columns

# %% [markdown]
# ## Отбор данных

# %%
y = y[0:81000:10]
X = X[0:81000:10]

# %% [markdown]
# ## Балансировка

# %%
nm = NearMiss()
X, y = nm.fit_resample(X, y.ravel())

# %%
scaler = StandardScaler()

# %%
X = scaler.fit_transform(X)

# %% [markdown]
# ## Обучение

# %% [markdown]
# ### K-means

# %% [markdown]
# #### Подбор гиперпараметров

# %%
ss = []

for i in range(2, 10):
  ss.append(silhouette_score(X, KMeans(i, n_init='auto').fit(X).labels_))

plt.plot(range(2,10), ss)

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(2, n_init='auto')

label = kmeans.fit_predict(X)

# %%
label_0 = X[label == 0]
label_1 = X[label == 1]

# %%
plt.scatter(X[:,1], X[:,2], c=label, marker="o")
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], s=100, c='red')

# %%
plt.scatter(X[:,1], X[:,2], c=y, marker="o")

# %%
metrics('K-Mmeans', kmeans, X, y)
# Out:
# K-Mmeans
#
# Внутренние метрики
# Силуэт: 0.3831873652932142
# Индекс Дэвиса-Болдуина: 1.0213670983474918
#
# Внешние метрики
# Индекс RAND: 0.807471657544957
# Индекс Фоулкса – Мэллова 0.8108941134132358

# %% [markdown]
# ### DBSCAN

# %% [markdown]
# #### Подбор гиперпараметров

# %%
from sklearn.neighbors import NearestNeighbors

nbrs = NearestNeighbors(n_neighbors=33).fit(X)
distances, indices = nbrs.kneighbors(X)
distances = np.mean(distances, axis=1)
distances = np.sort(distances)
# distances
plt.plot(distances)

# %%
dbs = DBSCAN(eps=0.9, min_samples = 65)
label = dbs.fit_predict(X)

# %%
plt.scatter(X[:,1], X[:,2], c=label, marker="o")

# %%
plt.scatter(X[:,1], X[:,2], c=y, marker="o")

# %%
metrics('DBSCAN', dbs, X, y)
# Out:
# DBSCAN
#
# Внутренние метрики
# Силуэт: 0.17249015845230473
# Индекс Дэвиса-Болдуина: 3.3824629331018095
#
# Внешние метрики
# Индекс RAND: 0.5009394546520719
# Индекс Фоулкса – Мэллова 0.5405479048781147

# %% [markdown]
# ### Иерархическая кластеризация

# %%
ag = AgglomerativeClustering(n_clusters=2, linkage="ward")
label = ag.fit_predict(X)

# %%
plt.scatter(X[:,1], X[:,2], c=label, marker="o")

# %%
plt.scatter(X[:,1], X[:,2], c=y, marker="o")

# %%
metrics('Hierarchy', ag, X, y)
# Out:
# Hierarchy
#
# Внутренние метрики
# Силуэт: 0.381881413397664
# Индекс Дэвиса-Болдуина: 1.0143222168323232
#
# Внешние метрики
# Индекс RAND: 0.781078967943706
# Индекс Фоулкса – Мэллова 0.7879198497582179

# %% [markdown]
# ## Заключение

# %% [markdown]
# По взятым метрикам видно, что хорошо себя показали модели, построенные с помощью алгоритмов K-means и Иерархической кластеризации, но модель, построенная с помощью K-means показала себя чуть лучше по всем метрикам.

# %% [markdown]
# ### Первый датасет

# %%
import sys
sys.path.append("..")
from models.KMeans import myKMeans

# %%
mykmeans = myKMeans(k=2, max_iter=2000)

# %%
plt.scatter(X1[:,0], X1[:,1], c=label)
plt.scatter(mykmeans.centroids[:,0], mykmeans.centroids[:,1], s=100, c='red')

# %%
mykmeans.fit(X1)

label = mykmeans.predict(X1)
metrics('K-Mmeans', mykmeans, X1, Y1)
# Out:
# K-Mmeans
#
# Внутренние метрики
# Силуэт: 0.39781881428472343
# Индекс Дэвиса-Болдуина: 1.06077136905463
#
# Внешние метрики
# Индекс RAND: 0.9304529058116232
# Индекс Фоулкса – Мэллова 0.9304091226241625

# %% [markdown]
# ### Второй датасет

# %%
mykmeans2 = myKMeans(k=3, max_iter=2000)

# %%
plt.scatter(X2[:,0], X2[:,1], c=label)
plt.scatter(mykmeans2.centroids[:,0], mykmeans2.centroids[:,1], s=100, c='red')

# %%
mykmeans2.fit(X2)

label = mykmeans2.predict(X2)
metrics('K-Mmeans', mykmeans2, X2, Y2)
# Out:
# K-Mmeans
#
# Внутренние метрики
# Силуэт: 0.7682327484780341
# Индекс Дэвиса-Болдуина: 0.3370157110126761
#
# Внешние метрики
# Индекс RAND: 1.0
# Индекс Фоулкса – Мэллова 1.0

# %% [markdown]
# ### Третий датасет

# %%
mykmeans3 = myKMeans(k=5, max_iter=2000)

# %%
mykmeans3.fit(X3)
label = mykmeans3.predict(X3)
metrics('K-Mmeans',mykmeans3, X3, Y3)
# Out:
# K-Mmeans
#
# Внутренние метрики
# Силуэт: 0.7866124005339178
# Индекс Дэвиса-Болдуина: 0.3078906457882362
#
# Внешние метрики
# Индекс RAND: 1.0
# Индекс Фоулкса – Мэллова 1.0

# %%
plt.scatter(X3[:,0], X3[:,1], c=label)
plt.scatter(mykmeans3.centroids[:,0], mykmeans3.centroids[:,1], s=100, c='red')
