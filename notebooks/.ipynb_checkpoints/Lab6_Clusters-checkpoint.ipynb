# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.cluster import KMeans, AffinityPropagation, DBSCAN
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import davies_bouldin_score, rand_score, silhouette_score, fowlkes_mallows_score, make_scorer
from sklearn.mixture import GaussianMixture

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Генерация датасетов

# %%
from sklearn.datasets import make_classification, make_blobs

# %%
X1, Y1 = make_classification(n_samples=500, n_classes=2, n_features=3, n_redundant=0, n_clusters_per_class=1)

plt.scatter(X1[:, 0], X1[:, 1], marker="o", c=Y1, s=25, edgecolor="k")
plt.show()

# %%
X2, Y2 = make_blobs(n_samples=300, n_features=5, centers = 3, cluster_std=1.5)

plt.scatter(X2[:, 0], X2[:, 1], marker="o", c=Y2, s=25, edgecolor="k")
plt.show()

# %%
X3, Y3 = make_blobs(n_samples=300, n_features=8, centers = 5, cluster_std=0.75)

plt.scatter(X3[:, 0], X3[:, 1], marker="o", c=Y3, s=25, edgecolor="k")
plt.show()

# %% [markdown]
# # Вспомогательные функции

# %%
def metrics(name, model, X, Y):
    print(name)
    print('\nВнутренние метрики')
    print('Силуэт:', silhouette_score(X, model.labels_))
    print('Индекс Дэвиса-Болдуина:', davies_bouldin_score(X, model.labels_))
    print('\nВнешние метрики')
    print('Индекс RAND:', rand_score(Y, model.labels_))
    print('Индекс Фоулкса – Мэллова', fowlkes_mallows_score(Y, model.labels_))

# %% [markdown]
# # Кластеризация

# %% [markdown]
# ## Подбор гиперпараметров

# %% [markdown]
# ### Метод локтя

# %% [markdown]
# #### Первый датасет

# %%
inertias = []

for i in range(1, 10):
  m = KMeans(i, n_init='auto').fit(X1)
  inertias.append(m.inertia_)

plt.plot(range(1,10), inertias)

# %% [markdown]
# #### Второй датасет

# %%
inertias = []

for i in range(1, 10):
  m = KMeans(i, n_init='auto').fit(X2)
  inertias.append(m.inertia_)

plt.plot(range(1,10), inertias)

# %% [markdown]
# #### Третий датасет

# %%
inertias = []

for i in range(1, 10):
  m = KMeans(i, n_init='auto').fit(X3)
  inertias.append(m.inertia_)

plt.plot(range(1,10), inertias)

# %% [markdown]
# ### Метод силуэтов

# %% [markdown]
# #### Первый датасет

# %%
ss = []

for i in range(2, 10):
  ss.append(silhouette_score(X1, KMeans(i, n_init='auto').fit(X1).labels_))

plt.plot(range(2,10), ss)

# %% [markdown]
# #### Второй датасет

# %%
ss = []

for i in range(2, 10):
  ss.append(silhouette_score(X2, KMeans(i, n_init='auto').fit(X2).labels_))

plt.plot(range(2,10), ss)

# %% [markdown]
# #### Третий датасет

# %%
ss = []

for i in range(2, 10):
  ss.append(silhouette_score(X3, KMeans(i, n_init='auto').fit(X3).labels_))

plt.plot(range(2,10), ss)

# %% [markdown]
# ### Заключение

# %% [markdown]
# Метод силуэтов показал себя чуть лучше, так как по нему проще определить число кластеров. По результатам: для первого датасета - 2 кластера, для второго - 3, для третьего - 5.

# %% [markdown]
# ## K-means

# %% [markdown]
# ### Первый датасет

# %%
kmeans1 = KMeans(2, n_init='auto').fit(X1)

# %%
plt.scatter(X1[:,0], X1[:,1], c=kmeans1.labels_)
plt.scatter(kmeans1.cluster_centers_[:,0], kmeans1.cluster_centers_[:,1], s=100, c='red')

# %% [markdown]
# #### Метрики

# %%
metrics('K-means', kmeans1, X1, Y1)
# Out:
# K-means
#
# Внутренние метрики
# Силуэт: 0.373129609339844
# Индекс Дэвиса-Болдуина: 1.0664919057137263
#
# Внешние метрики
# Индекс RAND: 0.7444889779559118
# Индекс Фоулкса – Мэллова 0.7536293397304799

# %% [markdown]
# ### Второй датасет

# %%
kmeans2 = KMeans(3, n_init='auto').fit(X2)

# %%
plt.scatter(X2[:,0], X2[:,1], c=kmeans2.labels_)
plt.scatter(kmeans2.cluster_centers_[:,0], kmeans2.cluster_centers_[:,1], s=100, c='red')

# %% [markdown]
# #### Метрики

# %%
metrics('K-means', kmeans2, X2, Y2)
# Out:
# K-means
#
# Внутренние метрики
# Силуэт: 0.5350279377931181
# Индекс Дэвиса-Болдуина: 0.7116093723156406
#
# Внешние метрики
# Индекс RAND: 0.9955629877369008
# Индекс Фоулкса – Мэллова 0.9932998894556296

# %% [markdown]
# ### Третий датасет

# %%
kmeans3 = KMeans(5, n_init='auto').fit(X3)

# %%
plt.scatter(X3[:,0], X3[:,1], c=kmeans3.labels_)
plt.scatter(kmeans3.cluster_centers_[:,0], kmeans3.cluster_centers_[:,1], s=100, c='red')

# %% [markdown]
# #### Метрики

# %%
metrics('K-means', kmeans3, X3, Y3)
# Out:
# K-means
#
# Внутренние метрики
# Силуэт: 0.8364076686051363
# Индекс Дэвиса-Болдуина: 0.2328909707981371
#
# Внешние метрики
# Индекс RAND: 1.0
# Индекс Фоулкса – Мэллова 1.0

# %% [markdown]
# ## AffinityPropagation

# %% [markdown]
# ### Первый датасет

# %%
ap1 = AffinityPropagation()
parameters = {'preference': np.arange(-600, 0, 50)}
grid_search = GridSearchCV(ap1, parameters, scoring=make_scorer(rand_score))
grid_search.fit(X1)
ap1 = grid_search.best_estimator_

# %%
plt.scatter(X1[:,0], X1[:,1], c=ap1.labels_)
plt.scatter(ap1.cluster_centers_[:,0], ap1.cluster_centers_[:,1], s=100, c='red')

# %% [markdown]
# #### Метрики

# %%
metrics('AffinityPropagation', ap1, X1, Y1)
# Out:
# AffinityPropagation
#
# Внутренние метрики
# Силуэт: -0.0024044557541002486
# Индекс Дэвиса-Болдуина: 0.19109501410206822
#
# Внешние метрики
# Индекс RAND: 0.5009939879759518
# Индекс Фоулкса – Мэллова 0.004007991887704373

# %% [markdown]
# ### Второй датасет

# %%
ap2 = AffinityPropagation()
parameters = {'preference': np.arange(-600, 0, 50)}
grid_search = GridSearchCV(ap2, parameters, scoring=make_scorer(rand_score))
grid_search.fit(X2)
ap2 = grid_search.best_estimator_

# %%
plt.scatter(X2[:,0], X2[:,1], c=ap2.labels_)
plt.scatter(ap2.cluster_centers_[:,0], ap2.cluster_centers_[:,1], s=100, c='red')

# %% [markdown]
# #### Метрики

# %%
metrics('AffinityPropagation', ap2, X2, Y2)
# Out:
# AffinityPropagation
#
# Внутренние метрики
# Силуэт: 0.534850658873844
# Индекс Дэвиса-Болдуина: 0.7112480717148236
#
# Внешние метрики
# Индекс RAND: 1.0
# Индекс Фоулкса – Мэллова 1.0

# %% [markdown]
# ### Третий датасет

# %%
ap3 = AffinityPropagation()
parameters = {'preference': np.arange(-1000, 0, 50)}
grid_search = GridSearchCV(ap3, parameters, scoring=make_scorer(rand_score))
grid_search.fit(X3)
ap3 = grid_search.best_estimator_

# %%
plt.scatter(X3[:,0], X3[:,1], c=ap3.labels_)
plt.scatter(ap3.cluster_centers_[:,0], ap3.cluster_centers_[:,1], s=100, c='red')

# %% [markdown]
# #### Метрики

# %%
metrics('AffinityPropagation', ap3, X3, Y3)
# Out:
# AffinityPropagation
#
# Внутренние метрики
# Силуэт: 0.1495785880615157
# Индекс Дэвиса-Болдуина: 0.2537131539599119
#
# Внешние метрики
# Индекс RAND: 0.8422742474916388
# Индекс Фоулкса – Мэллова 0.44797094336764176

# %% [markdown]
# ## DBSCAN

# %% [markdown]
# ### Подбор гиперпараметров

# %%
from sklearn.neighbors import NearestNeighbors

nbrs = NearestNeighbors(n_neighbors=25).fit(X1)
distances, indices = nbrs.kneighbors(X1)
distances = np.mean(distances, axis=1)
distances = np.sort(distances)
# distances
plt.plot(distances)

# %%
from sklearn.neighbors import NearestNeighbors

nbrs = NearestNeighbors(n_neighbors=43).fit(X2)
distances, indices = nbrs.kneighbors(X2)
distances = np.mean(distances, axis=1)
distances = np.sort(distances)
# distances
plt.plot(distances)

# %%
from sklearn.neighbors import NearestNeighbors

nbrs = NearestNeighbors(n_neighbors=45).fit(X3)
distances, indices = nbrs.kneighbors(X3)
distances = np.mean(distances, axis=1)
distances = np.sort(distances)
# distances
plt.plot(distances)

# %% [markdown]
# ### Первый датасет

# %%
dbs1 = DBSCAN(eps=0.9, min_samples=50).fit(X1)

# %%
print(np.unique(dbs1.labels_))
plt.scatter(X1[:,0], X1[:,1], c=dbs1.labels_)
# Out:
# [-1  0  1]

# %% [markdown]
# #### Метрики

# %%
metrics('DBSCAN', dbs1, X1, Y1)
# Out:
# DBSCAN
#
# Внутренние метрики
# Силуэт: 0.2976631917648343
# Индекс Дэвиса-Болдуина: 4.418907219636876
#
# Внешние метрики
# Индекс RAND: 0.8467655310621243
# Индекс Фоулкса – Мэллова 0.8330195832163141

# %% [markdown]
# ### Второй датасет

# %%
dbs2 = DBSCAN(eps=3).fit(X2)

# %%
print(np.unique(dbs2.labels_))
plt.scatter(X2[:,0], X2[:,1], c=dbs2.labels_)
# Out:
# [-1  0  1]

# %% [markdown]
# #### Метрики

# %%
metrics('DBSCAN', dbs2, X2, Y2)
# Out:
# DBSCAN
#
# Внутренние метрики
# Силуэт: 0.3874023318269733
# Индекс Дэвиса-Болдуина: 2.5868576746659295
#
# Внешние метрики
# Индекс RAND: 0.7632775919732442
# Индекс Фоулкса – Мэллова 0.732588104076092

# %% [markdown]
# ### Третий датасет

# %%
dbs3 = DBSCAN(eps=3).fit(X3)

# %%
print(np.unique(dbs3.labels_))
plt.scatter(X3[:,0], X3[:,1], c=dbs3.labels_)
# Out:
# [0 1 2 3 4]

# %% [markdown]
# #### Метрики

# %%
metrics('DBSCAN', dbs3, X3, Y3)
# Out:
# DBSCAN
#
# Внутренние метрики
# Силуэт: 0.8364076686051363
# Индекс Дэвиса-Болдуина: 0.2328909707981371
#
# Внешние метрики
# Индекс RAND: 1.0
# Индекс Фоулкса – Мэллова 1.0

# %% [markdown]
# ## Gaussian Mixtures

# %% [markdown]
# ### Первый датасет

# %%
gm = GaussianMixture(n_components=2).fit(X1)

# %%
plt.scatter(X1[:,0], X1[:,1], c=gm.predict(X1))
plt.scatter(gm.means_[:,0], gm.means_[:,1], s=100, c='red')

# %% [markdown]
# #### Метрики

# %%
metrics('GaussianMixture', gm, X1, Y1)
# Out:
# GaussianMixture
#
# Внутренние метрики
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 metrics('GaussianMixture', gm, X1, Y1)
#
# Cell In[7], line 4, in metrics(name, model, X, Y)
#       2 print(name)
#       3 print('\nВнутренние метрики')
# ----> 4 print('Силуэт:', silhouette_score(X, model.labels_))
#       5 print('Индекс Дэвиса-Болдуина:', davies_bouldin_score(X, model.labels_))
#       6 print('\nВнешние метрики')
#
# AttributeError: 'GaussianMixture' object has no attribute 'labels_'

# %% [markdown]
# ### Второй датасет

# %%
gm2 = GaussianMixture(n_components=3).fit(X2)

# %%
plt.scatter(X2[:,0], X2[:,1], c=gm2.predict(X2))
plt.scatter(gm2.means_[:,0], gm2.means_[:,1], s=100, c='red')

# %% [markdown]
# #### Метрики

# %%
metrics('DBSCAN', dbs2, X2, Y2)
# Out:
# DBSCAN
#
# Внутренние метрики
# Силуэт: 0.3874023318269733
# Индекс Дэвиса-Болдуина: 2.5868576746659295
#
# Внешние метрики
# Индекс RAND: 0.7632775919732442
# Индекс Фоулкса – Мэллова 0.732588104076092

# %% [markdown]
# ### Третий датасет

# %%
gm2 = GaussianMixture(n_components=5).fit(X2)

# %%
print(np.unique(dbs3.labels_))
plt.scatter(X3[:,0], X3[:,1], c=dbs3.labels_)
# Out:
# [0 1 2 3 4]

# %% [markdown]
# #### Метрики

# %%
metrics('DBSCAN', dbs3, X3, Y3)
# Out:
# DBSCAN
#
# Внутренние метрики
# Силуэт: 0.8364076686051363
# Индекс Дэвиса-Болдуина: 0.2328909707981371
#
# Внешние метрики
# Индекс RAND: 1.0
# Индекс Фоулкса – Мэллова 1.0
