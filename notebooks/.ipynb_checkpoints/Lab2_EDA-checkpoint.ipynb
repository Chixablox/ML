# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings

# %%
df = pd.read_csv('../data/DataSet2.csv')
df.head(10)
# Out:
#    Unnamed: 0                            Film Oscar Year  \
# 0           0                           Wings    1927/28
# 1           1                      7th Heaven    1927/28
# 2           2                      The Racket    1927/28
# 3           3             The Broadway Melody    1928/29
# 4           4                           Alibi    1928/29
# 5           5                 Hollywood Revue    1928/29
# 6           6                  In Old Arizona    1928/29
# 7           7                     The Patriot    1928/29
# 8           8  All Quiet on the Western Front    1929/30
# 9           9                   The Big House    1929/30
#
#   Film Studio/Producer(s)    Award  Year of Release  Movie Time  \
# 0    Famous Players-Lasky   Winner             1927         144
# 1                     Fox  Nominee             1927         110
# 2       The Caddo Company  Nominee             1928          84
# 3     Metro-Goldwyn-Mayer   Winner             1929         100
# 4     Feature Productions  Nominee             1929          91
# 5     Metro-Goldwyn-Mayer  Nominee             1929         130
# 6                     Fox  Nominee             1928          95
# 7  Paramount Famous Lasky  Nominee             1928         113
# 8               Universal   Winner             1930         152
# 9            Cosmopolitan  Nominee             1930          87
#
#               Movie Genre  IMDB Rating IMDB Votes  ... Tomatometer Status  \
# 0       Drama,Romance,War          7.5     12,221  ...    Certified-Fresh
# 1           Drama,Romance          7.7      3,439  ...                NaN
# 2   Crime,Drama,Film-Noir          6.7      1,257  ...                NaN
# 3   Drama,Musical,Romance          5.7      6,890  ...             Rotten
# 4    Action,Crime,Romance          5.8        765  ...                NaN
# 5            Comedy,Music          5.7      2,004  ...                NaN
# 6                 Western          5.6      1,019  ...             Rotten
# 7  Drama,History,Thriller          7.4         18  ...                NaN
# 8               Drama,War          8.1     59,214  ...                NaN
# 9    Crime,Drama,Thriller          7.1      2,079  ...              Fresh
#
#   Tomatometer Rating Tomatometer Count Audience Status Audience Rating  \
# 0               93.0              46.0         Upright            78.0
# 1                NaN               NaN             NaN             NaN
# 2                NaN               NaN             NaN             NaN
# 3               33.0              24.0         Spilled            21.0
# 4                NaN               NaN             NaN             NaN
# 5                NaN               NaN             NaN             NaN
# 6               56.0               9.0         Spilled            38.0
# 7                NaN               NaN             NaN             NaN
# 8                NaN               NaN             NaN             NaN
# 9               75.0               8.0         Upright            69.0
#
#   Audience Count Tomatometer Top Critics Count  \
# 0         3530.0                           9.0
# 1            NaN                           NaN
# 2            NaN                           NaN
# 3         1813.0                           7.0
# 4            NaN                           NaN
# 5            NaN                           NaN
# 6          356.0                           2.0
# 7            NaN                           NaN
# 8            NaN                           NaN
# 9          323.0                           0.0
#
#   Tomatometer Fresh Critics Count Tomatometer Rotten Critics Count  \
# 0                            43.0                              3.0
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             8.0                             16.0
# 4                             NaN                              NaN
# 5                             NaN                              NaN
# 6                             5.0                              4.0
# 7                             NaN                              NaN
# 8                             NaN                              NaN
# 9                             6.0                              2.0
#
#                                 Film ID
# 0  2becf7d5-a3de-46ab-ae45-abdd6b588067
# 1  19ed3295-a878-4fd2-8e60-5cd7b5f93dad
# 2  3111c2d8-0908-4093-8ff3-99c89f2f2f08
# 3  de063f3f-2d35-4e1c-8636-6eb4c16bd236
# 4  609887c2-877c-43a4-b88c-e40e31096a98
# 5  689f22d5-a700-4ce1-b9be-65652f32c186
# 6  a0644f19-a136-44c2-ab5d-50978ef19608
# 7  5d4ef7bd-2f81-47f3-9305-2c8fe140d4e4
# 8  281742f9-3b4e-480d-b704-c8c15de6b721
# 9  297aa285-29d7-4a22-b833-c5632ab3e562
#
# [10 rows x 30 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Film', 'Oscar Year', 'Film Studio/Producer(s)', 'Award',
#        'Year of Release', 'Movie Time', 'Movie Genre', 'IMDB Rating',
#        'IMDB Votes', 'Movie Info', 'Genres', 'Critic Consensus',
#        'Content Rating', 'Directors', 'Authors', 'Actors',
#        'Original Release Date', 'Streaming Release Date', 'Production Company',
#        'Tomatometer Status', 'Tomatometer Rating', 'Tomatometer Count',
#        'Audience Status', 'Audience Rating', 'Audience Count',
#        'Tomatometer Top Critics Count', 'Tomatometer Fresh Critics Count',
#        'Tomatometer Rotten Critics Count', 'Film ID'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 30 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Unnamed: 0                        571 non-null    int64
#  1   Film                              571 non-null    object
#  2   Oscar Year                        571 non-null    object
#  3   Film Studio/Producer(s)           571 non-null    object
#  4   Award                             571 non-null    object
#  5   Year of Release                   571 non-null    int64
#  6   Movie Time                        571 non-null    int64
#  7   Movie Genre                       571 non-null    object
#  8   IMDB Rating                       571 non-null    float64
#  9   IMDB Votes                        571 non-null    object
#  10  Movie Info                        438 non-null    object
#  11  Genres                            439 non-null    object
#  12  Critic Consensus                  339 non-null    object
#  13  Content Rating                    439 non-null    object
#  14  Directors                         437 non-null    object
#  15  Authors                           437 non-null    object
#  16  Actors                            439 non-null    object
#  17  Original Release Date             439 non-null    object
#  18  Streaming Release Date            438 non-null    object
#  19  Production Company                439 non-null    object
#  20  Tomatometer Status                439 non-null    object
#  21  Tomatometer Rating                439 non-null    float64
#  22  Tomatometer Count                 439 non-null    float64
#  23  Audience Status                   436 non-null    object
#  24  Audience Rating                   439 non-null    float64
#  25  Audience Count                    439 non-null    float64
#  26  Tomatometer Top Critics Count     439 non-null    float64
#  27  Tomatometer Fresh Critics Count   439 non-null    float64
#  28  Tomatometer Rotten Critics Count  439 non-null    float64
#  29  Film ID                           571 non-null    object
# dtypes: float64(8), int64(3), object(19)
# memory usage: 134.0+ KB

# %% [markdown]
# Сразу удалим стобец "Unnamed: 0"

# %%
df.drop('Unnamed: 0', axis= 1 , inplace= True )

# %% [markdown]
# ### Обработка пропущенных знаечний

# %% [markdown]
# Посмотрим число пропущенных значений

# %%
df.isna().sum()
# Out:
# Film                                  0
# Oscar Year                            0
# Film Studio/Producer(s)               0
# Award                                 0
# Year of Release                       0
# Movie Time                            0
# Movie Genre                           0
# IMDB Rating                           0
# IMDB Votes                            0
# Movie Info                          133
# Genres                              132
# Critic Consensus                    232
# Content Rating                      132
# Directors                           134
# Authors                             134
# Actors                              132
# Original Release Date               132
# Streaming Release Date              133
# Production Company                  132
# Tomatometer Status                  132
# Tomatometer Rating                  132
# Tomatometer Count                   132
# Audience Status                     135
# Audience Rating                     132
# Audience Count                      132
# Tomatometer Top Critics Count       132
# Tomatometer Fresh Critics Count     132
# Tomatometer Rotten Critics Count    132
# Film ID                               0
# dtype: int64

# %% [markdown]
# Из данного списка видно, что из 571 фильма, представленного в датасете, у 132 фильмов отсутствует информация в 19 столбцах из 30. Удалим эти фильмы из таблицы, потому что восстановить данные этих столбцов восстановить сложно, а подставление нулей или медианы очень сильно скажется на оценке содержимого.

# %%
df.dropna(subset=['Production Company'], how='all', inplace=True)

# %%
df.isna().sum()
# Out:
# Film                                  0
# Oscar Year                            0
# Film Studio/Producer(s)               0
# Award                                 0
# Year of Release                       0
# Movie Time                            0
# Movie Genre                           0
# IMDB Rating                           0
# IMDB Votes                            0
# Movie Info                            1
# Genres                                0
# Critic Consensus                    100
# Content Rating                        0
# Directors                             2
# Authors                               2
# Actors                                0
# Original Release Date                 0
# Streaming Release Date                1
# Production Company                    0
# Tomatometer Status                    0
# Tomatometer Rating                    0
# Tomatometer Count                     0
# Audience Status                       3
# Audience Rating                       0
# Audience Count                        0
# Tomatometer Top Critics Count         0
# Tomatometer Fresh Critics Count       0
# Tomatometer Rotten Critics Count      0
# Film ID                               0
# dtype: int64

# %% [markdown]
# В столбце "Critic Consensus" проставим unknown, потому что восстановить его невозможно, это же сделаем со столбцами "Movie Info", "Directors", "Authors"

# %%
df['Critic Consensus'] = df['Critic Consensus'].fillna('Unknown')
df['Movie Info'] = df['Movie Info'].fillna('Unknown')
df['Directors'] = df['Directors'].fillna('Unknown')
df['Authors'] = df['Authors'].fillna('Unknown')

# %%
df.isna().sum()
# Out:
# Film                                0
# Oscar Year                          0
# Film Studio/Producer(s)             0
# Award                               0
# Year of Release                     0
# Movie Time                          0
# Movie Genre                         0
# IMDB Rating                         0
# IMDB Votes                          0
# Movie Info                          0
# Genres                              0
# Critic Consensus                    0
# Content Rating                      0
# Directors                           0
# Authors                             0
# Actors                              0
# Original Release Date               0
# Streaming Release Date              1
# Production Company                  0
# Tomatometer Status                  0
# Tomatometer Rating                  0
# Tomatometer Count                   0
# Audience Status                     3
# Audience Rating                     0
# Audience Count                      0
# Tomatometer Top Critics Count       0
# Tomatometer Fresh Critics Count     0
# Tomatometer Rotten Critics Count    0
# Film ID                             0
# dtype: int64

# %% [markdown]
# В столбце "Streaming Release Date"

# %%
df_new = df[df['Streaming Release Date'].isnull()]
df_new
# Out:
#                       Film Oscar Year Film Studio/Producer(s)    Award  \
# 212  Cat on a Hot Tin Roof       1958     Lawrence Weingarten  Nominee
#
#      Year of Release  Movie Time Movie Genre  IMDB Rating IMDB Votes  \
# 212             1958         108       Drama          8.0     47,222
#
#     Movie Info  ... Tomatometer Status Tomatometer Rating Tomatometer Count  \
# 212    Unknown  ...              Fresh               97.0              37.0
#
#     Audience Status Audience Rating Audience Count  \
# 212         Upright            92.0        31748.0
#
#     Tomatometer Top Critics Count Tomatometer Fresh Critics Count  \
# 212                           5.0                            36.0
#
#     Tomatometer Rotten Critics Count                               Film ID
# 212                              1.0  466621aa-287c-4316-9083-74a5fc72a4f6
#
# [1 rows x 29 columns]

# %%
df.loc[df['Film'] == 'Cat on a Hot Tin Roof', 'Production Company']
# Out:
# 212    MGM Home Entertainment
# Name: Production Company, dtype: object

# %% [markdown]
# Посмотрим на дату онлайн релиза фильмов, которые имеют ту же компанию по продакшену

# %%
df.loc[df['Production Company'] == 'MGM Home Entertainment', 'Streaming Release Date']
# Out:
# 3      2017-02-25
# 13     2017-01-08
# 18     2016-12-20
# 27     2012-04-16
# 60     2016-11-18
# 70     2015-12-26
# 72     2016-11-21
# 83     2009-01-01
# 84     2013-12-03
# 92     2015-09-11
# 106    2017-03-12
# 120    2017-01-12
# 126    2016-11-21
# 129    2016-05-07
# 146    2008-08-04
# 148    2008-12-31
# 154    2009-04-01
# 173    2012-04-16
# 182    2013-12-03
# 186    2008-01-01
# 193    2015-05-08
# 195    2017-01-19
# 210    2016-04-19
# 212           NaN
# 213    2017-04-18
# 214    2016-05-04
# 306    2016-07-14
# 359    2016-11-01
# Name: Streaming Release Date, dtype: object

# %% [markdown]
# Мы видим, что даты онлайн релизов фильмов, стоящих рядом, находятся в 2016-2017 годах, проставим схожую дату.

# %%
df.at [212, 'Streaming Release Date'] = '2016-08-10'

# %% [markdown]
# Так как столбец "Audience Status" содержит исключительно два значения "Upright" и "Spilled", то проставим вместо NaN значение, которое завивит от оценки фильмов

# %%
df_new = df[df['Audience Status'].isnull()]
df_new
# Out:
#                Film Oscar Year  \
# 557    The Irishman       2019
# 559           Joker       2019
# 561  Marriage Story       2019
#
#                                Film Studio/Producer(s)    Award  \
# 557  Martin Scorsese, Robert De Niro, Jane Rosentha...  Nominee
# 559  Todd Phillips, Bradley Cooper, and Emma Tillin...  Nominee
# 561                     Noah Baumbach and David Heyman  Nominee
#
#      Year of Release  Movie Time            Movie Genre  IMDB Rating  \
# 557             2019         209  Biography,Crime,Drama          7.8
# 559             2019         122   Crime,Drama,Thriller          8.4
# 561             2019         137   Comedy,Drama,Romance          7.9
#
#     IMDB Votes                                         Movie Info  ...  \
# 557    349,303  In the 1950s, truck driver Frank Sheeran gets ...  ...
# 559  1,056,051  Forever alone in a crowd, failed comedian Arth...  ...
# 561    270,304  A stage director and his actor wife struggle t...  ...
#
#     Tomatometer Status Tomatometer Rating Tomatometer Count Audience Status  \
# 557    Certified-Fresh               96.0             439.0             NaN
# 559              Fresh               68.0             574.0             NaN
# 561    Certified-Fresh               94.0             381.0             NaN
#
#     Audience Rating Audience Count Tomatometer Top Critics Count  \
# 557            86.0         1057.0                          53.0
# 559            88.0        66303.0                          56.0
# 561            85.0          184.0                          48.0
#
#     Tomatometer Fresh Critics Count Tomatometer Rotten Critics Count  \
# 557                           421.0                             19.0
# 559                           393.0                            182.0
# 561                           359.0                             22.0
#
#                                   Film ID
# 557  cf8fb1fa-1a2b-48bd-a241-c7e9d487c09d
# 559  9988cdef-854b-4e3d-8dc4-19e8e8717b9b
# 561  4dfbadb9-b7f9-4c24-bbd8-5d55dce2c7c6
#
# [3 rows x 29 columns]

# %% [markdown]
# Так как у данных фильмов значение "Audience Rating" больше 60, то в столбец "Audience Status" для данных фильмов проставим "Upright"

# %%
df.at [557, 'Audience Status'] = 'Upright'
df.at [559, 'Audience Status'] = 'Upright'
df.at [561, 'Audience Status'] = 'Upright'

# %%
df.isna().sum()
# Out:
# Film                                0
# Oscar Year                          0
# Film Studio/Producer(s)             0
# Award                               0
# Year of Release                     0
# Movie Time                          0
# Movie Genre                         0
# IMDB Rating                         0
# IMDB Votes                          0
# Movie Info                          0
# Genres                              0
# Critic Consensus                    0
# Content Rating                      0
# Directors                           0
# Authors                             0
# Actors                              0
# Original Release Date               0
# Streaming Release Date              0
# Production Company                  0
# Tomatometer Status                  0
# Tomatometer Rating                  0
# Tomatometer Count                   0
# Audience Status                     0
# Audience Rating                     0
# Audience Count                      0
# Tomatometer Top Critics Count       0
# Tomatometer Fresh Critics Count     0
# Tomatometer Rotten Critics Count    0
# Film ID                             0
# dtype: int64

# %%
df
# Out:
#                     Film Oscar Year  \
# 0                  Wings    1927/28
# 3    The Broadway Melody    1928/29
# 6         In Old Arizona    1928/29
# 9          The Big House    1929/30
# 13              Cimarron    1930/31
# ..                   ...        ...
# 552       A Star Is Born       2018
# 553                 Vice       2018
# 557         The Irishman       2019
# 559                Joker       2019
# 561       Marriage Story       2019
#
#                                Film Studio/Producer(s)    Award  \
# 0                                 Famous Players-Lasky   Winner
# 3                                  Metro-Goldwyn-Mayer   Winner
# 6                                                  Fox  Nominee
# 9                                         Cosmopolitan  Nominee
# 13                                           RKO Radio   Winner
# ..                                                 ...      ...
# 552  Bill Gerber, Bradley Cooper, and Lynette Howel...  Nominee
# 553  Dede Gardner, Jeremy Kleiner, Adam McKay, and ...  Nominee
# 557  Martin Scorsese, Robert De Niro, Jane Rosentha...  Nominee
# 559  Todd Phillips, Bradley Cooper, and Emma Tillin...  Nominee
# 561                     Noah Baumbach and David Heyman  Nominee
#
#      Year of Release  Movie Time             Movie Genre  IMDB Rating  \
# 0               1927         144       Drama,Romance,War          7.5
# 3               1929         100   Drama,Musical,Romance          5.7
# 6               1928          95                 Western          5.6
# 9               1930          87    Crime,Drama,Thriller          7.1
# 13              1931         123           Drama,Western          5.9
# ..               ...         ...                     ...          ...
# 552             2018         136     Drama,Music,Romance          7.6
# 553             2018         132  Biography,Comdey,Drama          7.2
# 557             2019         209   Biography,Crime,Drama          7.8
# 559             2019         122    Crime,Drama,Thriller          8.4
# 561             2019         137    Comedy,Drama,Romance          7.9
#
#     IMDB Votes                                         Movie Info  ...  \
# 0       12,221  With World War I afoot, David Armstrong (Richa...  ...
# 3        6,890  Vaudeville sisters "Hank" (Bessie Love) and Qu...  ...
# 6        1,019  In this early Western, notorious bandit the Ci...  ...
# 9        2,079  After being convicted of manslaughter, drunk d...  ...
# 13       5,851  In 1889, adventurous lawyer and newspaper edit...  ...
# ..         ...                                                ...  ...
# 552    354,157  Seasoned musician Jackson Maine discovers -- a...  ...
# 553    132,014  Gov. George W. Bush of Texas picks Dick Cheney...  ...
# 557    349,303  In the 1950s, truck driver Frank Sheeran gets ...  ...
# 559  1,056,051  Forever alone in a crowd, failed comedian Arth...  ...
# 561    270,304  A stage director and his actor wife struggle t...  ...
#
#     Tomatometer Status Tomatometer Rating Tomatometer Count Audience Status  \
# 0      Certified-Fresh               93.0              46.0         Upright
# 3               Rotten               33.0              24.0         Spilled
# 6               Rotten               56.0               9.0         Spilled
# 9                Fresh               75.0               8.0         Upright
# 13              Rotten               50.0              24.0         Spilled
# ..                 ...                ...               ...             ...
# 552    Certified-Fresh               90.0             517.0         Upright
# 553              Fresh               65.0             359.0         Upright
# 557    Certified-Fresh               96.0             439.0         Upright
# 559              Fresh               68.0             574.0         Upright
# 561    Certified-Fresh               94.0             381.0         Upright
#
#     Audience Rating Audience Count Tomatometer Top Critics Count  \
# 0              78.0         3530.0                           9.0
# 3              21.0         1813.0                           7.0
# 6              38.0          356.0                           2.0
# 9              69.0          323.0                           0.0
# 13             25.0         1514.0                           6.0
# ..              ...            ...                           ...
# 552            79.0        20442.0                          62.0
# 553            60.0         5061.0                          47.0
# 557            86.0         1057.0                          53.0
# 559            88.0        66303.0                          56.0
# 561            85.0          184.0                          48.0
#
#     Tomatometer Fresh Critics Count Tomatometer Rotten Critics Count  \
# 0                              43.0                              3.0
# 3                               8.0                             16.0
# 6                               5.0                              4.0
# 9                               6.0                              2.0
# 13                             12.0                             12.0
# ..                              ...                              ...
# 552                           466.0                             52.0
# 553                           234.0                            125.0
# 557                           421.0                             19.0
# 559                           393.0                            182.0
# 561                           359.0                             22.0
#
#                                   Film ID
# 0    2becf7d5-a3de-46ab-ae45-abdd6b588067
# 3    de063f3f-2d35-4e1c-8636-6eb4c16bd236
# 6    a0644f19-a136-44c2-ab5d-50978ef19608
# 9    297aa285-29d7-4a22-b833-c5632ab3e562
# 13   db2683c0-128e-4b5c-858f-d9f18c2fb9b9
# ..                                    ...
# 552  a8a00610-8b95-4d5f-b95e-128b6a2853ea
# 553  27048415-ff2e-427e-a4de-5d2898a0812d
# 557  cf8fb1fa-1a2b-48bd-a241-c7e9d487c09d
# 559  9988cdef-854b-4e3d-8dc4-19e8e8717b9b
# 561  4dfbadb9-b7f9-4c24-bbd8-5d55dce2c7c6
#
# [439 rows x 29 columns]

# %% [markdown]
# ### Проверим уникальность значений

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 439 entries, 0 to 561
# Data columns (total 29 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Film                              439 non-null    object
#  1   Oscar Year                        439 non-null    object
#  2   Film Studio/Producer(s)           439 non-null    object
#  3   Award                             439 non-null    object
#  4   Year of Release                   439 non-null    int64
#  5   Movie Time                        439 non-null    int64
#  6   Movie Genre                       439 non-null    object
#  7   IMDB Rating                       439 non-null    float64
#  8   IMDB Votes                        439 non-null    object
#  9   Movie Info                        439 non-null    object
#  10  Genres                            439 non-null    object
#  11  Critic Consensus                  439 non-null    object
#  12  Content Rating                    439 non-null    object
#  13  Directors                         439 non-null    object
#  14  Authors                           439 non-null    object
#  15  Actors                            439 non-null    object
#  16  Original Release Date             439 non-null    object
#  17  Streaming Release Date            439 non-null    object
#  18  Production Company                439 non-null    object
#  19  Tomatometer Status                439 non-null    object
#  20  Tomatometer Rating                439 non-null    float64
#  21  Tomatometer Count                 439 non-null    float64
#  22  Audience Status                   439 non-null    object
#  23  Audience Rating                   439 non-null    float64
#  24  Audience Count                    439 non-null    float64
#  25  Tomatometer Top Critics Count     439 non-null    float64
#  26  Tomatometer Fresh Critics Count   439 non-null    float64
#  27  Tomatometer Rotten Critics Count  439 non-null    float64
#  28  Film ID                           439 non-null    object
# dtypes: float64(8), int64(2), object(19)
# memory usage: 119.1+ KB

# %% [markdown]
# Проверим столбцы "Movie Genre", "Genres", "Content Rating", "Production Company", "Tomatometer Status", "Audience Status".

# %%
sorted(df['Movie Genre'].unique())
# Out:
# ['Action,Adventure',
#  'Action,Adventure,Drama',
#  'Action,Adventure,Fantasy',
#  'Action,Adventure,History',
#  'Action,Adventure,Romance',
#  'Action,Adventure,Sci-Fi',
#  'Action,Biography,Crime',
#  'Action,Crime,Drama',
#  'Action,Drama,History',
#  'Action,Drama,Thriller',
#  'Action,Romance,Thriller',
#  'Action,Sci-Fi,Thriller',
#  'Adventure,Biography,Crime',
#  'Adventure,Biography,Drama',
#  'Adventure,Comedy,Crime',
#  'Adventure,Comedy,Drama',
#  'Adventure,Comedy,Family',
#  'Adventure,Comedy,History',
#  'Adventure,Comedy,Musical',
#  'Adventure,Drama',
#  'Adventure,Drama,Family',
#  'Adventure,Drama,Fantasy',
#  'Adventure,Drama,History',
#  'Adventure,Drama,Romance',
#  'Adventure,Drama,Sci-Fi',
#  'Adventure,Drama,Thriller',
#  'Adventure,Drama,War',
#  'Adventure,Drama,Western',
#  'Adventure,Family,Fantasy',
#  'Adventure,Thriller',
#  'Animation,Adventure,Comedy',
#  'Animation,Family,Fantasy',
#  'Biography,Comdey,Drama',
#  'Biography,Comedy,Crime',
#  'Biography,Comedy,Drama',
#  'Biography,Crime,Drama',
#  'Biography,Drama',
#  'Biography,Drama,Family',
#  'Biography,Drama,History',
#  'Biography,Drama,Music',
#  'Biography,Drama,Musical',
#  'Biography,Drama,Romance',
#  'Biography,Drama,Sport',
#  'Biography,Drama,Thriller',
#  'Biography,Drama,War',
#  'Comedy,Crime,Drama',
#  'Comedy,Crime,Musical',
#  'Comedy,Crime,Mystery',
#  'Comedy,Drama',
#  'Comedy,Drama,Family',
#  'Comedy,Drama,Fantasy',
#  'Comedy,Drama,History',
#  'Comedy,Drama,Music',
#  'Comedy,Drama,Musical',
#  'Comedy,Drama,Mystery',
#  'Comedy,Drama,Romance',
#  'Comedy,Drama,War',
#  'Comedy,Family,Fantasy',
#  'Comedy,Family,Musical',
#  'Comedy,Fantasy,Music',
#  'Comedy,Fantasy,Romance',
#  'Comedy,Musical,Romance',
#  'Comedy,Romance',
#  'Comedy,Romance,War',
#  'Comedy,War',
#  'Crime,Drama',
#  'Crime,Drama,Fantasy',
#  'Crime,Drama,Film-Noir',
#  'Crime,Drama,History',
#  'Crime,Drama,Musical',
#  'Crime,Drama,Mystery',
#  'Crime,Drama,Romance',
#  'Crime,Drama,Sci-Fi',
#  'Crime,Drama,Thriller',
#  'Crime,Film-Noir,Mystery',
#  'Drama',
#  'Drama,Family',
#  'Drama,Family,Fantasy',
#  'Drama,Family,Musical',
#  'Drama,Family,Romance',
#  'Drama,Family,Western',
#  'Drama,Fantasy',
#  'Drama,Fantasy,Romance',
#  'Drama,Film-Noir',
#  'Drama,History',
#  'Drama,History,Musical',
#  'Drama,History,Romance',
#  'Drama,History,Sport',
#  'Drama,History,Thriller',
#  'Drama,Music',
#  'Drama,Music,Musical',
#  'Drama,Music,Romance',
#  'Drama,Musical,Romance',
#  'Drama,Mystery',
#  'Drama,Mystery,Romance',
#  'Drama,Mystery,Thriller',
#  'Drama,Mystery,War',
#  'Drama,Romance',
#  'Drama,Romance,Sci-Fi',
#  'Drama,Romance,War',
#  'Drama,Sci-Fi',
#  'Drama,Sci-Fi,Thriller',
#  'Drama,Sport',
#  'Drama,Thriller',
#  'Drama,Thriller,Western',
#  'Drama,War',
#  'Drama,Western',
#  'Film-Noir,Mystery,Thriller',
#  'Horror',
#  'Horror,Mystery,Thriller',
#  'Western']

# %%
sorted(df['Genres'].unique())
# Out:
# ['Action & Adventure',
#  'Action & Adventure, Animation, Comedy, Kids & Family',
#  'Action & Adventure, Art House & International, Classics, Drama',
#  'Action & Adventure, Art House & International, Classics, Drama, Romance',
#  'Action & Adventure, Classics',
#  'Action & Adventure, Classics, Comedy, Kids & Family, Musical & Performing Arts, Science Fiction & Fantasy',
#  'Action & Adventure, Classics, Comedy, Romance',
#  'Action & Adventure, Classics, Drama',
#  'Action & Adventure, Classics, Drama, Mystery & Suspense',
#  'Action & Adventure, Classics, Drama, Mystery & Suspense, Romance',
#  'Action & Adventure, Classics, Drama, Mystery & Suspense, Science Fiction & Fantasy',
#  'Action & Adventure, Classics, Drama, Romance',
#  'Action & Adventure, Classics, Drama, Science Fiction & Fantasy',
#  'Action & Adventure, Classics, Drama, Western',
#  'Action & Adventure, Classics, Romance',
#  'Action & Adventure, Classics, Science Fiction & Fantasy',
#  'Action & Adventure, Classics, Western',
#  'Action & Adventure, Classics, Western, Romance',
#  'Action & Adventure, Comedy, Drama, Kids & Family',
#  'Action & Adventure, Comedy, Mystery & Suspense, Science Fiction & Fantasy',
#  'Action & Adventure, Drama',
#  'Action & Adventure, Drama, Kids & Family, Science Fiction & Fantasy',
#  'Action & Adventure, Drama, Mystery & Suspense',
#  'Action & Adventure, Drama, Mystery & Suspense, Science Fiction & Fantasy',
#  'Action & Adventure, Drama, Science Fiction & Fantasy',
#  'Action & Adventure, Drama, Western',
#  'Action & Adventure, Science Fiction & Fantasy',
#  'Animation, Comedy, Kids & Family',
#  'Animation, Drama, Kids & Family, Musical & Performing Arts, Science Fiction & Fantasy, Romance',
#  'Art House & International, Classics, Comedy, Drama, Romance',
#  'Art House & International, Classics, Drama',
#  'Art House & International, Drama',
#  'Art House & International, Drama, Mystery & Suspense',
#  'Art House & International, Drama, Romance',
#  'Art House & International, Drama, Sports & Fitness',
#  'Classics, Comedy',
#  'Classics, Comedy, Drama',
#  'Classics, Comedy, Drama, Kids & Family',
#  'Classics, Comedy, Drama, Kids & Family, Musical & Performing Arts',
#  'Classics, Comedy, Drama, Musical & Performing Arts',
#  'Classics, Comedy, Drama, Musical & Performing Arts, Romance',
#  'Classics, Comedy, Drama, Musical & Performing Arts, Western',
#  'Classics, Comedy, Drama, Mystery & Suspense, Romance',
#  'Classics, Comedy, Drama, Romance',
#  'Classics, Comedy, Drama, Science Fiction & Fantasy, Romance',
#  'Classics, Comedy, Kids & Family, Musical & Performing Arts, Science Fiction & Fantasy',
#  'Classics, Comedy, Musical & Performing Arts',
#  'Classics, Comedy, Musical & Performing Arts, Romance',
#  'Classics, Comedy, Mystery & Suspense',
#  'Classics, Comedy, Romance',
#  'Classics, Comedy, Science Fiction & Fantasy, Romance',
#  'Classics, Documentary, Drama',
#  'Classics, Documentary, Drama, Romance',
#  'Classics, Documentary, Musical & Performing Arts, Special Interest, Television',
#  'Classics, Drama',
#  'Classics, Drama, Faith & Spirituality',
#  'Classics, Drama, Kids & Family',
#  'Classics, Drama, Kids & Family, Musical & Performing Arts',
#  'Classics, Drama, Kids & Family, Romance',
#  'Classics, Drama, Kids & Family, Science Fiction & Fantasy',
#  'Classics, Drama, Kids & Family, Science Fiction & Fantasy, Special Interest, Romance',
#  'Classics, Drama, Musical & Performing Arts',
#  'Classics, Drama, Musical & Performing Arts, Romance',
#  'Classics, Drama, Mystery & Suspense',
#  'Classics, Drama, Mystery & Suspense, Romance',
#  'Classics, Drama, Mystery & Suspense, Science Fiction & Fantasy',
#  'Classics, Drama, Romance',
#  'Classics, Drama, Television, Romance',
#  'Classics, Drama, Western',
#  'Classics, Drama, Western, Romance',
#  'Classics, Horror',
#  'Classics, Kids & Family',
#  'Classics, Kids & Family, Musical & Performing Arts, Science Fiction & Fantasy',
#  'Classics, Musical & Performing Arts, Romance',
#  'Classics, Western',
#  'Comedy',
#  'Comedy, Drama',
#  'Comedy, Drama, Musical & Performing Arts',
#  'Comedy, Drama, Mystery & Suspense',
#  'Comedy, Drama, Mystery & Suspense, Science Fiction & Fantasy, Romance',
#  'Comedy, Drama, Romance',
#  'Comedy, Drama, Sports & Fitness',
#  'Comedy, Musical & Performing Arts',
#  'Comedy, Romance',
#  'Comedy, Science Fiction & Fantasy, Romance, Sports & Fitness',
#  'Cult Movies, Drama',
#  'Drama',
#  'Drama, Gay & Lesbian',
#  'Drama, Kids & Family, Science Fiction & Fantasy, Sports & Fitness',
#  'Drama, Musical & Performing Arts',
#  'Drama, Musical & Performing Arts, Romance',
#  'Drama, Mystery & Suspense',
#  'Drama, Mystery & Suspense, Romance',
#  'Drama, Mystery & Suspense, Science Fiction & Fantasy',
#  'Drama, Romance',
#  'Drama, Science Fiction & Fantasy',
#  'Drama, Science Fiction & Fantasy, Romance',
#  'Drama, Science Fiction & Fantasy, Special Interest, Romance',
#  'Drama, Sports & Fitness',
#  'Drama, Western',
#  'Horror, Mystery & Suspense',
#  'Kids & Family, Mystery & Suspense',
#  'Musical & Performing Arts',
#  'Musical & Performing Arts, Romance',
#  'Mystery & Suspense',
#  'Mystery & Suspense, Western',
#  'Science Fiction & Fantasy']

# %%
sorted(df['Content Rating'].unique())
# Out:
# ['G', 'NR', 'PG', 'PG-13', 'R']

# %%
sorted(df['Production Company'].unique())
# Out:
# ['20th Century Fox',
#  '20th Century Fox Film Corporation',
#  '20th Century-Fox',
#  '21 Laps Entertainment',
#  'A24',
#  'A24 Films',
#  'Annapurna Pictures',
#  'Batjac Productions',
#  'Buena Vista',
#  'Buena Vista Internationa',
#  'Buena Vista Pictures',
#  'Columbia',
#  'Columbia Pictures',
#  'Columbia Pictures Corporation',
#  'Criterion Collection',
#  'DreamWorks Studios',
#  'Dreamworks',
#  'Dreamworks Distribution',
#  'Dreamworks Distribution LLC',
#  'Dreamworks Pictures',
#  'Eagle-Lion Films',
#  'Element Pictures',
#  'Embassy Pictures/Rialto Pictures',
#  'Film 44',
#  'Focus Features',
#  'Fox',
#  'Fox Searchlight',
#  'Fox Searchlight Pictures',
#  'Fox Searchlight Pictures, Film4 and Waypoint',
#  'Gramercy',
#  'Gramercy Pictures',
#  'Gravitas',
#  'HBO Video',
#  'Hollywood/Buena Vista',
#  'IFC Films',
#  'Image Entertainment Inc.',
#  'Liberty Films',
#  'Liongate Films',
#  'Lions Gate Films',
#  'Lionsgate',
#  'Live Home Video',
#  'MCA Universal Home Video',
#  'MGM',
#  'MGM Home Entertainment',
#  'MGM/United Artists',
#  'Madacy Entertainment',
#  'Marvel Studios',
#  'Media Home Entertainment',
#  'Miramax',
#  'Miramax Films',
#  'NCM Fathom',
#  'Nelson Entertainment',
#  'Netflix',
#  'New Line Cinema',
#  'New Line Home Entertainment',
#  'Open Road Films',
#  'Orion Pictures',
#  'Orion Pictures Corporation',
#  'Paramount',
#  'Paramount Classics',
#  'Paramount Home Video',
#  'Paramount Pictures',
#  'Paramount Studios',
#  'Paramount Vantage',
#  'RKO',
#  'RKO Radio Pictures',
#  'Republic Pictures',
#  'Rialto Pictures',
#  'Roadside Attractions',
#  'Roadside Attractions\xa0',
#  'Samuel Goldwyn Films',
#  'See-Saw Films',
#  'Slowhand Releasing',
#  'Sony Classics',
#  'Sony Pictures',
#  'Sony Pictures Classics',
#  'Sony Pictures Entertainment',
#  'Sony Pictures Home Entertainment',
#  'Sony Pictures/Screen Gems',
#  'Strand Releasing',
#  'Summit Entertainment',
#  'The Weinstein Co.',
#  'The Weinstein Co./MGM',
#  'The Weinstein Company',
#  'TriStar Pictures',
#  'Turner Home Entertainment',
#  'Twentieth Century Fox',
#  'Twentieth Century Fox Home Entertainment',
#  'USA Films',
#  'United Artists',
#  'United Artists Films',
#  'Universal',
#  'Universal Pictures',
#  'Universal Studios',
#  'Unknown',
#  'WARNER BROTHERS PICTURES',
#  'WB',
#  'Walt Disney Pictures',
#  'Walt Disney Productions',
#  'Warner Bros.',
#  'Warner Bros. Pictures',
#  'Warner Brothers/Seven Arts',
#  'Warner Home Video',
#  'Woodfall Film Productions']

# %%
sorted(df['Tomatometer Status'].unique())
# Out:
# ['Certified-Fresh', 'Fresh', 'Rotten']

# %%
sorted(df['Audience Status'].unique())
# Out:
# ['Spilled', 'Upright']

# %% [markdown]
# Замены надо производить только в столбце "Production Company"

# %%
def dup(df, duplicates, correct):
    for d in duplicates:
        df['Production Company'] = df['Production Company'].replace(d, correct)
    return df

# %%
df = dup(df, ['20th Century Fox Film Corporation','20th Century-Fox','Twentieth Century Fox'], '20th Century Fox')
df = dup(df,['A24 Films'],'A24')
df = dup(df,['Buena Vista', 'Hollywood/Buena Vista'],'Buena Vista Pictures')
df = dup(df, ['Columbia Pictures Corporation','Columbia'], 'Columbia Pictures')
df = dup(df, ['DreamWorks Studios', 'Dreamworks'], 'Dreamworks Pictures')
df = dup(df, ['Fox Searchlight', 'Fox Searchlight Pictures, Film4 and Waypoint'], 'Fox Searchlight Pictures')
df = dup(df, ['Gramercy'], 'Gramercy Pictures')
df = dup(df, ['Lions Gate Films', 'Lionsgate'], 'Liongate Films')
df = dup(df, ['Miramax'], 'Miramax Films')
df = dup(df, ['Orion Pictures Corporation'], 'Orion Pictures')
df = dup(df, ['Paramount', 'Paramount Classics', 'Paramount Studios'],'Paramount Pictures')
df = dup(df, ['RKO Radio Pictures'], 'RKO')
df = dup(df, ['Roadside Attractions\xa0'], 'Roadside Attractions')
df = dup(df, ['Sony Classics','Sony Pictures Classics', 'Sony Pictures Entertainment' ], 'Sony Pictures')
df = dup(df, ['The Weinstein Co./MGM', 'The Weinstein Company'], 'The Weinstein Co.')
df = dup(df, ['United Artists Films'], 'United Artists')
df = dup(df, ['Universal','Universal Studios'], 'Universal Pictures')
df = dup(df, ['WARNER BROTHERS PICTURES','WB', 'Warner Bros.'], 'Warner Bros. Pictures')
df = dup(df, ['Walt Disney Productions'], 'Walt Disney Pictures')

# %% [markdown]
# ### Замена типов столбцов

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 439 entries, 0 to 561
# Data columns (total 29 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Film                              439 non-null    object
#  1   Oscar Year                        439 non-null    object
#  2   Film Studio/Producer(s)           439 non-null    object
#  3   Award                             439 non-null    object
#  4   Year of Release                   439 non-null    int64
#  5   Movie Time                        439 non-null    int64
#  6   Movie Genre                       439 non-null    object
#  7   IMDB Rating                       439 non-null    float64
#  8   IMDB Votes                        439 non-null    object
#  9   Movie Info                        439 non-null    object
#  10  Genres                            439 non-null    object
#  11  Critic Consensus                  439 non-null    object
#  12  Content Rating                    439 non-null    object
#  13  Directors                         439 non-null    object
#  14  Authors                           439 non-null    object
#  15  Actors                            439 non-null    object
#  16  Original Release Date             439 non-null    object
#  17  Streaming Release Date            439 non-null    object
#  18  Production Company                439 non-null    object
#  19  Tomatometer Status                439 non-null    object
#  20  Tomatometer Rating                439 non-null    float64
#  21  Tomatometer Count                 439 non-null    float64
#  22  Audience Status                   439 non-null    object
#  23  Audience Rating                   439 non-null    float64
#  24  Audience Count                    439 non-null    float64
#  25  Tomatometer Top Critics Count     439 non-null    float64
#  26  Tomatometer Fresh Critics Count   439 non-null    float64
#  27  Tomatometer Rotten Critics Count  439 non-null    float64
#  28  Film ID                           439 non-null    object
# dtypes: float64(8), int64(2), object(19)
# memory usage: 119.1+ KB

# %% [markdown]
# Удалим все запятые и элементов столбца "IMDB Votes"

# %%
df['IMDB Votes'] = df['IMDB Votes'].replace({',':''}, regex=True)

# %%
df['Original Release Date'] = pd.to_datetime(df['Original Release Date'],format = '%Y-%m-%d')
df['Streaming Release Date'] = pd.to_datetime(df['Streaming Release Date'],format = '%Y-%m-%d')
df['Year of Release'] = df['Year of Release'].astype(int)
df['Movie Time'] = df['Movie Time'].astype(int)
df['IMDB Votes'] = df['IMDB Votes'].astype(int)
df['Tomatometer Rating'] = df['Tomatometer Rating'].astype(int)
df['Tomatometer Count'] = df['Tomatometer Count'].astype(int)
df['Audience Rating'] = df['Audience Rating'].astype(int)
df['Audience Count'] = df['Audience Count'].astype(int)
df['Tomatometer Top Critics Count'] = df['Tomatometer Top Critics Count'].astype(int)
df['Tomatometer Fresh Critics Count'] = df['Tomatometer Fresh Critics Count'].astype(int)
df['Tomatometer Rotten Critics Count'] = df['Tomatometer Rotten Critics Count'].astype(int)
df
# Out:
#                     Film Oscar Year  \
# 0                  Wings    1927/28
# 3    The Broadway Melody    1928/29
# 6         In Old Arizona    1928/29
# 9          The Big House    1929/30
# 13              Cimarron    1930/31
# ..                   ...        ...
# 552       A Star Is Born       2018
# 553                 Vice       2018
# 557         The Irishman       2019
# 559                Joker       2019
# 561       Marriage Story       2019
#
#                                Film Studio/Producer(s)    Award  \
# 0                                 Famous Players-Lasky   Winner
# 3                                  Metro-Goldwyn-Mayer   Winner
# 6                                                  Fox  Nominee
# 9                                         Cosmopolitan  Nominee
# 13                                           RKO Radio   Winner
# ..                                                 ...      ...
# 552  Bill Gerber, Bradley Cooper, and Lynette Howel...  Nominee
# 553  Dede Gardner, Jeremy Kleiner, Adam McKay, and ...  Nominee
# 557  Martin Scorsese, Robert De Niro, Jane Rosentha...  Nominee
# 559  Todd Phillips, Bradley Cooper, and Emma Tillin...  Nominee
# 561                     Noah Baumbach and David Heyman  Nominee
#
#      Year of Release  Movie Time             Movie Genre  IMDB Rating  \
# 0               1927         144       Drama,Romance,War          7.5
# 3               1929         100   Drama,Musical,Romance          5.7
# 6               1928          95                 Western          5.6
# 9               1930          87    Crime,Drama,Thriller          7.1
# 13              1931         123           Drama,Western          5.9
# ..               ...         ...                     ...          ...
# 552             2018         136     Drama,Music,Romance          7.6
# 553             2018         132  Biography,Comdey,Drama          7.2
# 557             2019         209   Biography,Crime,Drama          7.8
# 559             2019         122    Crime,Drama,Thriller          8.4
# 561             2019         137    Comedy,Drama,Romance          7.9
#
#      IMDB Votes                                         Movie Info  ...  \
# 0         12221  With World War I afoot, David Armstrong (Richa...  ...
# 3          6890  Vaudeville sisters "Hank" (Bessie Love) and Qu...  ...
# 6          1019  In this early Western, notorious bandit the Ci...  ...
# 9          2079  After being convicted of manslaughter, drunk d...  ...
# 13         5851  In 1889, adventurous lawyer and newspaper edit...  ...
# ..          ...                                                ...  ...
# 552      354157  Seasoned musician Jackson Maine discovers -- a...  ...
# 553      132014  Gov. George W. Bush of Texas picks Dick Cheney...  ...
# 557      349303  In the 1950s, truck driver Frank Sheeran gets ...  ...
# 559     1056051  Forever alone in a crowd, failed comedian Arth...  ...
# 561      270304  A stage director and his actor wife struggle t...  ...
#
#     Tomatometer Status Tomatometer Rating Tomatometer Count Audience Status  \
# 0      Certified-Fresh                 93                46         Upright
# 3               Rotten                 33                24         Spilled
# 6               Rotten                 56                 9         Spilled
# 9                Fresh                 75                 8         Upright
# 13              Rotten                 50                24         Spilled
# ..                 ...                ...               ...             ...
# 552    Certified-Fresh                 90               517         Upright
# 553              Fresh                 65               359         Upright
# 557    Certified-Fresh                 96               439         Upright
# 559              Fresh                 68               574         Upright
# 561    Certified-Fresh                 94               381         Upright
#
#     Audience Rating Audience Count Tomatometer Top Critics Count  \
# 0                78           3530                             9
# 3                21           1813                             7
# 6                38            356                             2
# 9                69            323                             0
# 13               25           1514                             6
# ..              ...            ...                           ...
# 552              79          20442                            62
# 553              60           5061                            47
# 557              86           1057                            53
# 559              88          66303                            56
# 561              85            184                            48
#
#     Tomatometer Fresh Critics Count Tomatometer Rotten Critics Count  \
# 0                                43                                3
# 3                                 8                               16
# 6                                 5                                4
# 9                                 6                                2
# 13                               12                               12
# ..                              ...                              ...
# 552                             466                               52
# 553                             234                              125
# 557                             421                               19
# 559                             393                              182
# 561                             359                               22
#
#                                   Film ID
# 0    2becf7d5-a3de-46ab-ae45-abdd6b588067
# 3    de063f3f-2d35-4e1c-8636-6eb4c16bd236
# 6    a0644f19-a136-44c2-ab5d-50978ef19608
# 9    297aa285-29d7-4a22-b833-c5632ab3e562
# 13   db2683c0-128e-4b5c-858f-d9f18c2fb9b9
# ..                                    ...
# 552  a8a00610-8b95-4d5f-b95e-128b6a2853ea
# 553  27048415-ff2e-427e-a4de-5d2898a0812d
# 557  cf8fb1fa-1a2b-48bd-a241-c7e9d487c09d
# 559  9988cdef-854b-4e3d-8dc4-19e8e8717b9b
# 561  4dfbadb9-b7f9-4c24-bbd8-5d55dce2c7c6
#
# [439 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 439 entries, 0 to 561
# Data columns (total 29 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Film                              439 non-null    object
#  1   Oscar Year                        439 non-null    object
#  2   Film Studio/Producer(s)           439 non-null    object
#  3   Award                             439 non-null    object
#  4   Year of Release                   439 non-null    int32
#  5   Movie Time                        439 non-null    int32
#  6   Movie Genre                       439 non-null    object
#  7   IMDB Rating                       439 non-null    float64
#  8   IMDB Votes                        439 non-null    int32
#  9   Movie Info                        439 non-null    object
#  10  Genres                            439 non-null    object
#  11  Critic Consensus                  439 non-null    object
#  12  Content Rating                    439 non-null    object
#  13  Directors                         439 non-null    object
#  14  Authors                           439 non-null    object
#  15  Actors                            439 non-null    object
#  16  Original Release Date             439 non-null    datetime64[ns]
#  17  Streaming Release Date            439 non-null    datetime64[ns]
#  18  Production Company                439 non-null    object
#  19  Tomatometer Status                439 non-null    object
#  20  Tomatometer Rating                439 non-null    int32
#  21  Tomatometer Count                 439 non-null    int32
#  22  Audience Status                   439 non-null    object
#  23  Audience Rating                   439 non-null    int32
#  24  Audience Count                    439 non-null    int32
#  25  Tomatometer Top Critics Count     439 non-null    int32
#  26  Tomatometer Fresh Critics Count   439 non-null    int32
#  27  Tomatometer Rotten Critics Count  439 non-null    int32
#  28  Film ID                           439 non-null    object
# dtypes: datetime64[ns](2), float64(1), int32(10), object(16)
# memory usage: 101.9+ KB

# %% [markdown]
# # Обогащение данных

# %% [markdown]
# Из столбца "Streaming Release Date" вытащим год.

# %%
df['Year of Streaming Release'] = df['Streaming Release Date'].dt.year

# %% [markdown]
# Добавим столбец, который будет находить разницу между годом оригинального релиза и годом стримингового релиза

# %%
df['Difference S and O Realease Year'] = df['Year of Streaming Release'] - df['Year of Release']

# %% [markdown]
# Добавим столбце, который будет считать среднюю оценку фильма с помощью столбцов "IMDB Rating", "Tomatometer Rating" и "Audience Rating"

# %%
df['Avg Score'] = round((df['IMDB Rating']*10 + df['Tomatometer Rating'] + df['Audience Rating'])/3)

# %% [markdown]
# Добавим столбец, учитывающий суммарное число оценк фильмов. Будем учитывать только столбцы "IMDB Votes"  и "Audience Count", так как столбец "Tomatometer Count" показывает число оценок критиков, а оно зачастую несоизмеримо мало с числом оценок зрителей

# %%
df['Votes'] = df['IMDB Votes'] + df['Audience Count']

# %% [markdown]
# Заменим значения в столбцах "Award", "Tomatometer Status", "Audience Status" на числовые

# %%
dict_cond = {'Winner': 1,
             'Nominee': 0}
df['Award'] = df['Award'].map(dict_cond)

# %%
dict_cond = {'Upright': 1,
             'Spilled': 0}
df['Audience Status'] = df['Audience Status'].map(dict_cond)

# %%
dict_cond = {'Certified-Fresh': 2,
             'Fresh' : 1,
             'Rotten': 0}
df['Tomatometer Status'] = df['Tomatometer Status'].map(dict_cond)

# %%
df
# Out:
#                     Film Oscar Year  \
# 0                  Wings    1927/28
# 3    The Broadway Melody    1928/29
# 6         In Old Arizona    1928/29
# 9          The Big House    1929/30
# 13              Cimarron    1930/31
# ..                   ...        ...
# 552       A Star Is Born       2018
# 553                 Vice       2018
# 557         The Irishman       2019
# 559                Joker       2019
# 561       Marriage Story       2019
#
#                                Film Studio/Producer(s)  Award  \
# 0                                 Famous Players-Lasky      1
# 3                                  Metro-Goldwyn-Mayer      1
# 6                                                  Fox      0
# 9                                         Cosmopolitan      0
# 13                                           RKO Radio      1
# ..                                                 ...    ...
# 552  Bill Gerber, Bradley Cooper, and Lynette Howel...      0
# 553  Dede Gardner, Jeremy Kleiner, Adam McKay, and ...      0
# 557  Martin Scorsese, Robert De Niro, Jane Rosentha...      0
# 559  Todd Phillips, Bradley Cooper, and Emma Tillin...      0
# 561                     Noah Baumbach and David Heyman      0
#
#      Year of Release  Movie Time             Movie Genre  IMDB Rating  \
# 0               1927         144       Drama,Romance,War          7.5
# 3               1929         100   Drama,Musical,Romance          5.7
# 6               1928          95                 Western          5.6
# 9               1930          87    Crime,Drama,Thriller          7.1
# 13              1931         123           Drama,Western          5.9
# ..               ...         ...                     ...          ...
# 552             2018         136     Drama,Music,Romance          7.6
# 553             2018         132  Biography,Comdey,Drama          7.2
# 557             2019         209   Biography,Crime,Drama          7.8
# 559             2019         122    Crime,Drama,Thriller          8.4
# 561             2019         137    Comedy,Drama,Romance          7.9
#
#      IMDB Votes                                         Movie Info  ...  \
# 0         12221  With World War I afoot, David Armstrong (Richa...  ...
# 3          6890  Vaudeville sisters "Hank" (Bessie Love) and Qu...  ...
# 6          1019  In this early Western, notorious bandit the Ci...  ...
# 9          2079  After being convicted of manslaughter, drunk d...  ...
# 13         5851  In 1889, adventurous lawyer and newspaper edit...  ...
# ..          ...                                                ...  ...
# 552      354157  Seasoned musician Jackson Maine discovers -- a...  ...
# 553      132014  Gov. George W. Bush of Texas picks Dick Cheney...  ...
# 557      349303  In the 1950s, truck driver Frank Sheeran gets ...  ...
# 559     1056051  Forever alone in a crowd, failed comedian Arth...  ...
# 561      270304  A stage director and his actor wife struggle t...  ...
#
#     Audience Rating Audience Count Tomatometer Top Critics Count  \
# 0                78           3530                             9
# 3                21           1813                             7
# 6                38            356                             2
# 9                69            323                             0
# 13               25           1514                             6
# ..              ...            ...                           ...
# 552              79          20442                            62
# 553              60           5061                            47
# 557              86           1057                            53
# 559              88          66303                            56
# 561              85            184                            48
#
#     Tomatometer Fresh Critics Count Tomatometer Rotten Critics Count  \
# 0                                43                                3
# 3                                 8                               16
# 6                                 5                                4
# 9                                 6                                2
# 13                               12                               12
# ..                              ...                              ...
# 552                             466                               52
# 553                             234                              125
# 557                             421                               19
# 559                             393                              182
# 561                             359                               22
#
#                                   Film ID Year of Streaming Release  \
# 0    2becf7d5-a3de-46ab-ae45-abdd6b588067                      2017
# 3    de063f3f-2d35-4e1c-8636-6eb4c16bd236                      2017
# 6    a0644f19-a136-44c2-ab5d-50978ef19608                      2017
# 9    297aa285-29d7-4a22-b833-c5632ab3e562                      2012
# 13   db2683c0-128e-4b5c-858f-d9f18c2fb9b9                      2017
# ..                                    ...                       ...
# 552  a8a00610-8b95-4d5f-b95e-128b6a2853ea                      2019
# 553  27048415-ff2e-427e-a4de-5d2898a0812d                      2019
# 557  cf8fb1fa-1a2b-48bd-a241-c7e9d487c09d                      2019
# 559  9988cdef-854b-4e3d-8dc4-19e8e8717b9b                      2019
# 561  4dfbadb9-b7f9-4c24-bbd8-5d55dce2c7c6                      2019
#
#     Difference S and O Realease Year Avg Score    Votes
# 0                                 90      82.0    15751
# 3                                 88      37.0     8703
# 6                                 89      50.0     1375
# 9                                 82      72.0     2402
# 13                                86      45.0     7365
# ..                               ...       ...      ...
# 552                                1      82.0   374599
# 553                                1      66.0   137075
# 557                                0      87.0   350360
# 559                                0      80.0  1122354
# 561                                0      86.0   270488
#
# [439 rows x 33 columns]

# %% [markdown]
# ### **Проверка "очищенных" данных**

# %% [markdown]
# Проверим строки на дубликаты

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Дубликатов нет. Проверим сводную информацию в DataFrame.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 439 entries, 0 to 561
# Data columns (total 33 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Film                              439 non-null    object
#  1   Oscar Year                        439 non-null    object
#  2   Film Studio/Producer(s)           439 non-null    object
#  3   Award                             439 non-null    int64
#  4   Year of Release                   439 non-null    int32
#  5   Movie Time                        439 non-null    int32
#  6   Movie Genre                       439 non-null    object
#  7   IMDB Rating                       439 non-null    float64
#  8   IMDB Votes                        439 non-null    int32
#  9   Movie Info                        439 non-null    object
#  10  Genres                            439 non-null    object
#  11  Critic Consensus                  439 non-null    object
#  12  Content Rating                    439 non-null    object
#  13  Directors                         439 non-null    object
#  14  Authors                           439 non-null    object
#  15  Actors                            439 non-null    object
#  16  Original Release Date             439 non-null    datetime64[ns]
#  17  Streaming Release Date            439 non-null    datetime64[ns]
#  18  Production Company                439 non-null    object
#  19  Tomatometer Status                439 non-null    int64
#  20  Tomatometer Rating                439 non-null    int32
#  21  Tomatometer Count                 439 non-null    int32
#  22  Audience Status                   439 non-null    int64
#  23  Audience Rating                   439 non-null    int32
#  24  Audience Count                    439 non-null    int32
#  25  Tomatometer Top Critics Count     439 non-null    int32
#  26  Tomatometer Fresh Critics Count   439 non-null    int32
#  27  Tomatometer Rotten Critics Count  439 non-null    int32
#  28  Film ID                           439 non-null    object
#  29  Year of Streaming Release         439 non-null    int32
#  30  Difference S and O Realease Year  439 non-null    int32
#  31  Avg Score                         439 non-null    float64
#  32  Votes                             439 non-null    int32
# dtypes: datetime64[ns](2), float64(2), int32(13), int64(3), object(13)
# memory usage: 110.5+ KB

# %%
df['Avg Score'] = df['Avg Score'].astype(int)

# %% [markdown]
# # EDA

# %% [markdown]
# ### Исследование основных параметров

# %% [markdown]
# Параметры:
# * Movie Time
# * Votes
# * Difference S and O Realease Year
# * Avg Score
#
# На эти перечисленные параметры будет обращено особое внимание с помощью гистограмм. Здесь выбросы будут влиять на форму и читаемость гистограмм.

# %%
df.describe()[['Movie Time','IMDB Votes','Tomatometer Count','Audience Count','Difference S and O Realease Year', "Avg Score"]]
# Out:
#        Movie Time    IMDB Votes  Tomatometer Count  Audience Count  \
# count  439.000000  4.390000e+02         439.000000    4.390000e+02
# mean   126.742597  2.355875e+05         110.697039    5.154145e+05
# min     66.000000  1.019000e+03           5.000000    6.000000e+00
# 25%    109.000000  1.438900e+04          25.000000    6.637500e+03
# 50%    123.000000  8.205100e+04          54.000000    3.716600e+04
# 75%    138.000000  2.965760e+05         199.000000    1.255365e+05
# max    228.000000  2.452594e+06         574.000000    3.579764e+07
# std     25.831555  3.657208e+05         119.541406    3.623107e+06
#
#        Difference S and O Realease Year   Avg Score
# count                        439.000000  439.000000
# mean                          38.405467   82.120729
# min                            0.000000   37.000000
# 25%                           12.000000   80.000000
# 50%                           38.000000   84.000000
# 75%                           63.000000   87.000000
# max                           90.000000   96.000000
# std                           27.453066    7.907080

# %%
columns = ['Movie Time','Votes','Difference S and O Realease Year', "Avg Score"]

for column in columns:
    df.hist(column, bins=50)

# %% [markdown]
# Заключение
#
# * Выбросы затрудняют чтение данных в столбце "Votes", "Avg Score"
# * На гистограмме данные столбца "Avg Score" смещены влево
# * Данные столбцов 'Votes' и 'Movie Time' смещены впарво

# %% [markdown]
# ### Изучение и обработка выбросов

# %% [markdown]
# Учитывая приведенные выше результаты, столбцы, содержащие выбросы, — это "IMDB Votes", 'Tomatometer Count', 'Audience Count', "Avg Score" и 'Movie Time'. Создадим DataFrame без этих выбросов. Выбросы можно идентифицировать путем определения нижнего/верхнего предела нормального диапазона значений.

# %%
outlier = df[["Votes", "Avg Score"]]
outlier
# Out:
#        Votes  Avg Score
# 0      15751         82
# 3       8703         37
# 6       1375         50
# 9       2402         72
# 13      7365         45
# ..       ...        ...
# 552   374599         82
# 553   137075         66
# 557   350360         87
# 559  1122354         80
# 561   270488         86
#
# [439 rows x 2 columns]

# %%
Q1 = outlier.quantile(0.25)
Q1
# Out:
# Votes        22088.5
# Avg Score       80.0
# Name: 0.25, dtype: float64

# %%
Q3 = outlier.quantile(0.75)
Q3
# Out:
# Votes        485107.0
# Avg Score        87.0
# Name: 0.75, dtype: float64

# %%
# IQR-оценки
IQR = Q3-Q1
# Отфильтрованные данные, из которых удалены выбросы
data_filtered = outlier[~((outlier < (Q1 - 1.5 * IQR)) |(outlier > (Q3 + 1.5 * IQR))).any(axis=1)]
data_filtered
# Out:
#        Votes  Avg Score
# 0      15751         82
# 9       2402         72
# 18     25328         79
# 21      3620         79
# 27     18903         81
# ..       ...        ...
# 551   153226         82
# 552   374599         82
# 557   350360         87
# 559  1122354         80
# 561   270488         86
#
# [376 rows x 2 columns]

# %%
index_list = list(data_filtered.index.values)

# %%
data_filtered = df[df.index.isin(index_list)]
data_filtered
# Out:
#                Film Oscar Year  \
# 0             Wings    1927/28
# 9     The Big House    1929/30
# 18      Grand Hotel    1931/32
# 21        The Champ    1931/32
# 27      42nd Street    1932/33
# ..              ...        ...
# 551            Roma       2018
# 552  A Star Is Born       2018
# 557    The Irishman       2019
# 559           Joker       2019
# 561  Marriage Story       2019
#
#                                Film Studio/Producer(s)  Award  \
# 0                                 Famous Players-Lasky      1
# 9                                         Cosmopolitan      0
# 18                                 Metro-Goldwyn-Mayer      1
# 21                                 Metro-Goldwyn-Mayer      0
# 27                                        Warner Bros.      0
# ..                                                 ...    ...
# 551              Gabriela Rodríguez and Alfonso Cuarón      0
# 552  Bill Gerber, Bradley Cooper, and Lynette Howel...      0
# 557  Martin Scorsese, Robert De Niro, Jane Rosentha...      0
# 559  Todd Phillips, Bradley Cooper, and Emma Tillin...      0
# 561                     Noah Baumbach and David Heyman      0
#
#      Year of Release  Movie Time            Movie Genre  IMDB Rating  \
# 0               1927         144      Drama,Romance,War          7.5
# 9               1930          87   Crime,Drama,Thriller          7.1
# 18              1932         112          Drama,Romance          7.4
# 21              1931          86            Drama,Sport          7.3
# 27              1933          89   Comedy,Drama,Musical          7.4
# ..               ...         ...                    ...          ...
# 551             2018         135                  Drama          7.7
# 552             2018         136    Drama,Music,Romance          7.6
# 557             2019         209  Biography,Crime,Drama          7.8
# 559             2019         122   Crime,Drama,Thriller          8.4
# 561             2019         137   Comedy,Drama,Romance          7.9
#
#      IMDB Votes                                         Movie Info  ...  \
# 0         12221  With World War I afoot, David Armstrong (Richa...  ...
# 9          2079  After being convicted of manslaughter, drunk d...  ...
# 18        18314  At a luxurious Berlin hotel between the wars, ...  ...
# 21         3003  Champ (Wallace Beery) is a down-on-his-luck bo...  ...
# 27        11342  When revered Broadway director Julian Marsh (W...  ...
# ..          ...                                                ...  ...
# 551      147705  Cleo is one of two domestic workers who help A...  ...
# 552      354157  Seasoned musician Jackson Maine discovers -- a...  ...
# 557      349303  In the 1950s, truck driver Frank Sheeran gets ...  ...
# 559     1056051  Forever alone in a crowd, failed comedian Arth...  ...
# 561      270304  A stage director and his actor wife struggle t...  ...
#
#     Audience Rating Audience Count Tomatometer Top Critics Count  \
# 0                78           3530                             9
# 9                69            323                             0
# 18               77           7014                            10
# 21               74            617                             2
# 27               74           7561                             4
# ..              ...            ...                           ...
# 551              72           5521                            56
# 552              79          20442                            62
# 557              86           1057                            53
# 559              88          66303                            56
# 561              85            184                            48
#
#     Tomatometer Fresh Critics Count Tomatometer Rotten Critics Count  \
# 0                                43                                3
# 9                                 6                                2
# 18                               36                                6
# 21                                9                                1
# 27                               24                                1
# ..                              ...                              ...
# 551                             370                               17
# 552                             466                               52
# 557                             421                               19
# 559                             393                              182
# 561                             359                               22
#
#                                   Film ID Year of Streaming Release  \
# 0    2becf7d5-a3de-46ab-ae45-abdd6b588067                      2017
# 9    297aa285-29d7-4a22-b833-c5632ab3e562                      2012
# 18   be69f946-6adc-47e4-8491-79d6c033f59d                      2016
# 21   c8994348-093e-4e22-8ffe-6ad3332a2bab                      2017
# 27   1ad59370-1ed5-4d3a-a8c4-8571f95da168                      2012
# ..                                    ...                       ...
# 551  1dc73d5e-4ae5-428e-a4f3-d465ffc9262d                      2018
# 552  a8a00610-8b95-4d5f-b95e-128b6a2853ea                      2019
# 557  cf8fb1fa-1a2b-48bd-a241-c7e9d487c09d                      2019
# 559  9988cdef-854b-4e3d-8dc4-19e8e8717b9b                      2019
# 561  4dfbadb9-b7f9-4c24-bbd8-5d55dce2c7c6                      2019
#
#     Difference S and O Realease Year Avg Score    Votes
# 0                                 90        82    15751
# 9                                 82        72     2402
# 18                                84        79    25328
# 21                                86        79     3620
# 27                                79        81    18903
# ..                               ...       ...      ...
# 551                                0        82   153226
# 552                                1        82   374599
# 557                                0        87   350360
# 559                                0        80  1122354
# 561                                0        86   270488
#
# [376 rows x 33 columns]

# %%
# создать гистограмму с отфильтрованным выбросом
filtered_outlier = data_filtered[["Votes", "Avg Score"]]

for col in filtered_outlier:
    data_filtered.hist(col, bins=100)

# %% [markdown]
# ### Изучение данных без выбросов

# %%
data_filtered.describe()[['Votes', "Avg Score"]]
# Out:
#               Votes   Avg Score
# count  3.760000e+02  376.000000
# mean   2.380984e+05   83.101064
# min    2.130000e+03   70.000000
# 25%    2.267125e+04   80.000000
# 50%    1.167795e+05   84.000000
# 75%    3.832150e+05   87.000000
# max    1.122354e+06   93.000000
# std    2.775257e+05    5.323197

# %%
print (df.hist('Votes', bins=100))
print (data_filtered.hist('Votes', bins=100))
# Out:
# [[<Axes: title={'center': 'Votes'}>]]
# [[<Axes: title={'center': 'Votes'}>]]

# %% [markdown]
# #### Заключение

# %% [markdown]
# - Выброс был уменьшен с максимального 35 000 000 до 1 100 000. Гистограмма всё равно не вглядит понятной, потому что большого числа фильмов значение данного столбца колеблется в райное от 0 до 200 000. Среднее значение все еще выше медианы, поэтому гистограмма имеет наклон впарво
#
#
# - На гистограмме видно, что большая часть числа оценок распределена в диапазоне 0 – 100 000. Максимальное число голосов составляет более 1 100 000. Для диапазона более 200 000 значение начинает резко уменьшаться.

# %%
print (df.hist('Avg Score', bins=100))
print (data_filtered.hist('Avg Score', bins=100))
# Out:
# [[<Axes: title={'center': 'Avg Score'}>]]
# [[<Axes: title={'center': 'Avg Score'}>]]

# %% [markdown]
# #### Заключение:
# - Нижний порог по средней оценке фильма был увеличен с 40 до 70. Среднее значение почти совпадает с медианным, поэтому мы имеем диаграмму почти симметричного распределения.
#
# - Судя по гистограмме, средняя оценка колеблется в районе 80-90 баллов. Значит будем считать такую оценку нормальной. Если оценка превышает указанный диапазон, то будем считать фильм отличным, а если меньше, то фильм будем считать чуть ниже среднего .

# %% [markdown]
# # Анализ по студиям

# %% [markdown]
# Проведём следующий анализ: найдём среднюю оценку фильма по студии продакшена, а также найдём число фильмов, которые были выпущены каждой студией

# %%
avg_score = data_filtered.pivot_table(index='Production Company', values='Avg Score', aggfunc='mean')
avg_score.sort_values(ascending=False ,by='Avg Score')
# Out:
#                           Avg Score
# Production Company
# Liberty Films             92.000000
# Open Road Films           90.000000
# Rialto Pictures           90.000000
# Eagle-Lion Films          90.000000
# Element Pictures          89.000000
# ...                             ...
# Liongate Films            78.000000
# Madacy Entertainment      77.000000
# MCA Universal Home Video  77.000000
# Media Home Entertainment  75.666667
# Gravitas                  70.000000
#
# [63 rows x 1 columns]

# %%
film_count = data_filtered.pivot_table(index='Production Company', values='Film ID', aggfunc='count')
film_count = film_count.sort_values(ascending=False, by ='Film ID' )
film_count = film_count.reset_index().reset_index()
film_count
# Out:
#     index                Production Company  Film ID
# 0       0             Warner Bros. Pictures       42
# 1       1                Paramount Pictures       30
# 2       2            MGM Home Entertainment       25
# 3       3                  20th Century Fox       24
# 4       4                Universal Pictures       20
# ..    ...                               ...      ...
# 58     58       New Line Home Entertainment        1
# 59     59                   Open Road Films        1
# 60     60  Embassy Pictures/Rialto Pictures        1
# 61     61                 Paramount Vantage        1
# 62     62                        NCM Fathom        1
#
# [63 rows x 3 columns]

# %%
film_count.plot(grid=True, figsize=(20, 7), kind = 'bar', x='Production Company',y='Film ID')
# Out:
# <Axes: xlabel='Production Company'>

# %% [markdown]
# #### Заключение
# * Как мы видим, самая высокая средняя оценка фильмов у студий "Liberty Films", "Rialto Pictures", "Eagle-Lion Films" и "Open Road Films", это связано с малым числом фильмов данных студий, прдеставленных в датасете.
# * Самое большое число фильмов у студий: "Warner Bros. Pictures" и "Paramount Pictures".

# %% [markdown]
# ## Факторы, влияющие на оценку фильма

# %% [markdown]
# На оценку могут влиять следующие факторы:
#
# * Продолжительность фильма
# * Наличие оскара
# * Рейтинг фильма
# * Год выхода
# * Число оценок

# %% [markdown]
# Для категориальных переменных (цвет и тип передачи) использовались прямоугольные диаграммы, а для остальных — диаграммы рассеяния. При анализе категориальных переменных категории должны содержать не менее 50 объявлений, чтобы их можно было анализировать.
# Матрица корреляции и графики корреляции будут использоваться для оценки силы и направления линейных связей между парами переменных.

# %%
# Отфильтровано 2 популярные студии
warner = data_filtered.loc[data_filtered['Production Company'] == 'Warner Bros. Pictures']
paramount = data_filtered.loc[data_filtered['Production Company'] == 'Paramount Pictures']

# %%
sns.lmplot(x="Movie Time", y="Avg Score", data=warner)
plt.title('Warner Bros. Pictures')
sns.lmplot(x="Movie Time", y="Avg Score", data=paramount)
plt.title('Paramount Pictures')
# Out:
# Text(0.5, 1.0, 'Paramount Pictures')

# %%
# вычисление корелляции
time_warner = warner[['Movie Time','Avg Score']]
corr_warner = time_warner.corr()
time_paramount = paramount[['Movie Time','Avg Score']]
corr_paramount = time_paramount.corr()

# %%
round(corr_warner,3)
# Out:
#             Movie Time  Avg Score
# Movie Time        1.00       0.07
# Avg Score         0.07       1.00

# %%
round(corr_paramount,3)
# Out:
#             Movie Time  Avg Score
# Movie Time       1.000     -0.002
# Avg Score       -0.002      1.000

# %% [markdown]
# ### Заключение
#
# Оценка фильмов "Warner Bros. Pictures" слегка растёт с их продолжительностью. Ситуации с "Paramount Pictures" иная: с увеличением продолжительности фильмов их оценка слегка падает. Но зависимость между продолжительностью фильма и его оценкой настолько слаба, что можно говорить о том, что её почти нет

# %%
sns.lmplot(x="Votes", y="Avg Score", data=warner, height = 5, aspect =3)
plt.title('Warner Bros. Pictures')
sns.lmplot(x="Votes", y="Avg Score", data=paramount, height = 5, aspect =3)
plt.title('Paramount Pictures')
# Out:
# Text(0.5, 1.0, 'Paramount Pictures')

# %%
# вычисление корелляции
vote_warner = warner[['Votes','Avg Score']]
corr_warner = vote_warner.corr()
vote_paramount = paramount[['Votes','Avg Score']]
corr_paramount = vote_paramount.corr()

# %%
round(corr_warner,3)
# Out:
#            Votes  Avg Score
# Votes        1.0        0.3
# Avg Score    0.3        1.0

# %%
round(corr_paramount,3)
# Out:
#            Votes  Avg Score
# Votes      1.000      0.078
# Avg Score  0.078      1.000

# %% [markdown]
# ### Заключение
#
# Оценки фильмов "Warner Bros. Pictures" и "Paramount Pictures" растут с их числом, но рост оценок у "Warner Bros. Pictures" значительнее

# %%
sns.lmplot(x="Year of Release", y="Avg Score", data=warner)
plt.title('Warner Bros. Pictures')
sns.lmplot(x="Year of Release", y="Avg Score", data=paramount)
plt.title('Paramount Pictures')
# Out:
# Text(0.5, 1.0, 'Paramount Pictures')

# %%
# вычисление корелляции
year_warner = warner[['Year of Release','Avg Score']]
corr_warner = year_warner.corr()
year_paramount = paramount[['Year of Release','Avg Score']]
corr_paramount = year_paramount.corr()

# %%
round(corr_warner,3)
# Out:
#                  Year of Release  Avg Score
# Year of Release            1.000      0.132
# Avg Score                  0.132      1.000

# %%
round(corr_paramount,3)
# Out:
#                  Year of Release  Avg Score
# Year of Release            1.000     -0.105
# Avg Score                 -0.105      1.000

# %% [markdown]
# ### Заключение
#
# С годами оценка фильмов "Warner Bros. Pictures" растёт, а у "Paramount Pictures" падает.

# %%
warner.boxplot(by ='Award', column =['Avg Score'], grid = True)
# Out:
# <Axes: title={'center': 'Avg Score'}, xlabel='Award'>

# %%
paramount.boxplot(by ='Award', column =['Avg Score'], grid = True)
# Out:
# <Axes: title={'center': 'Avg Score'}, xlabel='Award'>

# %% [markdown]
# ### Заключение
#
# Наличие оскара влияет на оценку фильмов "Warner Bros. Pictures", причём в лучшую сторону. Для фильмов "Paramount Pictures" ситуация иная: наличие оскра почти не влияет на оценку фильмов, так как даже средняя оценка почти совпадает.

# %%
warner.boxplot(by ='Content Rating', column =['Avg Score'], grid = True)
# Out:
# <Axes: title={'center': 'Avg Score'}, xlabel='Content Rating'>

# %%
paramount.boxplot(by ='Content Rating', column =['Avg Score'], grid = True)
# Out:
# <Axes: title={'center': 'Avg Score'}, xlabel='Content Rating'>

# %% [markdown]
# ### Заключение
#
# 1. У компании "Warner Bros. Pictures" наибольшую среднюю оценку получают фильмы с рейтингом PG, а наименьшую фильмы, не имеющие рейтинг, а значит рейтинг фильма влияет на его оценку.
# 2. У комапании "Paramount Pictures" рейтинг фильма почти никак не влияет на его оценку, хотя фильмы рейтинга G чуть более успешены.

# %% [markdown]
# # Общие выводы

# %% [markdown]
# *Заполнение пропущенных значений*
#
# - Отсутствующее значение стобцов "Critic Consensus", "Movie Info", "Directors", "Authors" были запонены unknown'ами
# - Недостающее значение в столбце "Streaming Release Date" может быть заполнено в зависимости от большинства для фильмов данной студии.
# - Отсутствующее значение столбца "Audience Status" может быть заполнено в зависимости от значения столбца "Audience Rating".
#
# *Изменение типа данных:*
#
# - Тип данных столбцов 'Original Release Date' и "Streaming Release Date" изменены на тип данных 'дату и время';
# - Тип данных столбцов 'Year of Release', 'Movie Time', 'IMDB Votes', 'Tomatometer Rating', 'Tomatometer Count', 'Audience Rating', 'Audience Count', 'Tomatometer Top Critics Count', 'Tomatometer Fresh Critics Count' и 'Tomatometer Rotten Critics Count' тип данных столбца с плавающей запятой изменен на int.
#
# *Редактирование данных:*
#
# - Добавили значения года выхода фильма в стриминговый релиз.
# - Добавили разницу между годами стримингового релиза и оригинального.
# - Добавили среднюю оценку для каждого фильма.
# - Добавили общее число оценок для каждого фильма.
# - Проверка дублированных данные и их удаление.
#
# *Проверка выбросов:*
#
# Были найдены выбросы параметров: Votes, Avg Score.
# На гистограмме данные столбца "Avg Score" смещены влево.
# А данные столбцов 'Votes' и 'Movie Time' смещены впарво
#
# *Удаление выбросов:*
#
# - Определили нижний и верхний пределы выбросов и сохранили их в отдельном DataFrame.
# - Выполнили сравнение, используя гистограмму данных, которые содержат выбросы и не содержат выбросов. Сравнение показало, что гистограмма без выбросов позволяет легко исследовать среднее, медианное значение в данных столбцов.
#
# *Изучение оценочного фактора:*
#
# Факторы, влияющие на оценку: продолжительность фильма, наличие оскара, рейтинг фильма, год выхода, число оценок.
# Продолжительность фильма, число оценок и год выхода используют метод диаграммы рассеяния, а остальные используют коробчатую диаграмму для исследования.
#
# #### Результат:
#
# *Продолжительность фильма*
#
# Так как коэффициент корелляции небольшой, то продолжительность фильма почти не влияет на его оценку.
#
# *Число оценок*
#
# Коэффициент корелляции для данной характеристики у фильмов компании "Warner Bros. Pictures" довольно велик, а значит число оценок всё же влияет на итоговую оценку их фильмов. Для "Paramount Pictures" ситуация иная: коэффициент корелляциии довольно мал, а значит число оценок почти не влияет на итоговую оценку фильма данной студии. В общем, влияние данной характеристи на среднюю оценку фильма зависит от студии, снявшей фильм.
#
# *Год выхода*
#
# Год выхода оказывает некое влияние на среднюю оценку фильмов, но это влияние довольно мало, так как модуль коэффициента корелляции данной характеристикии для обоих студий не превышвет 0.1.
#
# *Наличие оскара*
#
# Наличие оскара оказывает влияние на оценку фильма. Однако, это влияние зависит от студии, выпускающей фильм.
#
# *Рейтинг фильма*
#
# Рейтинг фильма также оказывает влияние на его итоговую оценку. Но для разных студий это влияние разное: у одной студии могут быть более успешны фильмы с рейтингом PG, а у другой с рейтингом G.
